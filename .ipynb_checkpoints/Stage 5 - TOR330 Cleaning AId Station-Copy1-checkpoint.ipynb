# %%
import re
import pandas as pd
import time
import numpy as np
import matplotlib.pyplot as plt

# %%
# # Set pandas options to display all columns and rows
# pd.set_option('display.max_columns', None)  # Show all columns
# pd.set_option('display.max_rows', None)     # Show all rows

# %%
years = ['2021', '2022', '2023', '2024']
races = ['TOR330', 'TOR450', 'TOR130']

# %% [markdown]
# ## Looping through scraped data from 100X100trail

# %%
races = ['TOR330'
        # ,'TOR450'
        ]
# years = ['2023']

TORX_df = {}

for race in races:
    for year in years:
        df = pd.read_excel(f'{race} Data/100x100trail/aid_station_{race}_{year}.xlsx',
                                 dtype={'Start Date': 'string',
                                        'Year': 'string'})
        print(f'{race}_{year} {df.shape}')
        # Store the DataFrame in the dictionary with a key like 'TOR330_2021'
        TORX_df[f'{race}_{year}'] = df
    print('*'*50)
        
#         print(f"Data read from f'{race}_{year}.xlsx'")
# Out:
# TOR330_2021 (28600, 10)
# TOR330_2022 (34940, 10)
# TOR330_2023 (42964, 10)
# TOR330_2024 (39181, 10)
# **************************************************

# %%
TORX_df_concat = pd.concat(TORX_df)

# %%
# TOR330 = TORX_df_concat[TORX_df_concat['Year'] == '2023']
TOR330 = TORX_df_concat.copy().reset_index(drop = True)
TOR330.head()
# Out:
#            Name  Bib Sex Nationality    Race  Year Category  \
# 0  Colle Franco    1   M          IT  TOR330  2021       V1
# 1  Colle Franco    1   M          IT  TOR330  2021       V1
# 2  Colle Franco    1   M          IT  TOR330  2021       V1
# 3  Colle Franco    1   M          IT  TOR330  2021       V1
# 4  Colle Franco    1   M          IT  TOR330  2021       V1
#
#                                    Place                       Time  Status
# 0           660 - FINISH 330|349.3|30879  2021-09-15T04:43:57+00:00    True
# 1  650 - Mont de la Saxe 130|133.7|12388  2021-09-15T04:04:48+00:00    True
# 2    630 - Rif. Frassati 130|118.9|11422  2021-09-15T01:19:06+00:00    True
# 3           620 - Bosses 130|109.8|10210  2021-09-14T23:19:05+00:00    True
# 4  610 - Ponteille Desot 330|308.9|28045  2021-09-14T21:59:00+00:00    True

# %% [markdown]
# ### DUV and ITRA data

# %%
    TORX_duv_df = pd.read_excel(f'Database Data/TORX_duv_df.xlsx',
                                     dtype={'Start Date': 'string',
                                            'Year': 'string'})

    TORX_itra_no_DNF = pd.read_excel(f'Database Data/TORX_itra_no_DNF.xlsx',
                                     dtype={'Start Date': 'string',
                                           'Year': 'string'})

# %%
def find_out_the_rows_difference_between_datasets(df):
    for year in years :
        for race in races:
            print(' - ',race, year)
            print('ITRA rows: ', TORX_itra_no_DNF[(TORX_itra_no_DNF['Year'] == year) &
                              (TORX_itra_no_DNF['Race'] == race)].shape[0])
            print('DUV rows: ',TORX_duv_df[(TORX_duv_df['Year'] == year) &
                              (TORX_duv_df['Race'] == race)].shape[0])
            print('TOR330 rows: ',df[(df['Year'] == year) &
                          (df['Race'] == race) &
                              (df['Status'] == True)].shape[0])
        print('\n', '*'*20)
        
        if year == '2022' and race == 'TOR330':
            print(TORX_itra_no_DNF[(TORX_itra_no_DNF['Race'] == race) &
                                  (TORX_itra_no_DNF['Year'] == year)].groupby(['Status'])['Status'].count())
            print('\n', '*'*20)

# %%
find_out_the_rows_difference_between_datasets(TORX_df_concat)
# Out:
#  -  TOR330 2021
# ITRA rows:  431
# DUV rows:  431
# TOR330 rows:  23001
#
#  ********************
#  -  TOR330 2022
# ITRA rows:  590
# DUV rows:  408
# TOR330 rows:  20017
#
#  ********************
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [101], in <cell line: 1>()
# ----> 1 find_out_the_rows_difference_between_datasets(TORX_df_concat)
#
# Input In [100], in find_out_the_rows_difference_between_datasets(df)
#      12 print('\n', '*'*20)
#      14 if year == '2022' and race == 'TOR330':
# ---> 15     print(TORX_itra_no_DNF[(TORX_itra_no_DNF['Race'] == race) &
#      16                           TORX_itra_no_DNF['Year'] == year].groupby(['Status'])['Status'].count())
#      17     print('\n', '*'*20)
#
# File ~\miniconda3\lib\site-packages\pandas\core\ops\common.py:70, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      66             return NotImplemented
#      68 other = item_from_zerodim(other)
# ---> 70 return method(self, other)
#
# File ~\miniconda3\lib\site-packages\pandas\core\arraylike.py:70, in OpsMixin.__and__(self, other)
#      68 @unpack_zerodim_and_defer("__and__")
#      69 def __and__(self, other):
# ---> 70     return self._logical_method(other, operator.and_)
#
# File ~\miniconda3\lib\site-packages\pandas\core\series.py:5634, in Series._logical_method(self, other, op)
#    5631 lvalues = self._values
#    5632 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# -> 5634 res_values = ops.logical_op(lvalues, rvalues, op)
#    5635 return self._construct_result(res_values, name=res_name)
#
# File ~\miniconda3\lib\site-packages\pandas\core\ops\array_ops.py:376, in logical_op(left, right, op)
#     372 rvalues = right
#     374 if should_extension_dispatch(lvalues, rvalues):
#     375     # Call the method on lvalues
# --> 376     res_values = op(lvalues, rvalues)
#     378 else:
#     379     if isinstance(rvalues, np.ndarray):
#
# File ~\miniconda3\lib\site-packages\pandas\core\arrays\numpy_.py:158, in PandasArray.__array_ufunc__(self, ufunc, method, *inputs, **kwargs)
#     154 if out:
#     155     kwargs["out"] = tuple(
#     156         x._ndarray if isinstance(x, PandasArray) else x for x in out
#     157     )
# --> 158 result = getattr(ufunc, method)(*inputs, **kwargs)
#     160 if ufunc.nout > 1:
#     161     # multiple return values; re-box array-like results
#     162     return tuple(type(self)(x) for x in result)
#
# TypeError: unsupported operand type(s) for &: 'bool' and 'str'

# %% [markdown]
# ### Exploring whether RITIRIO is the same as FALSE

# %%
retired_but_with_status_true = TOR330[(TOR330['Place'].str.contains('RITIRO')) &
       (TOR330['Status'] == True)]

list_of_names_retired_but_with_status_true  = list(retired_but_with_status_true['Name'].unique())

retired_but_with_status_true
# Out:
#                          Name   Bib Sex Nationality    Race  Year Category  \
# 21955         Mcdermott David   668   M          US  TOR330  2021       V3
# 63613          Verjee Sabrina    48   F          GB  TOR330  2023       V1
# 65921          Brumana Andrea    62   M          IT  TOR330  2023       V1
# 70807      Hartmuth Katharina   665   F          CH  TOR330  2023      SEN
# 72441          Smith Jonathan  1321   M          AU  TOR330  2023       V2
# 95929   Houteer Magni Justine   275   F          FR  TOR330  2023       V1
# 115123   Hutchinson  G Brian   1013   M          IE  TOR330  2024       V2
# 115815           Cagna Andrea  1547   M          IT  TOR330  2024       V1
#
#                                                  Place  \
# 21955   360 - Niel - La Gruba 330|199.7|17166 - RITIRO
# 63613                     290 - Donnas IN 330 - RITIRO
# 65921                    520 - Rif. Magià 330 - RITIRO
# 70807                     290 - Donnas IN 330 - RITIRO
# 72441                    291 - Donnas OUT 450 - RITIRO
# 95929                 381 - Gressoney OUT 330 - RITIRO
# 115123                       620 - Bosses 330 - RITIRO
# 115815                    201 - Cogne OUT 450 - RITIRO
#
#                              Time  Status
# 21955   2021-09-15T23:37:31+00:00    True
# 63613   2023-09-11T14:00:51+02:00    True
# 65921   2023-09-13T10:28:07+02:00    True
# 70807   2023-09-11T14:00:58+02:00    True
# 72441   2023-09-12T17:18:56+02:00    True
# 95929   2023-09-14T01:33:04+02:00    True
# 115123  2024-09-13T06:21:34+02:00    True
# 115815  2024-09-10T06:52:37+02:00    True

# %%
# How many have 'RITIRIO
TOR330[TOR330['Place'].str.contains('RITIRO')].shape
# Out:
# (437, 10)

# %%
# How many have not finished
len(list(TOR330['Name'][TOR330['Status'] == False].unique()))
# Out:
# 1628

# %% [markdown]
# ### Cleaning Place column

# %%
TOR330['Place'].unique()
# Out:
# array(['660 - FINISH 330|349.3|30879',
#        '650 - Mont de la Saxe 130|133.7|12388',
#        '630 - Rif. Frassati 130|118.9|11422',
#        '620 - Bosses 130|109.8|10210',
#        '610 - Ponteille Desot 330|308.9|28045',
#        '590 - Rif. Champillon 330|303.5|27681',
#        '581 - Ollomont OUT330|298.5|26602',
#        '580 - Ollomont 330 IN|298.5|26602',
#        '570 - Berio Damon 130|83.7|8089', '550 - Oyace 330|285.1|25038',
#        '540 - Biv. R. Clermont 130|63.6|6242',
#        '530 - Rif. Cuney 130|58.9|5762',
#        '520 - Rif. Magià 330|266.6|23540',
#        '490 - Rif. Barmasse 330|252.8|22390',
#        '481 - Valtournenche OUT 330|248.2|21547',
#        '480 - Valtournenche 130 IN|33.1|3247\\t',
#        '470 - Rif. Grand Tournalin 330|239.1|21172',
#        '460 - Champoluc 330|230.8|20019',
#        '450 - Rif. Alpenzu 130|3.6|526',
#        '381 - Gressoney 330 OUT|213.4|18300',
#        '380 - Gressoney 330 IN|213.4|18300', '370 - Loo|206|18063',
#        '360 - Niel - La Gruba 330|199.7|17166',
#        '350 - Col della Vecchia|193.3|16747',
#        '340 - Lago Chiaro|189|16226',
#        '330 - Rif. della Balm 450a|255|21628',
#        '320 - Rif. Coda 330|174.5|15024', '310 - Sassa|169.9|14143',
#        '300 - Perloz|162.2|12913', '291 - Donnas 330 OUT|156.3|12242',
#        '290 - Donnas 330 IN|156.3|12242', '260 - Pontboset|146.7|11637',
#        '250 - Chardonney|138.4|11406',
#        '240 - Rif. Dondena 330|132.9|11303', '225 - Sogno|125.2|10919',
#        '210 - Goilles|116.3|10074', '201 - Cogne 330 OUT|110.5|9616',
#        '200 - Cogne 330 IN|110.5|9616', '190 - Rif. Sella 450|142|11543',
#        '180 - Eaux Rousse|84.5|7537', '170 - Rhemes-Notre-Dame|68.6|5982',
#        '160 - Chalet Epee|60.5|5410', '151 - Valgrisenche OUT|54|4586',
#        '150 - Valgrisenche IN|54|4586', '130 - Promoud|37.8|3364',
#        '060 - Rif. Deffeyes 330|28.2|2937', '030 - La Thuile|18.7|1751',
#        '020 - Baite Youlaz|12|1524', '010 - START|0|0', '000',
#        '660 - FINISH - UHF', '640 - Pas Entre Deux Sauts 330|335.6|30486',
#        '010 - START330', '560 - Bruson Arp 330|290.2|26057',
#        '510 - Vareton 330|257.9|22911', '140 - Planaval|48.2|4307', '010',
#        '010 - START - MANUAL',
#        '360 - Niel - La Gruba 330|199.7|17166 - RITIRO',
#        '150 - Valgrisenche IN|54|4586 - RITIRO',
#        '610 - Ponteille Desot 330|308.9|28045 - RITIRO',
#        '581 - Ollomont OUT330|298.5|26602 - RITIRO',
#        '480 - Valtournenche 130 IN|33.1|3247\\t - RITIRO',
#        '460 - Champoluc 330|230.8|20019 - RITIRO',
#        '400 - Rif. Ferraro|314|26622',
#        '381 - Gressoney 330 OUT|213.4|18300 - RITIRO',
#        '310 - Sassa|169.9|14143 - RITIRO',
#        '330 - Rif. della Balm 450a|255|21628 - RITIRO',
#        '290 - Donnas 330 IN|156.3|12242 - RITIRO',
#        '260 - Pontboset|146.7|11637 - RITIRO',
#        '250 - Chardonney|138.4|11406 - RITIRO',
#        '201 - Cogne 330 OUT|110.5|9616 - RITIRO',
#        '200 - Cogne 330 IN|110.5|9616 - RITIRO',
#        '190 - Rif. Sella 450|142|11543 - RITIRO',
#        '140 - Planaval|48.2|4307 - RITIRO',
#        '151 - Valgrisenche OUT|54|4586 - RITIRO',
#        '650 - Mont de la Saxe 330|344.5|30828',
#        '630 - Rif. Frassati 330|329.7|29862',
#        '620 - Bosses 330|320.6|28650',
#        '540 - Biv. R. Clermont 330|274.4|24682', '530 - Rif. Cuney 130',
#        '480 - Valtournenche 130 IN', '470 - Rif. Grand Tournalin 130',
#        '450 - Rif. Alpenzu 330|218.7|18826',
#        '330 - Rif. della Barma 330|183.2|15676',
#        '290 - Donnas 450 IN|226|17774', '010 - START', '660 - FINISH|UHF',
#        '540 - Biv. R. Clermont 130',
#        '490 - Rif. Barmasse 330|252.8|22390 - RITIRO',
#        '620 - Bosses 330|320.6|28650 - RITIRO',
#        '580 - Ollomont 330 IN|298.5|26602 - RITIRO',
#        '540 - Biv. R. Clermont 330|274.4|24682 - RITIRO',
#        '481 - Valtournenche OUT 330|248.2|21547 - RITIRO',
#        '450 - Rif. Alpenzu 330|218.7|18826 - RITIRO',
#        '291 - Donnas 330 OUT|156.3|12242 - RITIRO',
#        '300 - Perloz|162.2|12913 - RITIRO',
#        '240 - Rif. Dondena 330|132.9|11303 - RITIRO',
#        '010 - START - RITIRO', '180 - Eaux Rousse|84.5|7537 - RITIRO',
#        '170 - Rhemes-Notre-Dame|68.6|5982 - RITIRO', '660 - FINISH 330',
#        '650 - Monte de la Saxe 450', '640 - Pas Entre Deux Sauts 450',
#        '630 - Rif. Frassati 450', '620 - Bosses 330',
#        '610 - Ponteille Desot 450', '590 - Rif. Champillon 450',
#        '581 - Ollomont OUT 330', '580 - Ollomont IN 330',
#        '570 - Berio Damon 330', '565 - Col Brison 330',
#        '551 - Oyace OUT 330', '550 - Oyace IN 330',
#        '540 - Biv. R. Clermont 330', '530 - Rif. Cuney 330',
#        '520 - Rif. Magià 330', '490 - Rif. Barmasse 330',
#        '481 - Valtournenche OUT 330', '480 - Valtournenche IN 330',
#        '470 - Rif. Grand Tournalin 330', '460 - Champoluc 330',
#        '450 - Rif. Alpenzu 330', '381 - Gressoney OUT 330',
#        '380 - Gressoney IN 330', '370 - Loo', '360 - Niel La Gruba 450',
#        '350 - Col della Vecchia', '340 - Lago Chiaro',
#        '330 - Rif. della Barma 450', '320 - Rif. Coda 450', '310 - Sassa',
#        '300 - Perloz', '291 - Donnas OUT 450', '290 - Donnas IN 330',
#        '260 - Pontboset', '250 - Chardonney', '240 - Rif. Dondena 450',
#        '210 - Goilles', '201 - Cogne OUT 330', '200 - Cogne IN 330',
#        '190 - Rif. Sella 450', '180 - Eaux Rousse',
#        '170 - Rhemes-Notre-Dame', '160 - Chalet Epee',
#        '151 - Valgrisenche OUT', '150 - Valgrisenche IN',
#        '140 - Planaval', '130 - Biv. Zappelli', '060 - Rif. Deffeyes 450',
#        '030 - La Thuile', '020 - Baite Youlaz', '000 - PETTORALI',
#        '655 - Parco Bollino|UHF', '290 - Donnas IN 330 - RITIRO',
#        '560 - Bruson Arp 330', '510 - Vareton 330',
#        '520 - Rif. Magià 330 - RITIRO', '291 - Donnas OUT 450 - RITIRO',
#        '650 - Mont de la Saxe 330', '381 - Gressoney OUT 330 - RITIRO',
#        '581 - Ollomont OUT 330 - RITIRO',
#        '580 - Ollomont IN 330 - RITIRO', '340 - Lago Chiaro - RITIRO',
#        '550 - Oyace IN 330 - RITIRO',
#        '481 - Valtournenche OUT 330 - RITIRO',
#        '460 - Champoluc 330 - RITIRO', '310 - Sassa - RITIRO',
#        '330 - Rif. della Barma 450 - RITIRO', '230 - Rif. Miserin',
#        '380 - Gressoney IN 330 - RITIRO',
#        '360 - Niel La Gruba 450 - RITIRO',
#        '350 - Col della Vecchia - RITIRO', '250 - Chardonney - RITIRO',
#        '151 - Valgrisenche OUT - RITIRO',
#        '240 - Rif. Dondena 450 - RITIRO', '210 - Goilles - RITIRO',
#        '201 - Cogne OUT 330 - RITIRO', '200 - Cogne IN 330 - RITIRO',
#        '190 - Rif. Sella 450 - RITIRO', '180 - Eaux Rousse - RITIRO',
#        '170 - Rhemes-Notre-Dame - RITIRO', '160 - Chalet Epee - RITIRO',
#        '150 - Valgrisenche IN - RITIRO', '030 - La Thuile - RITIRO',
#        '020 - Baite Youlaz - RITIRO', '560 - Bruson Arp 130',
#        '381 - Gressoney OUT 450', '380 - Gressoney IN 450',
#        '320 - Rif. Coda 330', '290 - Donnas IN 450',
#        '201 - Cogne OUT 450', '200 - Cogne IN 450', '551 - Oyace OUT 130',
#        '010 - START|UHF', '620 - Bosses 330 - RITIRO',
#        '201 - Cogne OUT 450 - RITIRO', '650 - Mont de la Saxe 30',
#        '590 - Rif. Champillon 450 - RITIRO',
#        '381 - Gressoney OUT 450 - RITIRO', '290 - Donnas IN 450 - RITIRO',
#        '260 - Pontboset - RITIRO', '200 - Cogne IN 450 - RITIRO',
#        '140 - Planaval - RITIRO'], dtype=object)

# %%
TOR330['aid_stations'] = TOR330['Place'].str.split(r'^\d+ - ').str.get(-1)

TOR330['aid_stations'] = TOR330['aid_stations'].str.replace(r'\d+', '', regex=True)
TOR330['aid_stations'] = TOR330['aid_stations'].str.split('|').str.get(0)
TOR330['aid_stations'] = TOR330['aid_stations'].str.replace('Rif.', 'Rifugio')
TOR330['aid_stations'] = TOR330['aid_stations'].str.replace('Biv.','Bivacco')
TOR330['aid_stations'] = TOR330['aid_stations'].str.strip()

TOR330['RITIRIO'] = np.where(
    TOR330['aid_stations'].str.contains('RITIRO', na=False), 
    TOR330['aid_stations'],  '')
# TOR330['RITIRIO] =TOR330['RITIRIO].str.replace('- RITIRO', '')
TOR330['aid_stations'] = TOR330['aid_stations'].str.split(' - RITIRO').str.get(0)
TOR330['aid_stations'].unique()
# Out:
# C:\Users\Karina\AppData\Local\Temp\ipykernel_3092\3056331615.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   TOR330['aid_stations'] = TOR330['aid_stations'].str.replace('Rif.', 'Rifugio')
# C:\Users\Karina\AppData\Local\Temp\ipykernel_3092\3056331615.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   TOR330['aid_stations'] = TOR330['aid_stations'].str.replace('Biv.','Bivacco')
# array(['FINISH', 'Mont de la Saxe', 'Rifugio Frassati', 'Bosses',
#        'Ponteille Desot', 'Rifugio Champillon', 'Ollomont OUT',
#        'Ollomont  IN', 'Berio Damon', 'Oyace', 'Bivacco R. Clermont',
#        'Rifugio Cuney', 'Rifugio Magià', 'Rifugio Barmasse',
#        'Valtournenche OUT', 'Valtournenche  IN',
#        'Rifugio Grand Tournalin', 'Champoluc', 'Rifugio Alpenzu',
#        'Gressoney  OUT', 'Gressoney  IN', 'Loo', 'Niel - La Gruba',
#        'Col della Vecchia', 'Lago Chiaro', 'Rifugio della Balm a',
#        'Rifugio Coda', 'Sassa', 'Perloz', 'Donnas  OUT', 'Donnas  IN',
#        'Pontboset', 'Chardonney', 'Rifugio Dondena', 'Sogno', 'Goilles',
#        'Cogne  OUT', 'Cogne  IN', 'Rifugio Sella', 'Eaux Rousse',
#        'Rhemes-Notre-Dame', 'Chalet Epee', 'Valgrisenche OUT',
#        'Valgrisenche IN', 'Promoud', 'Rifugio Deffeyes', 'La Thuile',
#        'Baite Youlaz', 'START', '', 'FINISH - UHF',
#        'Pas Entre Deux Sauts', 'Bruson Arp', 'Vareton', 'Planaval',
#        'START - MANUAL', 'Rifugio Ferraro', 'Rifugio della Barma',
#        'Monte de la Saxe', 'Ollomont IN', 'Col Brison', 'Oyace OUT',
#        'Oyace IN', 'Valtournenche IN', 'Gressoney OUT', 'Gressoney IN',
#        'Niel La Gruba', 'Donnas OUT', 'Donnas IN', 'Cogne OUT',
#        'Cogne IN', 'Bivacco Zappelli', 'PETTORALI', 'Parco Bollino',
#        'Donnas IN ', 'Rifugio Magià ', 'Donnas OUT ', 'Gressoney OUT ',
#        'Ollomont OUT ', 'Ollomont IN ', 'Oyace IN ', 'Valtournenche OUT ',
#        'Champoluc ', 'Rifugio della Barma ', 'Rifugio Miserin',
#        'Gressoney IN ', 'Niel La Gruba ', 'Rifugio Dondena ',
#        'Cogne OUT ', 'Cogne IN ', 'Rifugio Sella ', 'Bosses ',
#        'Rifugio Champillon '], dtype=object)

# %%
# dropping rows with PETTORALI
TOR330 = TOR330[~(TOR330['Place'].str.contains('PETTORALI'))].reset_index(drop=True)

# %%
TOR330[~(TOR330['RITIRIO'] == '')].head()
# Out:
#                    Name   Bib Sex Nationality    Race  Year Category  \
# 62071  Antonelli Davide   149   M          IT  TOR330  2022      SEN
# 62088     Begnis Andrea    66   M          IT  TOR330  2022      SEN
# 63478        Galea Eric  1228   M          FR  TOR330  2022       V2
# 63484     Hinman Martin  1345   M          GB  TOR330  2022       V1
# 63611    Verjee Sabrina    48   F          GB  TOR330  2023       V1
#
#                               Place                       Time  Status  \
# 62071          010 - START - RITIRO  2022-09-15T16:26:11+00:00   False
# 62088          010 - START - RITIRO  2022-09-15T16:26:04+00:00   False
# 63478          010 - START - RITIRO  2022-09-15T16:25:06+00:00   False
# 63484          010 - START - RITIRO  2022-09-15T16:24:56+00:00   False
# 63611  290 - Donnas IN 330 - RITIRO  2023-09-11T14:00:51+02:00    True
#
#       aid_stations              RITIRIO
# 62071        START       START - RITIRO
# 62088        START       START - RITIRO
# 63478        START       START - RITIRO
# 63484        START       START - RITIRO
# 63611   Donnas IN   Donnas IN  - RITIRO

# %%
TOR330['RITIRIO'].unique()
# Out:
# array(['', 'START - RITIRO', 'Donnas IN  - RITIRO',
#        'Rifugio Magià  - RITIRO', 'Donnas OUT  - RITIRO',
#        'Gressoney OUT  - RITIRO', 'Ollomont OUT  - RITIRO',
#        'Ollomont IN  - RITIRO', 'Lago Chiaro - RITIRO',
#        'Oyace IN  - RITIRO', 'Valtournenche OUT  - RITIRO',
#        'Champoluc  - RITIRO', 'Sassa - RITIRO',
#        'Rifugio della Barma  - RITIRO', 'Gressoney IN  - RITIRO',
#        'Niel La Gruba  - RITIRO', 'Col della Vecchia - RITIRO',
#        'Chardonney - RITIRO', 'Valgrisenche OUT - RITIRO',
#        'Rifugio Dondena  - RITIRO', 'Goilles - RITIRO',
#        'Cogne OUT  - RITIRO', 'Cogne IN  - RITIRO',
#        'Rifugio Sella  - RITIRO', 'Eaux Rousse - RITIRO',
#        'Rhemes-Notre-Dame - RITIRO', 'Chalet Epee - RITIRO',
#        'Valgrisenche IN - RITIRO', 'La Thuile - RITIRO',
#        'Baite Youlaz - RITIRO', 'Bosses  - RITIRO',
#        'Rifugio Champillon  - RITIRO', 'Pontboset - RITIRO',
#        'Planaval - RITIRO'], dtype=object)

# %% [markdown]
# ### Reading in TORX dates extracted from DUV

# %%
file = f'Database Data/TORX_duv_dates_df.xlsx'
dates_duv_df = pd.read_excel(file)

# Drop the intermediate columns if they're no longer needed
dates_duv_df = dates_duv_df.drop(columns=['Day_of_Week Start_Date'])    
dates_duv_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Race        26 non-null     object
#  1   Year        26 non-null     int64
#  2   Start Date  26 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 752.0+ bytes

# %% [markdown]
# ### Cleaning Time column
#
# Column '2024-09-11T07:08:32+02:00' needs to be fixed into '2024-09-11 07:08:32' and turned into the datetime
#
# ![image.png](attachment:image.png)

# %%
# 2024-09-11T07:08:32+02:00

# Split the 'Time' column to remove the timezone offset
TOR330['new_Time'] = TOR330['Time'].str.split('+').str[0]

# Convert the cleaned time string to a datetime object
TOR330['new_Time'] = pd.to_datetime(TOR330['new_Time'])

# # Add the 2-hour offset using timedelta
# # NO NEED!!!
# TOR330['new_Time'] = TOR330['new_Time'] + pd.to_timedelta('02:00:00')

# Preview the DataFrame
TOR330.head()
# Out:
#            Name  Bib Sex Nationality    Race  Year Category  \
# 0  Colle Franco    1   M          IT  TOR330  2021       V1
# 1  Colle Franco    1   M          IT  TOR330  2021       V1
# 2  Colle Franco    1   M          IT  TOR330  2021       V1
# 3  Colle Franco    1   M          IT  TOR330  2021       V1
# 4  Colle Franco    1   M          IT  TOR330  2021       V1
#
#                                    Place                       Time  Status  \
# 0           660 - FINISH 330|349.3|30879  2021-09-15T04:43:57+00:00    True
# 1  650 - Mont de la Saxe 130|133.7|12388  2021-09-15T04:04:48+00:00    True
# 2    630 - Rif. Frassati 130|118.9|11422  2021-09-15T01:19:06+00:00    True
# 3           620 - Bosses 130|109.8|10210  2021-09-14T23:19:05+00:00    True
# 4  610 - Ponteille Desot 330|308.9|28045  2021-09-14T21:59:00+00:00    True
#
#        aid_stations RITIRIO            new_Time
# 0            FINISH         2021-09-15 04:43:57
# 1   Mont de la Saxe         2021-09-15 04:04:48
# 2  Rifugio Frassati         2021-09-15 01:19:06
# 3            Bosses         2021-09-14 23:19:05
# 4   Ponteille Desot         2021-09-14 21:59:00

# %% [markdown]
# ### PIVOTING the Dataset

# %%
# Pivot the data so that each participant has its own column
pivoted_TOR330 = TOR330.pivot_table(
    index=['Name','Bib', 'Sex', 
           'Nationality', 'Category', 'Race','Year', 'Status'# , 'RITIRIO'
          ],
    columns='aid_stations',  
    values='new_Time',
    aggfunc='first'  # Ensures only the first match is kept in case of duplicates
).reset_index()

pivoted_TOR330.head()
# Out:
# aid_stations                Name   Bib Sex Nationality Category    Race  Year  \
# 0                   Aakre Eivind  1325   M          NO       V2  TOR330  2022
# 1             Abbet Jean-Maurice   781   M          CH       V2  TOR330  2021
# 2                 Abbet Valentin   311   M          CH      SEN  TOR330  2021
# 3                    Abe Hiroshi   374   M          JP       V1  TOR330  2024
# 4                    Abe Takashi   443   M          JP       V1  TOR330  2023
#
# aid_stations  Status                            Baite Youlaz  ...  \
# 0              False                 NaT 2022-09-11 15:12:45  ...
# 1               True 2021-09-11 17:37:28 2021-09-12 15:01:48  ...
# 2               True 2021-09-11 17:38:10 2021-09-12 12:40:48  ...
# 3              False                 NaT 2024-09-08 13:03:31  ...
# 4               True                 NaT 2023-09-10 12:32:30  ...
#
# aid_stations START - MANUAL               Sassa               Sogno  \
# 0                       NaT                 NaT                 NaT
# 1                       NaT 2021-09-14 22:44:39 2021-09-14 04:59:48
# 2                       NaT 2021-09-14 22:44:58 2021-09-14 04:59:31
# 3                       NaT 2024-09-11 04:02:41                 NaT
# 4                       NaT 2023-09-12 20:07:44                 NaT
#
# aid_stations     Valgrisenche IN    Valgrisenche OUT   Valtournenche  IN  \
# 0            2022-09-12 02:43:23 2022-09-12 04:12:59                 NaT
# 1            2021-09-13 01:02:43 2021-09-13 03:15:58 2021-09-16 10:33:15
# 2            2021-09-12 22:30:51 2021-09-13 03:16:03 2021-09-16 10:33:25
# 3            2024-09-09 00:43:19 2024-09-09 04:15:35                 NaT
# 4            2023-09-10 22:29:16 2023-09-11 01:27:00                 NaT
#
# aid_stations    Valtournenche IN   Valtournenche OUT Valtournenche OUT   \
# 0                            NaT                 NaT                NaT
# 1                            NaT 2021-09-16 15:56:41                NaT
# 2                            NaT 2021-09-16 15:56:56                NaT
# 3                            NaT                 NaT                NaT
# 4            2023-09-14 11:20:43 2023-09-14 16:38:25                NaT
#
# aid_stations             Vareton
# 0                            NaT
# 1            2021-09-16 19:30:08
# 2            2021-09-16 19:29:51
# 3                            NaT
# 4            2023-09-14 19:55:33
#
# [5 rows x 100 columns]

# %%
find_out_the_rows_difference_between_datasets(pivoted_TOR330)
# Out:
#  -  TOR330 2021
# ITRA rows:  431
# DUV rows:  431
# TOR330 rows:  432
#
#  ********************
#  -  TOR330 2022
# ITRA rows:  590
# DUV rows:  408
# TOR330 rows:  408
#
#  ********************
# Status
# Finished                        5692
# Finished at Bosses                81
# Finished at Rifugio Frassati     101
# Name: Status, dtype: int64
#
#  ********************
#  -  TOR330 2023
# ITRA rows:  621
# DUV rows:  621
# TOR330 rows:  630
#
#  ********************
#  -  TOR330 2024
# ITRA rows:  533
# DUV rows:  533
# TOR330 rows:  535
#
#  ********************

# %% [markdown]
# ### RITIRIO
# Issues with retired because there are both blanks and ' - Ritirio' for each person

# %%
ritirio_df = TOR330[~(TOR330['RITIRIO'] == '')]
# Merge the datsets back after pivoting
pivoted_TOR330 = pivoted_TOR330.merge(
    ritirio_df[['Bib', 'RITIRIO']].drop_duplicates(),  # Ensure no duplicates in 'Bib' and 'RITIRIO'
    on='Bib',
    how='left'
)

# reordering columns 
pivoted_TOR330 = pivoted_TOR330[[
'Name', 'Bib', 'Sex', 'Nationality', 'Year', 'Race','Category', 'Status', 'RITIRIO',  
'START', 'Baite Youlaz', 'La Thuile', 'Rifugio Deffeyes', 'Bivacco Zappelli',
    'Planaval', 'Valgrisenche IN', 'Valgrisenche OUT', 'Chalet Epee', 'Rhemes-Notre-Dame',
    'Eaux Rousse', 'Rifugio Sella', 'Cogne IN', 'Cogne OUT', 'Goilles', 'Rifugio Dondena', 
    'Chardonney', 'Pontboset', 'Donnas IN', 'Donnas OUT', 'Perloz', 'Sassa', 'Rifugio Coda',
    'Rifugio della Barma', 'Lago Chiaro', 'Col della Vecchia', 'Niel La Gruba', 'Loo',
    'Gressoney IN', 'Gressoney OUT', 'Rifugio Alpenzu', 'Champoluc', 'Rifugio Grand Tournalin', 
    'Valtournenche IN', 'Valtournenche OUT', 'Rifugio Barmasse', 'Vareton',
    'Rifugio Magià', 'Rifugio Cuney', 'Bivacco R. Clermont', 
    'Oyace IN', 'Bruson Arp', 'Col Brison', 'Berio Damon', 'Ollomont IN', 
    'Ollomont OUT', 'Rifugio Champillon', 'Ponteille Desot', 'Bosses', 'Rifugio Frassati', 
    'Pas Entre Deux Sauts', 'Monte de la Saxe', 'FINISH']]

pivoted_TOR330.head()
# Out:
#                  Name   Bib Sex Nationality  Year    Race Category  Status  \
# 0         Abe Takashi   443   M          JP  2023  TOR330       V1    True
# 1         Acerbi Luca  1290   M          IT  2023  TOR330       V3   False
# 2  Adamczyk Guillaume  1215   M          BE  2023  TOR330       V2   False
# 3        Affre Roxane  1320   F          FR  2023  TOR330       V2   False
# 4  Agnoletti Maurizio   311   M          IT  2023  TOR330       V3    True
#
#   RITIRIO               START  ...         Berio Damon         Ollomont IN  \
# 0     NaN                 NaT  ... 2023-09-15 12:13:32 2023-09-15 12:44:26
# 1     NaN 2023-09-10 11:22:44  ...                 NaT                 NaT
# 2     NaN 2023-09-10 11:50:58  ...                 NaT                 NaT
# 3     NaN 2023-09-10 11:19:55  ...                 NaT                 NaT
# 4     NaN 2023-09-10 09:36:43  ... 2023-09-15 13:52:37 2023-09-15 14:19:47
#
#          Ollomont OUT  Rifugio Champillon     Ponteille Desot  \
# 0 2023-09-15 15:41:40 2023-09-15 17:27:29 2023-09-15 19:31:31
# 1                 NaT                 NaT                 NaT
# 2                 NaT                 NaT                 NaT
# 3                 NaT                 NaT                 NaT
# 4 2023-09-15 16:25:03 2023-09-15 19:11:02 2023-09-15 22:15:24
#
#                Bosses    Rifugio Frassati Pas Entre Deux Sauts  \
# 0 2023-09-15 21:56:14 2023-09-16 02:00:21  2023-09-16 06:08:26
# 1                 NaT                 NaT                  NaT
# 2                 NaT                 NaT                  NaT
# 3                 NaT                 NaT                  NaT
# 4 2023-09-16 01:31:20 2023-09-16 05:53:46  2023-09-16 09:22:14
#
#      Monte de la Saxe              FINISH
# 0 2023-09-16 08:39:35 2023-09-16 10:15:52
# 1                 NaT                 NaT
# 2                 NaT                 NaT
# 3                 NaT                 NaT
# 4 2023-09-16 11:18:39 2023-09-16 12:16:45
#
# [5 rows x 62 columns]

# %% [markdown]
# ### Dealing with Anomalies

# %%
# #### FOund these because I creaated a dataset based on Finishers only 
# other_DNFs = pivoted_TOR330_dates_noDNF[(pivoted_TOR330_dates_noDNF['Rifugio Frassati'].isna()) &
#                            (pivoted_TOR330_dates_noDNF['Pas Entre Deux Sauts'].isna())
#                            &
#                            (pivoted_TOR330_dates_noDNF['Monte de la Saxe'].isna())]

# DNFs_names_list = other_DNFs['Name'].unique()

# DNFs_names_list =['Peron Bastien', 'Yang Victor', 'Tang Yuen Ying ', 'Yoshida Shuhei']

# %%
# Issues with 2024 
TOR330[(TOR330['Status'] == True) |
        (TOR330['Place'].str.contains('RITIRIO'))
                                     ]
# Out:
#                Name  Bib Sex Nationality    Race  Year Category  \
# 0      Colle Franco    2   M          IT  TOR330  2023       V1
# 1      Colle Franco    2   M          IT  TOR330  2023       V1
# 2      Colle Franco    2   M          IT  TOR330  2023       V1
# 3      Colle Franco    2   M          IT  TOR330  2023       V1
# 4      Colle Franco    2   M          IT  TOR330  2023       V1
# ...             ...  ...  ..         ...     ...   ...      ...
# 33086  Tibaldi Erik  533   M          IT  TOR330  2023       V1
# 33087  Tibaldi Erik  533   M          IT  TOR330  2023       V1
# 33088  Tibaldi Erik  533   M          IT  TOR330  2023       V1
# 33089  Tibaldi Erik  533   M          IT  TOR330  2023       V1
# 33090  Tibaldi Erik  533   M          IT  TOR330  2023       V1
#
#                                 Place                       Time  Status  \
# 0                    660 - FINISH 330  2023-09-13T04:39:16+02:00    True
# 1          650 - Monte de la Saxe 450  2023-09-13T03:52:25+02:00    True
# 2      640 - Pas Entre Deux Sauts 450  2023-09-13T02:23:36+02:00    True
# 3             630 - Rif. Frassati 450  2023-09-13T00:45:25+02:00    True
# 4                    620 - Bosses 330  2023-09-12T22:30:41+02:00    True
# ...                               ...                        ...     ...
# 33086             130 - Biv. Zappelli  2023-09-10T18:23:00+02:00    True
# 33087         060 - Rif. Deffeyes 450  2023-09-10T16:35:37+02:00    True
# 33088                 030 - La Thuile  2023-09-10T13:53:01+02:00    True
# 33089              020 - Baite Youlaz  2023-09-10T12:57:14+02:00    True
# 33090                     010 - START  2023-09-10T09:30:01+02:00    True
#
#                aid_stations RITIRIO            new_Time
# 0                    FINISH         2023-09-13 04:39:16
# 1          Monte de la Saxe         2023-09-13 03:52:25
# 2      Pas Entre Deux Sauts         2023-09-13 02:23:36
# 3          Rifugio Frassati         2023-09-13 00:45:25
# 4                    Bosses         2023-09-12 22:30:41
# ...                     ...     ...                 ...
# 33086      Bivacco Zappelli         2023-09-10 18:23:00
# 33087      Rifugio Deffeyes         2023-09-10 16:35:37
# 33088             La Thuile         2023-09-10 13:53:01
# 33089          Baite Youlaz         2023-09-10 12:57:14
# 33090                 START         2023-09-10 09:30:01
#
# [33091 rows x 13 columns]

# %%
# # Issues with 2024 
# TOR330[~(TOR330['Name'].str.contains('Hutchinson')) | # Hutchinson Brian G actually FINISHED the race
#         (TOR330['Name'].str.contains('Cagna'))
#                                      ]

# %%
# Issues with TOR330 2023
name_issues_2023 = ['Verjee Sabrina', 'Brumana Andrea',
             'Hartmuth Katharina', 'Smith Jonathan',
             'Houteer Magni Justine','Peron Bastien',
             'Yang Victor', 'Tang Yuen Ying ', 'Yoshida Shuhei']

pivoted_TOR330[pivoted_TOR330['Name'].isin(name_issues_2023)]
# Out:
#                        Name   Bib Sex Nationality  Year    Race Category  \
# 120          Brumana Andrea    62   M          IT  2023  TOR330       V1
# 430      Hartmuth Katharina   665   F          CH  2023  TOR330      SEN
# 453   Houteer Magni Justine   275   F          FR  2023  TOR330       V1
# 749           Peron Bastien   540   M          FR  2023  TOR330      SEN
# 921          Smith Jonathan  1321   M          AU  2023  TOR330       V2
# 966         Tang Yuen Ying   1105   F          HK  2023  TOR330      SEN
# 1031         Verjee Sabrina    48   F          GB  2023  TOR330       V1
# 1073            Yang Victor   493   M          US  2023  TOR330       V1
# 1075         Yoshida Shuhei  1143   M          JP  2023  TOR330       V2
#
#       Status                  RITIRIO               START  ... Berio Damon  \
# 120     True  Rifugio Magià  - RITIRO 2023-09-10 09:30:52  ...         NaT
# 430     True      Donnas IN  - RITIRO 2023-09-10 09:27:48  ...         NaT
# 453     True  Gressoney OUT  - RITIRO 2023-09-10 09:20:29  ...         NaT
# 749     True                      NaN 2023-09-10 09:32:59  ...         NaT
# 921     True     Donnas OUT  - RITIRO 2023-09-10 11:23:04  ...         NaT
# 966     True                      NaN 2023-09-10 11:52:42  ...         NaT
# 1031    True      Donnas IN  - RITIRO 2023-09-10 09:33:01  ...         NaT
# 1073    True                      NaN 2023-09-10 09:49:30  ...         NaT
# 1075    True                      NaN 2023-09-10 11:39:57  ...         NaT
#
#              Ollomont IN        Ollomont OUT  Rifugio Champillon  \
# 120  2023-09-13 20:45:04 2023-09-13 23:01:00 2023-09-14 00:58:41
# 430                  NaT                 NaT                 NaT
# 453                  NaT                 NaT                 NaT
# 749                  NaT                 NaT                 NaT
# 921                  NaT                 NaT                 NaT
# 966                  NaT                 NaT                 NaT
# 1031                 NaT                 NaT                 NaT
# 1073                 NaT                 NaT                 NaT
# 1075                 NaT                 NaT                 NaT
#
#          Ponteille Desot              Bosses    Rifugio Frassati  \
# 120  2023-09-14 02:54:49 2023-09-14 04:52:15 2023-09-14 08:08:35
# 430                  NaT                 NaT                 NaT
# 453                  NaT                 NaT                 NaT
# 749                  NaT                 NaT                 NaT
# 921                  NaT                 NaT                 NaT
# 966                  NaT                 NaT                 NaT
# 1031                 NaT                 NaT                 NaT
# 1073                 NaT                 NaT                 NaT
# 1075                 NaT                 NaT                 NaT
#
#      Pas Entre Deux Sauts    Monte de la Saxe              FINISH
# 120   2023-09-14 09:55:09 2023-09-14 11:41:55 2023-09-14 12:29:19
# 430                   NaT                 NaT 2023-09-15 08:58:31
# 453                   NaT                 NaT 2023-09-16 14:12:20
# 749                   NaT                 NaT 2023-09-13 20:12:12
# 921                   NaT                 NaT 2023-09-15 13:59:51
# 966                   NaT                 NaT 2023-09-14 17:35:33
# 1031                  NaT                 NaT 2023-09-13 05:38:22
# 1073                  NaT                 NaT 2023-09-14 00:08:44
# 1075                  NaT                 NaT 2023-09-16 17:07:25
#
# [9 rows x 62 columns]

# %%
# Issues with TOR330 2023
for name in ['Verjee Sabrina', 'Brumana Andrea',
             'Hartmuth Katharina', 'Smith Jonathan',
             'Houteer Magni Justine','Peron Bastien',
             'Yang Victor', 'Tang Yuen Ying ', 'Yoshida Shuhei']:

    # Fixing the code with .loc[] for proper assignment
    pivoted_TOR330.loc[pivoted_TOR330['Name'] == name, 'FINISH'] = pd.NaT
    pivoted_TOR330.loc[pivoted_TOR330['Name'] == name, 'Status'] = False
    
# find_out_the_rows_difference_between_datasets(pivoted_TOR330)
#### Now I have the same number of Finishers as DUV and ITRA!

# %% [markdown]
# ### Start Line Issues
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Adding dates into TOR330 and TOR4450

# %%
pivoted_TOR330['Year'] = pivoted_TOR330['Year'].astype('str')
dates_duv_df['Year'] = dates_duv_df['Year'].astype('str')

# have I dropped any rows?
print(pivoted_TOR330.shape)

# Merging on two columns: 'Race' and 'Year'
pivoted_TOR330_dates = pd.merge(pivoted_TOR330, dates_duv_df, on=['Race', 'Year'], how='inner')

# have I dropped any rows?
print(pivoted_TOR330_dates.shape)
# Out:
# (1097, 62)
# (1097, 63)

# %%
pivoted_TOR330_dates['new_Start Date'] = np.where(
    pivoted_TOR330_dates['Bib'] < 1001, 
        pivoted_TOR330_dates['Start Date'], 
        pivoted_TOR330_dates['Start Date'] + pd.to_timedelta('02:00:00'))

pivoted_TOR330_dates['Wave'] = np.where(
    pivoted_TOR330_dates['Bib'] < 1001, 
        'Wave1', 
        'Wave2')

pivoted_TOR330_dates[pivoted_TOR330_dates['Bib']> 1001].head()
# Out:
#                  Name   Bib Sex Nationality  Year    Race Category  Status  \
# 1         Acerbi Luca  1290   M          IT  2023  TOR330       V3   False
# 2  Adamczyk Guillaume  1215   M          BE  2023  TOR330       V2   False
# 3        Affre Roxane  1320   F          FR  2023  TOR330       V2   False
# 5  Agostini Giancarla  1146   F          IT  2023  TOR330       V1    True
# 6       Akimoto Kenji  1161   M          JP  2023  TOR330       V3   False
#
#   RITIRIO               START  ...  Rifugio Champillon     Ponteille Desot  \
# 1     NaN 2023-09-10 11:22:44  ...                 NaT                 NaT
# 2     NaN 2023-09-10 11:50:58  ...                 NaT                 NaT
# 3     NaN 2023-09-10 11:19:55  ...                 NaT                 NaT
# 5     NaN 2023-09-10 11:26:06  ... 2023-09-15 14:03:37 2023-09-15 16:14:59
# 6     NaN 2023-09-10 11:39:53  ...                 NaT                 NaT
#
#                Bosses    Rifugio Frassati Pas Entre Deux Sauts  \
# 1                 NaT                 NaT                  NaT
# 2                 NaT                 NaT                  NaT
# 3                 NaT                 NaT                  NaT
# 5 2023-09-15 18:32:12 2023-09-15 22:05:20  2023-09-16 00:46:37
# 6                 NaT                 NaT                  NaT
#
#      Monte de la Saxe              FINISH          Start Date  \
# 1                 NaT                 NaT 2023-09-10 10:00:00
# 2                 NaT                 NaT 2023-09-10 10:00:00
# 3                 NaT                 NaT 2023-09-10 10:00:00
# 5 2023-09-16 03:13:12 2023-09-16 04:41:04 2023-09-10 10:00:00
# 6                 NaT                 NaT 2023-09-10 10:00:00
#
#        new_Start Date   Wave
# 1 2023-09-10 12:00:00  Wave2
# 2 2023-09-10 12:00:00  Wave2
# 3 2023-09-10 12:00:00  Wave2
# 5 2023-09-10 12:00:00  Wave2
# 6 2023-09-10 12:00:00  Wave2
#
# [5 rows x 65 columns]

# %%
# Calculate Duration
pivoted_TOR330_dates['Duration'] = pivoted_TOR330_dates['FINISH'] - pivoted_TOR330_dates['new_Start Date'] 

# Sort the DataFrame by the 'Duration' column
pivoted_TOR330_dates = pivoted_TOR330_dates.sort_values(by='Duration')

# %%
# Reorder the columns in the correct order
pivoted_TOR330_dates = pivoted_TOR330_dates[[
        'Name', 'Bib', 'Sex', 'Nationality', 'Year', 'Race', 'Category', 'Status','Wave', 'Duration','RITIRIO',
        'new_Start Date', 'Baite Youlaz', 'La Thuile', 'Rifugio Deffeyes',
        'Bivacco Zappelli', 'Planaval', 'Valgrisenche IN', 'Valgrisenche OUT',
        'Chalet Epee', 'Rhemes-Notre-Dame', 'Eaux Rousse', 'Rifugio Sella',
        'Cogne IN', 'Cogne OUT', 'Goilles', 'Rifugio Dondena', 'Chardonney',
        'Pontboset', 'Donnas IN', 'Donnas OUT', 'Perloz', 'Sassa',
        'Rifugio Coda', 'Rifugio della Barma', 'Lago Chiaro',
        'Col della Vecchia', 'Niel La Gruba', 'Loo', 'Gressoney IN',
        'Gressoney OUT', 'Rifugio Alpenzu', 'Champoluc',
        'Rifugio Grand Tournalin', 'Valtournenche IN', 'Valtournenche OUT',
        'Rifugio Barmasse', 'Vareton', 'Rifugio Magià', 'Rifugio Cuney',
        'Bivacco R. Clermont', 'Oyace IN', 'Bruson Arp', 'Col Brison',
        'Berio Damon', 'Ollomont IN', 'Ollomont OUT', 'Rifugio Champillon',
        'Ponteille Desot', 'Bosses', 'Rifugio Frassati', 'Pas Entre Deux Sauts',
        'Monte de la Saxe', 'FINISH'
]]

# %%
print(pivoted_TOR330_dates['Duration'][pivoted_TOR330_dates['Name'].str.contains('Jonina')])
print(TORX_duv_df['Performance'][TORX_duv_df['Name'].str.contains('Jonina')])
# Finished in 144:46:43 hours and
# Out:
# 486   6 days 00:46:43
# Name: Duration, dtype: timedelta64[ns]
# 5291    6.032442
# Name: Performance, dtype: float64

# %%
# Group by 'Status' and count occurrences in each group
status_counts = pivoted_TOR330_dates.groupby('Status')['Status'].count()

# Display the counts
print(status_counts)
# Out:
# Status
# False    476
# True     621
# Name: Status, dtype: int64

# %%
for i in pivoted_TOR330_dates.columns: 
    print(i, pivoted_TOR330_dates[i].isna().sum())
# Out:
# Name 0
# Bib 0
# Sex 0
# Nationality 0
# Year 0
# Race 0
# Category 0
# Status 0
# Wave 0
# Duration 476
# RITIRIO 962
# new_Start Date 0
# Baite Youlaz 6
# La Thuile 8
# Rifugio Deffeyes 20
# Bivacco Zappelli 27
# Planaval 37
# Valgrisenche IN 43
# Valgrisenche OUT 91
# Chalet Epee 141
# Rhemes-Notre-Dame 112
# Eaux Rousse 141
# Rifugio Sella 371
# Cogne IN 208
# Cogne OUT 281
# Goilles 233
# Rifugio Dondena 250
# Chardonney 241
# Pontboset 258
# Donnas IN 253
# Donnas OUT 269
# Perloz 264
# Sassa 277
# Rifugio Coda 280
# Rifugio della Barma 298
# Lago Chiaro 321
# Col della Vecchia 326
# Niel La Gruba 348
# Loo 368
# Gressoney IN 396
# Gressoney OUT 408
# Rifugio Alpenzu 415
# Champoluc 417
# Rifugio Grand Tournalin 429
# Valtournenche IN 426
# Valtournenche OUT 435
# Rifugio Barmasse 433
# Vareton 435
# Rifugio Magià 439
# Rifugio Cuney 446
# Bivacco R. Clermont 448
# Oyace IN 448
# Bruson Arp 465
# Col Brison 552
# Berio Damon 532
# Ollomont IN 470
# Ollomont OUT 482
# Rifugio Champillon 501
# Ponteille Desot 469
# Bosses 470
# Rifugio Frassati 476
# Pas Entre Deux Sauts 484
# Monte de la Saxe 504
# FINISH 476

# %% [markdown]
# ### Only Finishers

# %%
pivoted_TOR330_dates_noDNF = pivoted_TOR330_dates[(pivoted_TOR330_dates['Status'] == True) &
                    ~(pivoted_TOR330_dates['FINISH'].isna())].reset_index()


for i in pivoted_TOR330_dates_noDNF.columns: 
    print(i, pivoted_TOR330_dates_noDNF[i].isna().sum())
# Out:
# index 0
# Name 0
# Bib 0
# Sex 0
# Nationality 0
# Year 0
# Race 0
# Category 0
# Status 0
# Wave 0
# Duration 0
# RITIRIO 621
# new_Start Date 0
# Baite Youlaz 1
# La Thuile 1
# Rifugio Deffeyes 1
# Bivacco Zappelli 1
# Planaval 0
# Valgrisenche IN 0
# Valgrisenche OUT 1
# Chalet Epee 5
# Rhemes-Notre-Dame 2
# Eaux Rousse 0
# Rifugio Sella 148
# Cogne IN 3
# Cogne OUT 31
# Goilles 1
# Rifugio Dondena 7
# Chardonney 0
# Pontboset 7
# Donnas IN 4
# Donnas OUT 9
# Perloz 2
# Sassa 5
# Rifugio Coda 0
# Rifugio della Barma 2
# Lago Chiaro 8
# Col della Vecchia 4
# Niel La Gruba 1
# Loo 0
# Gressoney IN 0
# Gressoney OUT 3
# Rifugio Alpenzu 1
# Champoluc 1
# Rifugio Grand Tournalin 4
# Valtournenche IN 0
# Valtournenche OUT 5
# Rifugio Barmasse 2
# Vareton 3
# Rifugio Magià 2
# Rifugio Cuney 2
# Bivacco R. Clermont 0
# Oyace IN 0
# Bruson Arp 10
# Col Brison 86
# Berio Damon 62
# Ollomont IN 5
# Ollomont OUT 16
# Rifugio Champillon 32
# Ponteille Desot 2
# Bosses 0
# Rifugio Frassati 1
# Pas Entre Deux Sauts 9
# Monte de la Saxe 29
# FINISH 0

# %%
pivoted_TOR330_dates.groupby(['Wave', 'Status'])['Status'].size()
# Out:
# Wave   Status
# Wave1  False     194
#        True      407
# Wave2  False     282
#        True      214
# Name: Status, dtype: int64

# %%
# Plot the histogram
plt.figure(figsize=(10, 6))
plt.hist(pivoted_TOR330_dates['Bib'], bins=7, color='skyblue', edgecolor='black')
plt.title(f'Histogram of Bibs')
plt.xlabel('Hours')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### Cleaning DNFs

# %%
pivoted_TOR330_dates_DNF = pivoted_TOR330_dates[
                    # selecting all rows that DNFed
                    (pivoted_TOR330_dates['Status'] == False) & # AND
                    # selecting all rows where FINISH does not have a time
                    (pivoted_TOR330_dates['FINISH'].isna())]

pivoted_TOR330_dates_DNF.head()
# Out:
#                   Name   Bib Sex Nationality  Year    Race Category  Status  \
# 1          Acerbi Luca  1290   M          IT  2023  TOR330       V3   False
# 2   Adamczyk Guillaume  1215   M          BE  2023  TOR330       V2   False
# 3         Affre Roxane  1320   F          FR  2023  TOR330       V2   False
# 6        Akimoto Kenji  1161   M          JP  2023  TOR330       V3   False
# 10     Altmann Joachim   206   M          DE  2023  TOR330       V1   False
#
#      Wave Duration  ... Berio Damon Ollomont IN Ollomont OUT  \
# 1   Wave2      NaT  ...         NaT         NaT          NaT
# 2   Wave2      NaT  ...         NaT         NaT          NaT
# 3   Wave2      NaT  ...         NaT         NaT          NaT
# 6   Wave2      NaT  ...         NaT         NaT          NaT
# 10  Wave1      NaT  ...         NaT         NaT          NaT
#
#    Rifugio Champillon Ponteille Desot Bosses Rifugio Frassati  \
# 1                 NaT             NaT    NaT              NaT
# 2                 NaT             NaT    NaT              NaT
# 3                 NaT             NaT    NaT              NaT
# 6                 NaT             NaT    NaT              NaT
# 10                NaT             NaT    NaT              NaT
#
#    Pas Entre Deux Sauts Monte de la Saxe FINISH
# 1                   NaT              NaT    NaT
# 2                   NaT              NaT    NaT
# 3                   NaT              NaT    NaT
# 6                   NaT              NaT    NaT
# 10                  NaT              NaT    NaT
#
# [5 rows x 64 columns]

# %%
pivoted_TOR330_dates_DNF.isna().sum()
# Out:
# Name                      0
# Bib                       0
# Sex                       0
# Nationality               0
# Year                      0
#                        ...
# Bosses                  470
# Rifugio Frassati        475
# Pas Entre Deux Sauts    475
# Monte de la Saxe        475
# FINISH                  476
# Length: 64, dtype: int64

# %% [markdown]
# ### What is the last place of DNFs?

# %%
# Function to find the last non-blank column
def get_last_non_blank(row):
    for col in reversed(row.index):
        if pd.notna(row[col]):  # Check if the value is not NaN
#             print(col)
            return col
#     return None  # In case all columns are blank

# # Apply the function to each row and assign the result to 'Retired'
pivoted_TOR330_dates_DNF['Retired'] = pivoted_TOR330_dates_DNF.apply(get_last_non_blank, axis=1)
# Out:
# C:\Users\Karina\AppData\Local\Temp\ipykernel_3092\358637973.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pivoted_TOR330_dates_DNF['Retired'] = pivoted_TOR330_dates_DNF.apply(get_last_non_blank, axis=1)

# %%
pivoted_TOR330_dates_DNF.columns
# Out:
# Index(['Name', 'Bib', 'Sex', 'Nationality', 'Year', 'Race', 'Category',
#        'Status', 'Wave', 'Duration', 'RITIRIO', 'new_Start Date',
#        'Baite Youlaz', 'La Thuile', 'Rifugio Deffeyes', 'Bivacco Zappelli',
#        'Planaval', 'Valgrisenche IN', 'Valgrisenche OUT', 'Chalet Epee',
#        'Rhemes-Notre-Dame', 'Eaux Rousse', 'Rifugio Sella', 'Cogne IN',
#        'Cogne OUT', 'Goilles', 'Rifugio Dondena', 'Chardonney', 'Pontboset',
#        'Donnas IN', 'Donnas OUT', 'Perloz', 'Sassa', 'Rifugio Coda',
#        'Rifugio della Barma', 'Lago Chiaro', 'Col della Vecchia',
#        'Niel La Gruba', 'Loo', 'Gressoney IN', 'Gressoney OUT',
#        'Rifugio Alpenzu', 'Champoluc', 'Rifugio Grand Tournalin',
#        'Valtournenche IN', 'Valtournenche OUT', 'Rifugio Barmasse', 'Vareton',
#        'Rifugio Magià', 'Rifugio Cuney', 'Bivacco R. Clermont', 'Oyace IN',
#        'Bruson Arp', 'Col Brison', 'Berio Damon', 'Ollomont IN',
#        'Ollomont OUT', 'Rifugio Champillon', 'Ponteille Desot', 'Bosses',
#        'Rifugio Frassati', 'Pas Entre Deux Sauts', 'Monte de la Saxe',
#        'FINISH', 'Retired'],
#       dtype='object')

# %%
pivoted_TOR330_dates_DNF = pivoted_TOR330_dates_DNF[['Name', 'Bib', 'Sex', 'Nationality', 'Year', 'Race', 'Category',
       'Status', 'Wave', 'Duration', 'RITIRIO', 'Retired','new_Start Date',
       'Baite Youlaz', 'La Thuile', 'Rifugio Deffeyes', 'Bivacco Zappelli',
       'Planaval', 'Valgrisenche IN', 'Valgrisenche OUT', 'Chalet Epee',
       'Rhemes-Notre-Dame', 'Eaux Rousse', 'Rifugio Sella', 'Cogne IN',
       'Cogne OUT', 'Goilles', 'Rifugio Dondena', 'Chardonney', 'Pontboset',
       'Donnas IN', 'Donnas OUT', 'Perloz', 'Sassa', 'Rifugio Coda',
       'Rifugio della Barma', 'Lago Chiaro', 'Col della Vecchia',
       'Niel La Gruba', 'Loo', 'Gressoney IN', 'Gressoney OUT',
       'Rifugio Alpenzu', 'Champoluc', 'Rifugio Grand Tournalin',
       'Valtournenche IN', 'Valtournenche OUT', 'Rifugio Barmasse', 'Vareton',
       'Rifugio Magià', 'Rifugio Cuney', 'Bivacco R. Clermont', 'Oyace IN',
       'Bruson Arp', 'Col Brison', 'Berio Damon', 'Ollomont IN',
       'Ollomont OUT', 'Rifugio Champillon', 'Ponteille Desot', 'Bosses',
       'Rifugio Frassati', 'Pas Entre Deux Sauts', 'Monte de la Saxe',
       'FINISH']]

# pivoted_TOR330_dates_DNF.to_excel('retired_df.xlsx', index = False)

# %% [markdown]
# ### Cleaning Last location
#
# ![image-2.png](attachment:image-2.png)

# %%
names_that_DNFed_and_then_popped_up_miles_away =['Utinek Vaclav', 'Walsh Padraic',
                                                'Ferraris Maurizio', 'Buonocore Gian Mario',
                                                'Forestiero Alessandro', 'Forrest Steve',
                                                 'Koehling Sebastien'
                                                ]

# %%
pivot_DNF = pivoted_TOR330_dates_DNF.copy()

# Ensure you're modifying the original DataFrame directly
for index, row in pivot_DNF[pivot_DNF['Name'].isin(names_that_DNFed_and_then_popped_up_miles_away)].iterrows():
    retired_column = row['Retired']  # Get the column name in 'Retired'
    
    # Check if the 'Retired' value is a valid column in the specified list
    if retired_column in [
   'Rifugio Dondena', 'Gressoney IN', 'Gressoney OUT', 'Col Brison',  'Bruson Arp',
    ]:
        # Update the specific cell for the 'retired_column'
        pivot_DNF.at[index, retired_column] = pd.NaT

# Display the updated DataFrame
pivot_DNF[['Name',
   'Rifugio Dondena', 'Gressoney IN', 'Gressoney OUT', 'Col Brison',  'Bruson Arp',
       'Retired']][pivot_DNF['Name'].isin(names_that_DNFed_and_then_popped_up_miles_away)]
# Out:
#                        Name     Rifugio Dondena        Gressoney IN  \
# 129    Buonocore Gian Mario                 NaT                 NaT
# 323       Ferraris Maurizio 2023-09-12 12:41:59                 NaT
# 338   Forestiero Alessandro 2023-09-12 10:36:09 2023-09-13 22:51:31
# 341           Forrest Steve 2023-09-12 12:29:19                 NaT
# 509      Koehling Sebastien 2023-09-12 06:19:56                 NaT
# 1009          Utinek Vaclav                 NaT                 NaT
# 1051          Walsh Padraic 2023-09-12 10:33:12                 NaT
#
#            Gressoney OUT Col Brison Bruson Arp          Retired
# 129                  NaT        NaT        NaT       Bruson Arp
# 323                  NaT        NaT        NaT    Gressoney OUT
# 338  2023-09-14 02:45:31        NaT        NaT       Col Brison
# 341                  NaT        NaT        NaT     Gressoney IN
# 509                  NaT        NaT        NaT    Gressoney OUT
# 1009                 NaT        NaT        NaT  Rifugio Dondena
# 1051                 NaT        NaT        NaT       Bruson Arp

# %%
# Drop the intermediate columns if they're no longer needed
pivot_DNF = pivot_DNF.drop(columns=['Retired'])    

# Apply the function to each row and assign the result to 'Retired'
pivot_DNF['Retired'] = pivot_DNF.apply(get_last_non_blank, axis=1)

# %%
pivot_DNF.head()
# Out:
#                   Name   Bib Sex Nationality  Year    Race Category  Status  \
# 1          Acerbi Luca  1290   M          IT  2023  TOR330       V3   False
# 2   Adamczyk Guillaume  1215   M          BE  2023  TOR330       V2   False
# 3         Affre Roxane  1320   F          FR  2023  TOR330       V2   False
# 6        Akimoto Kenji  1161   M          JP  2023  TOR330       V3   False
# 10     Altmann Joachim   206   M          DE  2023  TOR330       V1   False
#
#      Wave Duration  ... Ollomont IN Ollomont OUT Rifugio Champillon  \
# 1   Wave2      NaT  ...         NaT          NaT                NaT
# 2   Wave2      NaT  ...         NaT          NaT                NaT
# 3   Wave2      NaT  ...         NaT          NaT                NaT
# 6   Wave2      NaT  ...         NaT          NaT                NaT
# 10  Wave1      NaT  ...         NaT          NaT                NaT
#
#    Ponteille Desot Bosses Rifugio Frassati Pas Entre Deux Sauts  \
# 1              NaT    NaT              NaT                  NaT
# 2              NaT    NaT              NaT                  NaT
# 3              NaT    NaT              NaT                  NaT
# 6              NaT    NaT              NaT                  NaT
# 10             NaT    NaT              NaT                  NaT
#
#    Monte de la Saxe FINISH              Retired
# 1               NaT    NaT      Valgrisenche IN
# 2               NaT    NaT      Valgrisenche IN
# 3               NaT    NaT      Valgrisenche IN
# 6               NaT    NaT  Rifugio della Barma
# 10              NaT    NaT        Rifugio Sella
#
# [5 rows x 65 columns]

# %%
# Display the updated DataFrame
pivot_DNF[['Name',
   'Rifugio Dondena', 'Gressoney IN', 'Gressoney OUT', 'Col Brison',  'Bruson Arp',
       'Retired']][pivot_DNF['Name'].isin(names_that_DNFed_and_then_popped_up_miles_away)]
# Out:
#                        Name     Rifugio Dondena        Gressoney IN  \
# 129    Buonocore Gian Mario                 NaT                 NaT
# 323       Ferraris Maurizio 2023-09-12 12:41:59                 NaT
# 338   Forestiero Alessandro 2023-09-12 10:36:09 2023-09-13 22:51:31
# 341           Forrest Steve 2023-09-12 12:29:19                 NaT
# 509      Koehling Sebastien 2023-09-12 06:19:56                 NaT
# 1009          Utinek Vaclav                 NaT                 NaT
# 1051          Walsh Padraic 2023-09-12 10:33:12                 NaT
#
#            Gressoney OUT Col Brison Bruson Arp           Retired
# 129                  NaT        NaT        NaT       Eaux Rousse
# 323                  NaT        NaT        NaT            Perloz
# 338  2023-09-14 02:45:31        NaT        NaT     Rifugio Magià
# 341                  NaT        NaT        NaT            Perloz
# 509                  NaT        NaT        NaT            Perloz
# 1009                 NaT        NaT        NaT  Valgrisenche OUT
# 1051                 NaT        NaT        NaT       Lago Chiaro

# %%
section1 = ['Baite Youlaz', 'La Thuile', 'Rifugio Deffeyes', 
            'Bivacco Zappelli', 'Planaval', 'Valgrisenche IN']
section2 = [ 'Valgrisenche OUT', 'Chalet Epee', 'Rhemes-Notre-Dame',
            'Eaux Rousse', 'Rifugio Sella', 'Cogne IN']

section3 = ['Cogne OUT', 'Goilles', 'Rifugio Dondena', 'Chardonney', 'Pontboset', 'Donnas IN']
section4  = ['Donnas OUT', 'Perloz', 'Sassa', 'Rifugio Coda',
            'Rifugio della Barma', 'Lago Chiaro', 'Col della Vecchia',
            'Niel La Gruba', 'Loo', 'Gressoney IN']

section5 = ['Gressoney OUT','Rifugio Alpenzu', 'Champoluc', 'Rifugio Grand Tournalin', 'Valtournenche IN'] 

section6 = ['Valtournenche OUT', 'Rifugio Barmasse', 'Vareton',
            'Rifugio Magià', 'Rifugio Cuney', 'Bivacco R. Clermont', 'Oyace IN',
            'Bruson Arp', 'Col Brison', 'Berio Damon', 'Ollomont IN']
        
section7 = ['Ollomont OUT', 'Rifugio Champillon', 'Ponteille Desot', 'Bosses',
            'Rifugio Frassati', 'Pas Entre Deux Sauts', 'Monte de la Saxe',
            'FINISH']

# finding the low / high season by date
pivot_DNF.loc[pivot_DNF['Retired'].isin(section1), 'Retired_Section'] = 'Retired during Section 1'
pivot_DNF.loc[pivot_DNF['Retired'].isin(section2), 'Retired_Section'] = 'Retired during Section 2'
pivot_DNF.loc[pivot_DNF['Retired'].isin(section3), 'Retired_Section'] = 'Retired during Section 3'
pivot_DNF.loc[pivot_DNF['Retired'].isin(section4), 'Retired_Section'] = 'Retired during Section 4'
pivot_DNF.loc[pivot_DNF['Retired'].isin(section5), 'Retired_Section'] = 'Retired during Section 5'
pivot_DNF.loc[pivot_DNF['Retired'].isin(section6), 'Retired_Section'] = 'Retired during Section 6'
pivot_DNF.loc[pivot_DNF['Retired'].isin(section7), 'Retired_Section'] = 'Retired during Section 7'

# %%
pivot_DNF.groupby('Retired_Section')['Retired_Section'].count()
# Out:
# Retired_Section
# Retired during Section 1     86
# Retired during Section 2    138
# Retired during Section 3     32
# Retired during Section 4    147
# Retired during Section 5     23
# Retired during Section 6     36
# Retired during Section 7     10
# Name: Retired_Section, dtype: int64

# %%
counting_retired_section_and_wave = pivot_DNF.groupby(['Retired_Section', 'Wave'] ).size().to_frame()

# Reset the index to make it more readable
counting_retired_section_and_wave.index = pd.MultiIndex.from_tuples(counting_retired_section_and_wave.index, 
                                            names=["Retired_Section", "Wave"])

# Unstack the Wave level to create columns for Wave1 and Wave2
counting_retired_section_and_wave = counting_retired_section_and_wave.unstack(level="Wave")

# Display the result
counting_retired_section_and_wave.reset_index(drop =  False)

counting_retired_section_and_wave.columns = counting_retired_section_and_wave.columns.droplevel(0)

# %%
# counting_retired_section_and_wave.columns = counting_retired_section_and_wave.columns.droplevel(0)
counting_retired_section_and_wave['Total'] = counting_retired_section_and_wave['Wave1'] +counting_retired_section_and_wave['Wave2']

counting_retired_section_and_wave['Wave1_%'] = counting_retired_section_and_wave['Wave1']/counting_retired_section_and_wave['Total']
counting_retired_section_and_wave['Wave2_%'] = counting_retired_section_and_wave['Wave2']/counting_retired_section_and_wave['Total']

counting_retired_section_and_wave['Wave1_%'] = round(counting_retired_section_and_wave['Wave1_%']*100, 1)
counting_retired_section_and_wave['Wave2_%']= round(counting_retired_section_and_wave['Wave2_%']*100, 2)

counting_retired_section_and_wave
# Out:
# Wave                      Wave1  Wave2  Total  Wave1_%  Wave2_%
# Retired_Section
# Retired during Section 1     30     56     86     34.9    65.12
# Retired during Section 2     60     78    138     43.5    56.52
# Retired during Section 3     18     14     32     56.2    43.75
# Retired during Section 4     48     99    147     32.7    67.35
# Retired during Section 5     13     10     23     56.5    43.48
# Retired during Section 6     17     19     36     47.2    52.78
# Retired during Section 7      7      3     10     70.0    30.00

# %%
# DNS?
pivot_DNF[pivoted_TOR330_dates_DNF['Retired'] == 'new_Start Date']
# Out:
#                        Name   Bib Sex Nationality  Year    Race Category  \
# 361          Galli Alberto   1202   M          IT  2023  TOR330       V2
# 597   Marziano  Gianfranco   1367   M          IT  2023  TOR330       V2
# 1007            Ueno Takumi   535   M          JP  2023  TOR330       V3
# 1026            Veltman Ari  1218   M          IL  2023  TOR330       V2
#
#       Status   Wave Duration  ... Ollomont OUT Rifugio Champillon  \
# 361    False  Wave2      NaT  ...          NaT                NaT
# 597    False  Wave2      NaT  ...          NaT                NaT
# 1007   False  Wave1      NaT  ...          NaT                NaT
# 1026   False  Wave2      NaT  ...          NaT                NaT
#
#      Ponteille Desot Bosses Rifugio Frassati Pas Entre Deux Sauts  \
# 361              NaT    NaT              NaT                  NaT
# 597              NaT    NaT              NaT                  NaT
# 1007             NaT    NaT              NaT                  NaT
# 1026             NaT    NaT              NaT                  NaT
#
#      Monte de la Saxe FINISH         Retired Retired_Section
# 361               NaT    NaT  new_Start Date             NaN
# 597               NaT    NaT  new_Start Date             NaN
# 1007              NaT    NaT  new_Start Date             NaN
# 1026              NaT    NaT  new_Start Date             NaN
#
# [4 rows x 66 columns]

# %%
# Group by 'Status' and count occurrences in each group
pivot_DNF.groupby('Retired')['Retired'].count()
# Out:
# Retired
# Baite Youlaz                2
# Bivacco R. Clermont         3
# Bivacco Zappelli            8
# Bosses                      5
# Bruson Arp                  6
# Chalet Epee                 6
# Champoluc                   8
# Chardonney                  8
# Cogne IN                   24
# Cogne OUT                   4
# Col Brison                  2
# Col della Vecchia          27
# Donnas IN                  11
# Donnas OUT                  2
# Eaux Rousse                53
# Goilles                     3
# Gressoney IN               11
# Gressoney OUT               7
# La Thuile                  13
# Lago Chiaro                 9
# Loo                        28
# Monte de la Saxe            1
# Niel La Gruba              21
# Ollomont IN                 1
# Ollomont OUT                1
# Oyace IN                    9
# Perloz                      9
# Planaval                    9
# Pontboset                   2
# Ponteille Desot             3
# Rhemes-Notre-Dame          32
# Rifugio Alpenzu             2
# Rifugio Barmasse            1
# Rifugio Coda               16
# Rifugio Cuney               1
# Rifugio Deffeyes            7
# Rifugio Dondena             4
# Rifugio Grand Tournalin     2
# Rifugio Magià               8
# Rifugio Sella              10
# Rifugio della Barma        15
# Sassa                       9
# Valgrisenche IN            47
# Valgrisenche OUT           13
# Valtournenche IN            4
# Valtournenche OUT           1
# Vareton                     4
# new_Start Date              4
# Name: Retired, dtype: int64

# %%
pivot_DNF = pivot_DNF[['Name', 'Bib', 'Sex', 'Nationality', 'Year', 'Race', 'Category',
       'Status', 'Wave', 'Duration', 'RITIRIO', 'Retired', 'Retired_Section', 'new_Start Date',
       'Baite Youlaz', 'La Thuile', 'Rifugio Deffeyes', 'Bivacco Zappelli',
       'Planaval', 'Valgrisenche IN', 'Valgrisenche OUT', 'Chalet Epee',
       'Rhemes-Notre-Dame', 'Eaux Rousse', 'Rifugio Sella', 'Cogne IN',
       'Cogne OUT', 'Goilles', 'Rifugio Dondena', 'Chardonney', 'Pontboset',
       'Donnas IN', 'Donnas OUT', 'Perloz', 'Sassa', 'Rifugio Coda',
       'Rifugio della Barma', 'Lago Chiaro', 'Col della Vecchia',
       'Niel La Gruba', 'Loo', 'Gressoney IN', 'Gressoney OUT',
       'Rifugio Alpenzu', 'Champoluc', 'Rifugio Grand Tournalin',
       'Valtournenche IN', 'Valtournenche OUT', 'Rifugio Barmasse', 'Vareton',
       'Rifugio Magià', 'Rifugio Cuney', 'Bivacco R. Clermont', 'Oyace IN',
       'Bruson Arp', 'Col Brison', 'Berio Damon', 'Ollomont IN',
       'Ollomont OUT', 'Rifugio Champillon', 'Ponteille Desot', 'Bosses',
       'Rifugio Frassati', 'Pas Entre Deux Sauts', 'Monte de la Saxe',
       'FINISH']]

# %% [markdown]
# ### Calculating the Times for each section

# %%
pivoted_TOR330_dates['Section1 Time'] = pivoted_TOR330_dates['Valgrisenche IN'] - pivoted_TOR330_dates['new_Start Date']
pivoted_TOR330_dates['Time Spent in Valgrisenche'] = pivoted_TOR330_dates['Valgrisenche OUT'] - pivoted_TOR330_dates['Valgrisenche IN']

pivoted_TOR330_dates['Section2 Time'] = pivoted_TOR330_dates['Cogne IN'] - pivoted_TOR330_dates['Valgrisenche OUT']
pivoted_TOR330_dates['Time Spent in Cogne'] = pivoted_TOR330_dates['Cogne OUT'] - pivoted_TOR330_dates['Cogne IN']


pivoted_TOR330_dates['Section3 Time'] = pivoted_TOR330_dates['Donnas IN'] - pivoted_TOR330_dates['Cogne OUT']
pivoted_TOR330_dates['Time Spent in Donnas'] = pivoted_TOR330_dates['Donnas OUT'] - pivoted_TOR330_dates['Donnas IN']


pivoted_TOR330_dates['Section4 Time'] = pivoted_TOR330_dates['Gressoney IN'] - pivoted_TOR330_dates['Donnas OUT']
pivoted_TOR330_dates['Time Spent in Gressoney'] = pivoted_TOR330_dates['Gressoney OUT'] - pivoted_TOR330_dates['Gressoney IN']

pivoted_TOR330_dates['Section5 Time'] = pivoted_TOR330_dates['Valtournenche IN'] - pivoted_TOR330_dates['Gressoney OUT']
pivoted_TOR330_dates['Time Spent in Valtournenche'] = pivoted_TOR330_dates['Valtournenche OUT'] - pivoted_TOR330_dates['Valtournenche IN']

pivoted_TOR330_dates['Section6 Time'] = pivoted_TOR330_dates['Ollomont IN'] - pivoted_TOR330_dates['Valtournenche OUT']
pivoted_TOR330_dates['Time Spent in Ollomont'] = pivoted_TOR330_dates['Ollomont OUT'] - pivoted_TOR330_dates['Ollomont IN']

pivoted_TOR330_dates['Section7 Time'] = pivoted_TOR330_dates['FINISH'] - pivoted_TOR330_dates['Ollomont OUT']

# %%
pivoted_TOR330_dates.to_excel('TOR330 Data/TOR330_2023_aid_stations.xlsx' )

# %%
pivoted_TOR330_dates.head()
# Out:
#                  Name  Bib Sex Nationality  Year    Race Category  Status  \
# 204      Colle Franco    2   M          IT  2023  TOR330       V1    True
# 851    Romain Olivier  662   M          FR  2023  TOR330      SEN    True
# 828    Reynolds Galen    6   M          CA  2023  TOR330      SEN    True
# 424       Hall Damian   20   M          GB  2023  TOR330       V1    True
# 360  Galeati Gianluca  647   M          IT  2023  TOR330       V1    True
#
#       Wave        Duration  ... Time Spent in Cogne   Section3 Time  \
# 204  Wave1 2 days 18:39:16  ...     0 days 00:10:26 0 days 06:35:28
# 851  Wave1 2 days 21:49:38  ...     0 days 00:10:54 0 days 06:36:39
# 828  Wave1 2 days 23:22:30  ...     0 days 00:19:11 0 days 06:59:04
# 424  Wave1 3 days 00:04:07  ...     0 days 00:18:55 0 days 07:04:46
# 360  Wave1 3 days 00:16:06  ...     0 days 00:16:39 0 days 07:06:06
#
#     Time Spent in Donnas   Section4 Time Time Spent in Gressoney  \
# 204      0 days 00:08:37 0 days 11:44:50         0 days 00:12:55
# 851      0 days 00:30:12 0 days 11:21:58         0 days 00:13:04
# 828      0 days 00:02:01 0 days 13:33:23         0 days 00:11:38
# 424      0 days 00:22:05 0 days 13:17:00         0 days 00:23:46
# 360      0 days 00:00:44 0 days 13:29:15         0 days 00:12:20
#
#       Section5 Time Time Spent in Valtournenche   Section6 Time  \
# 204 0 days 07:59:22             0 days 00:15:53 0 days 11:47:06
# 851 0 days 07:59:10             0 days 00:16:03 0 days 12:31:42
# 828 0 days 08:23:21             0 days 00:11:27 0 days 13:30:28
# 424 0 days 08:05:42             0 days 00:10:44 0 days 13:30:46
# 360 0 days 08:23:09             0 days 00:15:01 0 days 13:24:02
#
#     Time Spent in Ollomont   Section7 Time
# 204        0 days 00:00:07 0 days 10:41:21
# 851        0 days 00:36:26 0 days 12:30:45
# 828        0 days 00:28:23 0 days 10:09:53
# 424        0 days 00:28:21 0 days 10:51:24
# 360        0 days 00:21:39 0 days 11:11:42
#
# [5 rows x 77 columns]

# %%
sub_pivoted_TOR330_dates= pivoted_TOR330_dates[[
            'Name', 'Bib', 'Sex', 'Nationality', 'Year', 'Race', 'Category',
            'Status', 'Wave','RITIRIO', 'Retired', 'Duration', 'new_Start Date', 
            'Valgrisenche IN', 'Valgrisenche OUT', 
             'Cogne IN','Cogne OUT', 

            'Donnas IN', 'Donnas OUT', 
            'Gressoney IN', 'Gressoney OUT',

            'Valtournenche IN', 'Valtournenche OUT', 
            'Ollomont IN','Ollomont OUT', 
            'FINISH',

            #####
            'Section1 Time', 'Time Spent in Valgrisenche',
            'Section2 Time', 'Time Spent in Cogne', 'Section3 Time',
            'Time Spent in Donnas', 'Section4 Time', 'Time Spent in Gressoney',
            'Section5 Time', 'Time Spent in Valtournenche', 'Section6 Time',
            'Time Spent in Ollomont', 'Section7 Time'
    
]]

sub_pivoted_TOR330_dates[sub_pivoted_TOR330_dates['Status'] == True].isna().sum()

# %%
pivot_DNF = pivoted_TOR330_dates[pivoted_TOR330_dates['Status'] == False]
pivot_noDNF = pivoted_TOR330_dates[pivoted_TOR330_dates['Status'] == True]

# Examining the statistics TIMES for each section
for section in [ 'Section1 Time', 'Time Spent in Valgrisenche',
            'Section2 Time', 'Time Spent in Cogne', 'Section3 Time',
            'Time Spent in Donnas', 'Section4 Time', 'Time Spent in Gressoney',
            'Section5 Time', 'Time Spent in Valtournenche', 'Section6 Time',
            'Time Spent in Ollomont', 'Section7 Time']: 
    print(section.upper(), '\n',pivoted_noDNF[section].describe(),'\n', '*'*20)

# %%
### One guy stayed in  Valgrisenche for 7 hours... I thought it was an error... but nope it is actually geniune!
pivot_DNF[pivot_DNF['Time Spent in Valgrisenche'] == pivot_DNF['Time Spent in Valgrisenche'].max()]

# %%
### I thought that was IMPOSSIBLE to do Section 3 in less than 12 hours...
# Again I was wrong!

pivot_noDNF[pivot_noDNF['Section4 Time'] == pivot_noDNF['Section4 Time'].min()]

# %%
# creating histograms to examine the time of people who finished 
for section in [            'Section1 Time', 'Time Spent in Valgrisenche',
            'Section2 Time', 'Time Spent in Cogne', 'Section3 Time',
            'Time Spent in Donnas', 'Section4 Time', 'Time Spent in Gressoney',
            'Section5 Time', 'Time Spent in Valtournenche', 'Section6 Time',
            'Time Spent in Ollomont', 'Section7 Time']: 
    section_time = [t.total_seconds() / 3600 for t in pivot_noDNF[section]]

    max_Performance = max(section_time)
    min_Performance =  min(section_time)
    Performance_bins = int(max_Performance- min_Performance)

    # Plot the histogram
    plt.figure(figsize=(10, 6))
    plt.hist(section_time, bins=Performance_bins, color='skyblue', edgecolor='black')
    plt.title(f'Histogram of {section}')
    plt.xlabel('Hours')
    plt.ylabel('Frequency')
    plt.show()
