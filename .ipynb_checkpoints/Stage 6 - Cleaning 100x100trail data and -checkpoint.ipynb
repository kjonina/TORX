# %% [markdown]
# # Cleaning Data
#
# At this stage, it is important to clean the 100x100data.
#
# Several issues were highlighted throughout the process.
#
# ### # of Finishers
# As part of the analysis, DUV and ITRA finishers time were downloaded to verify runner's status and, if lucky, finishing time.
#
# When comparing the scraped 100x100 data to DUV and ITRA, it came to light that sometimes, runners are marked as finished on 100x100trail, although they did not get a finishers status on ITRA or DUV. THis required cleaning.
#
# ![image-3.png](attachment:image-3.png)
#
# Furthermore, sometimes runners were given a status of not finished. THis was easily fixed by checking their timestamp at finish line (Courmayer). However, in that case, it was made sure that there was a timestamp for them between road Stages
#
# ### Life bases / Refugees
#
# Several cleaning methods were deployed to clean this column. There were 'RITIRIO' in some values, so this needed to be stripped and kept in a different column
#
# ![image-5.png](attachment:image-5.png)
#
#
# ### 'Time' column
# 'Time' Column is one the most important columns in this process and needs to be meticulously cleaned for errors and inconsitencies!
#
# The timesstamps had '+02:00' which was not necessary once inspected.
# ![image.png](attachment:image.png)
#
#
# ### Starting Time
# Starting Times were also inaccurate. The starting time was set random times (who knows why?) but the times were changed to reflect wave start times!
# ![image-2.png](attachment:image-2.png)
#
# To deal with the Start Time, issue, DUV data was used to detect the start date for each year
#
# ![image-6.png](attachment:image-6.png)

# %%
import re
import pandas as pd
import time
import numpy as np
import matplotlib.pyplot as plt
# import pandas as pd
# import matplotlib.pyplot as plt
import seaborn as sns

# %%
### FIX BARMASSE
### FIX BARMA

# %%
# # Set pandas options to display all columns and rows
# pd.set_option('display.max_columns', None)  # Show all columns
# pd.set_option('display.max_rows', None)     # Show all rows

# %% [markdown]
# ## Looping through scraped data from 100X100trail

# %%
races = ['TOR330'
#         ,'TOR450'
        ]
years = [ #'2021',
#         '2022',
         '2023', 
#     '2024'
        ]

TORX_df = {}

for race in races:
    for year in years:
        df = pd.read_excel(f'{race} Data/100x100trail/aid_station_{race}_{year}.xlsx',
                                 dtype={'Start Date': 'string',
                                        'Year': 'string'})
        print(f'{race}_{year} {df.shape}')
        # Store the DataFrame in the dictionary with a key like 'TOR330_2021'
        TORX_df[f'{race}_{year}'] = df
    print('*'*50),
# Out:
# TOR330_2023 (42964, 10)
# **************************************************

# %%
TORX_df_concat = pd.concat(TORX_df)

# %%
TOR330 = TORX_df_concat[TORX_df_concat['Year'] == year]
TOR330.head()
# Out:
#                        Name  Bib Sex Nationality    Race  Year Category  \
# TOR330_2023 0  Colle Franco    2   M          IT  TOR330  2023       V1
#             1  Colle Franco    2   M          IT  TOR330  2023       V1
#             2  Colle Franco    2   M          IT  TOR330  2023       V1
#             3  Colle Franco    2   M          IT  TOR330  2023       V1
#             4  Colle Franco    2   M          IT  TOR330  2023       V1
#
#                                         Place                       Time  \
# TOR330_2023 0                660 - FINISH 330  2023-09-13T04:39:16+02:00
#             1      650 - Monte de la Saxe 450  2023-09-13T03:52:25+02:00
#             2  640 - Pas Entre Deux Sauts 450  2023-09-13T02:23:36+02:00
#             3         630 - Rif. Frassati 450  2023-09-13T00:45:25+02:00
#             4                620 - Bosses 330  2023-09-12T22:30:41+02:00
#
#                Status
# TOR330_2023 0    True
#             1    True
#             2    True
#             3    True
#             4    True

# %%
def counting_finish_DNF_dataset(df):
    for year in years :
        for race in races:

            if len(df['Name'][(df['Year'] == year) & (df['Race'] == race)].unique()) != 0:
                print(race , year)
                ## The data is currently stacked so every checkpoint has a unique row
                # using the unique function to count unique participants in the data
                print('# of Partipants:', len(df['Name'][(df['Year'] == year) &
                                                        (df['Race'] == race)].unique()))
                
                
                
                # Finishers
                print('# of Finishers:', len(df['Name'][(df['Year'] == year) &
                                                        (df['Race'] == race) &
                                                        (df['Status'] ==  True)].unique()))
                # DNFs
                print('# of DNFs:', len(df['Name'][(df['Year'] == year) &
                                                        (df['Race'] == race) &
                                                        (df['Status'] ==  False)].unique()))
                print('*'*20)
            else:
                pass
            
counting_finish_DNF_dataset(TOR330)
# Out:
# TOR330 2023
# # of Partipants: 1206
# # of Finishers: 630
# # of DNFs: 576
# ********************

# %%
def counting_groupby_dataset(df, column):
    for year in years :
        for race in races:
            
            df = df[['Name', 'Status', 'Year', 'Race']].drop_duplicates()

            if len(df['Name'][(df['Year'] == year) & (df['Race'] == race)].unique()) != 0:
                print(race , year)
                ## The data is currently stacked so every checkpoint has a unique row
                # using the unique function to count unique participants in the data
                print('# of Partipants:', len(df['Name'][(df['Year'] == year) &
                                                        (df['Race'] == race)].unique()), '\n')
                
                print(df.groupby([column])[column].count())
                print('*'*20)
            else:
                pass
counting_groupby_dataset(df,  'Status')
# Out:
# TOR330 2023
# # of Partipants: 1206
#
# Status
# False    576
# True     630
# Name: Status, dtype: int64
# ********************

# %% [markdown]
# ### DUV and ITRA data
#
#
# #### # of Finishers
# As part of the analysis, DUV and ITRA finishers time were downloaded to verify runner's status and, if lucky, finishing time.
#
# When comparing the scraped 100x100 data to DUV and ITRA, it came to light that sometimes, runners are marked as finished on 100x100trail, although they did not get a finishers status on ITRA or DUV. THis required cleaning.
#
# ![image.png](attachment:image.png)

# %%
    TORX_duv_df = pd.read_excel(f'Database Data/TORX_duv_df.xlsx',
                                     dtype={'Start Date': 'string',
                                            'Year': 'string'})

    TORX_itra_no_DNF = pd.read_excel(f'Database Data/TORX_itra_no_DNF.xlsx',
                                     dtype={'Start Date': 'string',
                                           'Year': 'string'})

# %%
def find_out_the_rows_difference_between_datasets(df):
    for year in years :
        for race in races:
            if len(df['Name'][(df['Year'] == year)]) != 0:

                print(race, year)
                print('# ITRA rows: ', TORX_itra_no_DNF[(TORX_itra_no_DNF['Year'] == year) &
                                  (TORX_itra_no_DNF['Race'] == race)].shape[0])
                print('# DUV rows: ',TORX_duv_df[(TORX_duv_df['Year'] == year) &
                                  (TORX_duv_df['Race'] == race)].shape[0])

                print('# TOR330 rows: ', len(df['Name'][(df['Year'] == year) &
                                                 (df['Race'] == race) &
                                                 (df['Status'] == True)].unique()))
                print('\n', '*'*20)
                
                if year == '2022':
                    print(' - ','TOR330','2022')
                    print(TORX_itra_no_DNF[(TORX_itra_no_DNF['Race'] == 'TOR330') &
                          (TORX_itra_no_DNF['Year'] == '2022')].groupby(['Status'])['Status'].count())
                    print('\n', '*'*20)
            else: 
                pass

# %%
counting_finish_DNF_dataset(TOR330)
find_out_the_rows_difference_between_datasets(TOR330)
counting_groupby_dataset(TOR330,  'Status')
# Out:
# TOR330 2023
# # of Partipants: 1206
# # of Finishers: 630
# # of DNFs: 576
# ********************
# TOR330 2023
# # ITRA rows:  621
# # DUV rows:  621
# # TOR330 rows:  630
#
#  ********************
# TOR330 2023
# # of Partipants: 1206
#
# Status
# False    576
# True     630
# Name: Status, dtype: int64
# ********************

# %% [markdown]
# ### Cleaning Place column

# %%
TOR330['Place'].unique()
# Out:
# array(['660 - FINISH 330', '650 - Monte de la Saxe 450',
#        '640 - Pas Entre Deux Sauts 450', '630 - Rif. Frassati 450',
#        '620 - Bosses 330', '610 - Ponteille Desot 450',
#        '590 - Rif. Champillon 450', '581 - Ollomont OUT 330',
#        '580 - Ollomont IN 330', '570 - Berio Damon 330',
#        '565 - Col Brison 330', '551 - Oyace OUT 330',
#        '550 - Oyace IN 330', '540 - Biv. R. Clermont 330',
#        '530 - Rif. Cuney 330', '520 - Rif. Magià 330',
#        '490 - Rif. Barmasse 330', '481 - Valtournenche OUT 330',
#        '480 - Valtournenche IN 330', '470 - Rif. Grand Tournalin 330',
#        '460 - Champoluc 330', '450 - Rif. Alpenzu 330',
#        '381 - Gressoney OUT 330', '380 - Gressoney IN 330', '370 - Loo',
#        '360 - Niel La Gruba 450', '350 - Col della Vecchia',
#        '340 - Lago Chiaro', '330 - Rif. della Barma 450',
#        '320 - Rif. Coda 450', '310 - Sassa', '300 - Perloz',
#        '291 - Donnas OUT 450', '290 - Donnas IN 330', '260 - Pontboset',
#        '250 - Chardonney', '240 - Rif. Dondena 450', '210 - Goilles',
#        '201 - Cogne OUT 330', '200 - Cogne IN 330',
#        '190 - Rif. Sella 450', '180 - Eaux Rousse',
#        '170 - Rhemes-Notre-Dame', '160 - Chalet Epee',
#        '151 - Valgrisenche OUT', '150 - Valgrisenche IN',
#        '140 - Planaval', '130 - Biv. Zappelli', '060 - Rif. Deffeyes 450',
#        '030 - La Thuile', '020 - Baite Youlaz', '010 - START',
#        '000 - PETTORALI', '660 - FINISH|UHF', '655 - Parco Bollino|UHF',
#        '290 - Donnas IN 330 - RITIRO', '560 - Bruson Arp 330',
#        '510 - Vareton 330', '520 - Rif. Magià 330 - RITIRO',
#        '291 - Donnas OUT 450 - RITIRO', '650 - Mont de la Saxe 330',
#        '381 - Gressoney OUT 330 - RITIRO',
#        '581 - Ollomont OUT 330 - RITIRO',
#        '580 - Ollomont IN 330 - RITIRO', '340 - Lago Chiaro - RITIRO',
#        '550 - Oyace IN 330 - RITIRO',
#        '481 - Valtournenche OUT 330 - RITIRO',
#        '460 - Champoluc 330 - RITIRO', '310 - Sassa - RITIRO',
#        '330 - Rif. della Barma 450 - RITIRO', '230 - Rif. Miserin',
#        '380 - Gressoney IN 330 - RITIRO',
#        '360 - Niel La Gruba 450 - RITIRO',
#        '350 - Col della Vecchia - RITIRO', '250 - Chardonney - RITIRO',
#        '151 - Valgrisenche OUT - RITIRO',
#        '240 - Rif. Dondena 450 - RITIRO', '210 - Goilles - RITIRO',
#        '201 - Cogne OUT 330 - RITIRO', '200 - Cogne IN 330 - RITIRO',
#        '190 - Rif. Sella 450 - RITIRO', '180 - Eaux Rousse - RITIRO',
#        '170 - Rhemes-Notre-Dame - RITIRO', '160 - Chalet Epee - RITIRO',
#        '150 - Valgrisenche IN - RITIRO', '030 - La Thuile - RITIRO',
#        '020 - Baite Youlaz - RITIRO'], dtype=object)

# %%
# 030 - La Thuile - RITIRO
TOR330['aid_stations'] = TOR330['Place'].str.split(r'^\d+ - ').str.get(-1)
TOR330['aid_stations'] = TOR330['aid_stations'].str.replace('Rif. della Balm 450a','Rif. della Balma')
TOR330['aid_stations'] = TOR330['aid_stations'].str.replace(r'\d+', '', regex=True)
TOR330['aid_stations'] = TOR330['aid_stations'].str.split('|').str.get(0)
TOR330['aid_stations'] = TOR330['aid_stations'].str.replace('Rif.', 'Rifugio')
TOR330['aid_stations'] = TOR330['aid_stations'].str.replace('Biv.','Bivacco')
TOR330['aid_stations'] = TOR330['aid_stations'].str.replace('Niel - ','Niel ')
TOR330['aid_stations'] = TOR330['aid_stations'].str.replace('Oyace IN','Oyace')
TOR330['aid_stations'] = TOR330['aid_stations'].str.replace('  ',' ')
TOR330['aid_stations'] = TOR330['aid_stations'].str.replace('Mont de la Saxe','Monte de la Saxe')
TOR330['aid_stations'] = TOR330['aid_stations'].str.replace('Rifugio della Barmasse', 'Rifugio Barmasse')
TOR330['aid_stations'] = TOR330['aid_stations'].str.replace('Promoud','Bivacco Zappelli')
TOR330['aid_stations'] = TOR330['aid_stations'].str.strip()
TOR330['RITIRIO'] = np.where(
    TOR330['aid_stations'].str.contains('RITIRO', na=False), 
    TOR330['aid_stations'],  '')
# TOR330['RITIRIO] =TOR330['RITIRIO].str.replace('- RITIRO', '')
TOR330['aid_stations'] = TOR330['aid_stations'].str.split(' - RITIRO').str.get(0)
print(', '.join(list(TOR330['aid_stations'].unique())))
# Out:
# C:\Users\Karina\AppData\Local\Temp\ipykernel_20632\986193751.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   TOR330['aid_stations'] = TOR330['aid_stations'].str.replace('Rif. della Balm 450a','Rif. della Balma')
# C:\Users\Karina\AppData\Local\Temp\ipykernel_20632\986193751.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   TOR330['aid_stations'] = TOR330['aid_stations'].str.replace('Rif.', 'Rifugio')
# C:\Users\Karina\AppData\Local\Temp\ipykernel_20632\986193751.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   TOR330['aid_stations'] = TOR330['aid_stations'].str.replace('Biv.','Bivacco')
# FINISH, Monte de la Saxe, Pas Entre Deux Sauts, Rifugio Frassati, Bosses, Ponteille Desot, Rifugio Champillon, Ollomont OUT, Ollomont IN, Berio Damon, Col Brison, Oyace OUT, Oyace, Bivacco R. Clermont, Rifugio Cuney, Rifugio Magià, Rifugio Barmasse, Valtournenche OUT, Valtournenche IN, Rifugio Grand Tournalin, Champoluc, Rifugio Alpenzu, Gressoney OUT, Gressoney IN, Loo, Niel La Gruba, Col della Vecchia, Lago Chiaro, Rifugio della Barma, Rifugio Coda, Sassa, Perloz, Donnas OUT, Donnas IN, Pontboset, Chardonney, Rifugio Dondena, Goilles, Cogne OUT, Cogne IN, Rifugio Sella, Eaux Rousse, Rhemes-Notre-Dame, Chalet Epee, Valgrisenche OUT, Valgrisenche IN, Planaval, Bivacco Zappelli, Rifugio Deffeyes, La Thuile, Baite Youlaz, START, PETTORALI, Parco Bollino, Bruson Arp, Vareton, Rifugio Miserin

# %%
# copy the column to make a new column
for i in list(TOR330['RITIRIO'].unique()):
    print(i)
# Out:
# Donnas IN - RITIRO
# Rifugio Magià - RITIRO
# Donnas OUT - RITIRO
# Gressoney OUT - RITIRO
# Ollomont OUT - RITIRO
# Ollomont IN - RITIRO
# Lago Chiaro - RITIRO
# Oyace - RITIRO
# Valtournenche OUT - RITIRO
# Champoluc - RITIRO
# Sassa - RITIRO
# Rifugio della Barma - RITIRO
# Gressoney IN - RITIRO
# Niel La Gruba - RITIRO
# Col della Vecchia - RITIRO
# Chardonney - RITIRO
# Valgrisenche OUT - RITIRO
# Rifugio Dondena - RITIRO
# Goilles - RITIRO
# Cogne OUT - RITIRO
# Cogne IN - RITIRO
# Rifugio Sella - RITIRO
# Eaux Rousse - RITIRO
# Rhemes-Notre-Dame - RITIRO
# Chalet Epee - RITIRO
# Valgrisenche IN - RITIRO
# La Thuile - RITIRO
# Baite Youlaz - RITIRO

# %%
TOR330[~(TOR330['RITIRIO'].isnull())]
# Out:
#                                        Name   Bib Sex Nationality    Race  \
# TOR330_2023 0                  Colle Franco     2   M          IT  TOR330
#             1                  Colle Franco     2   M          IT  TOR330
#             2                  Colle Franco     2   M          IT  TOR330
#             3                  Colle Franco     2   M          IT  TOR330
#             4                  Colle Franco     2   M          IT  TOR330
# ...                                     ...   ...  ..         ...     ...
#             42959  Jimenez Roqhuett Marcelo  1487   M          CR  TOR330
#             42960              Campion Mark  1505   M          GB  TOR330
#             42961             Torre Silvere  1520   M          FR  TOR330
#             42962         Vlatkovic Tatiana  1523   F          CH  TOR330
#             42963          Dohrmann Michael  1525   M          US  TOR330
#
#                    Year Category                           Place  \
# TOR330_2023 0      2023       V1                660 - FINISH 330
#             1      2023       V1      650 - Monte de la Saxe 450
#             2      2023       V1  640 - Pas Entre Deux Sauts 450
#             3      2023       V1         630 - Rif. Frassati 450
#             4      2023       V1                620 - Bosses 330
# ...                 ...      ...                             ...
#             42959  2023       V1                 000 - PETTORALI
#             42960  2023       V1                 000 - PETTORALI
#             42961  2023       V3                 000 - PETTORALI
#             42962  2023      SEN                 000 - PETTORALI
#             42963  2023       V1                 000 - PETTORALI
#
#                                         Time  Status          aid_stations  \
# TOR330_2023 0      2023-09-13T04:39:16+02:00    True                FINISH
#             1      2023-09-13T03:52:25+02:00    True      Monte de la Saxe
#             2      2023-09-13T02:23:36+02:00    True  Pas Entre Deux Sauts
#             3      2023-09-13T00:45:25+02:00    True      Rifugio Frassati
#             4      2023-09-12T22:30:41+02:00    True                Bosses
# ...                                      ...     ...                   ...
#             42959  2023-08-29T16:30:00+02:00   False             PETTORALI
#             42960  2023-08-29T16:30:00+02:00   False             PETTORALI
#             42961  2023-08-29T16:30:00+02:00   False             PETTORALI
#             42962  2023-08-29T16:30:00+02:00   False             PETTORALI
#             42963  2023-08-29T16:30:00+02:00   False             PETTORALI
#
#                   RITIRIO
# TOR330_2023 0
#             1
#             2
#             3
#             4
# ...                   ...
#             42959
#             42960
#             42961
#             42962
#             42963
#
# [42964 rows x 12 columns]

# %% [markdown]
# ### Cleaning Time column
#
# Column '2024-09-11T07:08:32+02:00' needs to be fixed into '2024-09-11 07:08:32' and turned into the datetime
#
# ![image.png](attachment:image.png)

# %%
# 2024-09-11T07:08:32+02:00

# Split the 'Time' column to remove the timezone offset
TOR330['new_Time'] = TOR330['Time'].str.split('+').str[0]

# Convert the cleaned time string to a datetime object
TOR330['new_Time'] = pd.to_datetime(TOR330['new_Time'])

# # Add the 2-hour offset using timedelta
# # NO NEED!!!
# TOR330['new_Time'] = TOR330['new_Time'] + pd.to_timedelta('02:00:00')

# Preview the DataFrame
TOR330.head()
# Out:
#                        Name  Bib Sex Nationality    Race  Year Category  \
# TOR330_2023 0  Colle Franco    2   M          IT  TOR330  2023       V1
#             1  Colle Franco    2   M          IT  TOR330  2023       V1
#             2  Colle Franco    2   M          IT  TOR330  2023       V1
#             3  Colle Franco    2   M          IT  TOR330  2023       V1
#             4  Colle Franco    2   M          IT  TOR330  2023       V1
#
#                                         Place                       Time  \
# TOR330_2023 0                660 - FINISH 330  2023-09-13T04:39:16+02:00
#             1      650 - Monte de la Saxe 450  2023-09-13T03:52:25+02:00
#             2  640 - Pas Entre Deux Sauts 450  2023-09-13T02:23:36+02:00
#             3         630 - Rif. Frassati 450  2023-09-13T00:45:25+02:00
#             4                620 - Bosses 330  2023-09-12T22:30:41+02:00
#
#                Status          aid_stations RITIRIO            new_Time
# TOR330_2023 0    True                FINISH         2023-09-13 04:39:16
#             1    True      Monte de la Saxe         2023-09-13 03:52:25
#             2    True  Pas Entre Deux Sauts         2023-09-13 02:23:36
#             3    True      Rifugio Frassati         2023-09-13 00:45:25
#             4    True                Bosses         2023-09-12 22:30:41

# %%
for i in TOR330.aid_stations.unique():
    print(i)
# Out:
# FINISH
# Monte de la Saxe
# Pas Entre Deux Sauts
# Rifugio Frassati
# Bosses
# Ponteille Desot
# Rifugio Champillon
# Ollomont OUT
# Ollomont IN
# Berio Damon
# Col Brison
# Oyace OUT
# Oyace
# Bivacco R. Clermont
# Rifugio Cuney
# Rifugio Magià
# Rifugio Barmasse
# Valtournenche OUT
# Valtournenche IN
# Rifugio Grand Tournalin
# Champoluc
# Rifugio Alpenzu
# Gressoney OUT
# Gressoney IN
# Loo
# Niel La Gruba
# Col della Vecchia
# Lago Chiaro
# Rifugio della Barma
# Rifugio Coda
# Sassa
# Perloz
# Donnas OUT
# Donnas IN
# Pontboset
# Chardonney
# Rifugio Dondena
# Goilles
# Cogne OUT
# Cogne IN
# Rifugio Sella
# Eaux Rousse
# Rhemes-Notre-Dame
# Chalet Epee
# Valgrisenche OUT
# Valgrisenche IN
# Planaval
# Bivacco Zappelli
# Rifugio Deffeyes
# La Thuile
# Baite Youlaz
# START
# PETTORALI
# Parco Bollino
# Bruson Arp
# Vareton
# Rifugio Miserin

# %% [markdown]
# ### PIVOTING the Dataset

# %%
# Pivot the data so that each participant has its own column
pivoted_TOR330 = TOR330.pivot_table(
    index=['Name','Bib', 'Sex', 
           'Nationality', 'Category', 'Race','Year', 'Status' , #'RITIRIO'
          ],
    columns='aid_stations',  
    values='new_Time',
    aggfunc='first'  # Ensures only the first match is kept in case of duplicates
).reset_index()


# pivoted_TOR330 = pivoted_TOR330.sort_values(by = 'Bib', ascending = True)
pivoted_TOR330.head()
# Out:
# aid_stations                Name   Bib Sex Nationality Category    Race  Year  \
# 0                    Abe Takashi   443   M          JP       V1  TOR330  2023
# 1                    Acerbi Luca  1290   M          IT       V3  TOR330  2023
# 2             Acerbi Maria Luisa  1234   F          IT      SEN  TOR330  2023
# 3             Adamczyk Guillaume  1215   M          BE       V2  TOR330  2023
# 4                   Affre Roxane  1320   F          FR       V2  TOR330  2023
#
# aid_stations  Status        Baite Youlaz         Berio Damon  ...  \
# 0               True 2023-09-10 12:32:30 2023-09-15 12:13:32  ...
# 1              False 2023-09-10 15:26:07                 NaT  ...
# 2              False                 NaT                 NaT  ...
# 3              False 2023-09-10 15:30:04                 NaT  ...
# 4              False 2023-09-10 16:00:38                 NaT  ...
#
# aid_stations Rifugio Miserin       Rifugio Sella Rifugio della Barma  \
# 0                        NaT 2023-09-11 17:49:52 2023-09-13 03:14:01
# 1                        NaT                 NaT                 NaT
# 2                        NaT                 NaT                 NaT
# 3                        NaT                 NaT                 NaT
# 4                        NaT                 NaT                 NaT
#
# aid_stations               START               Sassa     Valgrisenche IN  \
# 0                            NaT 2023-09-12 20:07:44 2023-09-10 22:29:16
# 1            2023-09-10 11:22:44                 NaT 2023-09-11 04:16:59
# 2                            NaT                 NaT                 NaT
# 3            2023-09-10 11:50:58                 NaT 2023-09-11 06:20:04
# 4            2023-09-10 11:19:55                 NaT 2023-09-11 06:25:00
#
# aid_stations    Valgrisenche OUT    Valtournenche IN   Valtournenche OUT  \
# 0            2023-09-11 01:27:00 2023-09-14 11:20:43 2023-09-14 16:38:25
# 1                            NaT                 NaT                 NaT
# 2                            NaT                 NaT                 NaT
# 3                            NaT                 NaT                 NaT
# 4                            NaT                 NaT                 NaT
#
# aid_stations             Vareton
# 0            2023-09-14 19:55:33
# 1                            NaT
# 2                            NaT
# 3                            NaT
# 4                            NaT
#
# [5 rows x 65 columns]

# %%
print(pivoted_TOR330.shape)
print(pivoted_TOR330.groupby(['Status'])['Status'].count())
# Out:
# (1206, 65)
# Status
# False    576
# True     630
# Name: Status, dtype: int64

# %%
# reordering columns 
pivoted_TOR330 = pivoted_TOR330[[
'Name', 'Bib', 'Sex', 'Nationality', 'Year', 'Race','Category', 'Status', #'RITIRIO',  
'START', 'Baite Youlaz', 'La Thuile', 'Rifugio Deffeyes', 
    # 'Bivacco Zappelli', 'Col Brison', 'Berio Damon' # Dropping these because its not very useful anyway!
    'Planaval', 'Valgrisenche IN', 'Valgrisenche OUT', 'Chalet Epee', 'Rhemes-Notre-Dame',
    'Eaux Rousse', 'Rifugio Sella', 'Cogne IN', 'Cogne OUT', 'Goilles', 'Rifugio Dondena', 
    'Chardonney', 'Pontboset', 'Donnas IN', 'Donnas OUT', 'Perloz', 'Sassa', 'Rifugio Coda',
    'Rifugio della Barma', 'Lago Chiaro', 'Col della Vecchia', 'Niel La Gruba', 'Loo',
    'Gressoney IN', 'Gressoney OUT', 'Rifugio Alpenzu', 'Champoluc', 'Rifugio Grand Tournalin', 
    'Valtournenche IN', 'Valtournenche OUT', 'Rifugio Barmasse', 'Vareton',
    'Rifugio Magià', 'Rifugio Cuney', 'Bivacco R. Clermont', 
    'Oyace', 'Bruson Arp',   'Ollomont IN', 
    'Ollomont OUT', 'Rifugio Champillon', 'Ponteille Desot', 'Bosses', 'Rifugio Frassati', 
    'Pas Entre Deux Sauts', 'Monte de la Saxe', 'FINISH']]

pivoted_TOR330 = pivoted_TOR330.sort_values(by = 'Bib', ascending = True)
pivoted_TOR330.head()
# Out:
# aid_stations            Name  Bib Sex Nationality  Year    Race Category  \
# 955              Russi Jonas    1   M          CH  2023  TOR330      SEN
# 224             Colle Franco    2   M          IT  2023  TOR330       V1
# 243           Corsini Simone    3   M          IT  2023  TOR330      SEN
# 306              Doi Takashi    4   M          JP  2023  TOR330       V1
# 634            Macchi Andrea    5   M          IT  2023  TOR330      SEN
#
# aid_stations  Status               START        Baite Youlaz  ...  \
# 955            False                 NaT                 NaT  ...
# 224             True 2023-09-10 09:36:38 2023-09-10 11:48:06  ...
# 243            False                 NaT                 NaT  ...
# 306             True                 NaT 2023-09-10 11:54:54  ...
# 634            False 2023-09-10 09:43:41 2023-09-10 11:47:59  ...
#
# aid_stations          Bruson Arp         Ollomont IN        Ollomont OUT  \
# 955                          NaT                 NaT                 NaT
# 224                          NaT 2023-09-12 17:57:48 2023-09-12 17:57:55
# 243                          NaT                 NaT                 NaT
# 306          2023-09-13 10:05:36 2023-09-13 12:01:36 2023-09-13 12:25:30
# 634                          NaT                 NaT                 NaT
#
# aid_stations  Rifugio Champillon     Ponteille Desot              Bosses  \
# 955                          NaT                 NaT                 NaT
# 224          2023-09-12 19:36:02 2023-09-12 21:04:38 2023-09-12 22:30:41
# 243                          NaT                 NaT                 NaT
# 306          2023-09-13 14:39:25 2023-09-13 16:25:39 2023-09-13 18:06:33
# 634                          NaT                 NaT                 NaT
#
# aid_stations    Rifugio Frassati Pas Entre Deux Sauts    Monte de la Saxe  \
# 955                          NaT                  NaT                 NaT
# 224          2023-09-13 00:45:25  2023-09-13 02:23:36 2023-09-13 03:52:25
# 243                          NaT                  NaT                 NaT
# 306          2023-09-13 21:18:38  2023-09-13 23:50:12 2023-09-14 01:28:34
# 634                          NaT                  NaT                 NaT
#
# aid_stations              FINISH
# 955                          NaT
# 224          2023-09-13 04:39:16
# 243                          NaT
# 306          2023-09-14 02:20:44
# 634                          NaT
#
# [5 rows x 58 columns]

# %%
print(pivoted_TOR330.shape)
print(pivoted_TOR330.groupby(['Status'])['Status'].count())
# Out:
# (1206, 58)
# Status
# False    576
# True     630
# Name: Status, dtype: int64

# %% [markdown]
# ### RITIRIO
#
# Although every attempt was tried to include RITIRIO column in the dataset, it came to light that some people were twice marked retired.
#
# ![image-3.png](attachment:image-3.png)
#
# #### Solution
# Do nothing. Dont reattach it to the pivoted dataset. It is useless anyway. Only 140 runners were marked as retired, very far from the DNF number.
#
# ![image-4.png](attachment:image-4.png)

# %%
ritirio_df = TOR330[~(TOR330['RITIRIO'] == '')]
# ritirio_df = ritirio_df[['Bib', 'RITIRIO']]
ritirio_df.head()
# Out:
#                                     Name   Bib Sex Nationality    Race  Year  \
# TOR330_2023 73            Verjee Sabrina    48   F          GB  TOR330  2023
#             2381          Brumana Andrea    62   M          IT  TOR330  2023
#             7267      Hartmuth Katharina   665   F          CH  TOR330  2023
#             8901          Smith Jonathan  1321   M          AU  TOR330  2023
#             32389  Houteer Magni Justine   275   F          FR  TOR330  2023
#
#                   Category                             Place  \
# TOR330_2023 73          V1      290 - Donnas IN 330 - RITIRO
#             2381        V1     520 - Rif. Magià 330 - RITIRO
#             7267       SEN      290 - Donnas IN 330 - RITIRO
#             8901        V2     291 - Donnas OUT 450 - RITIRO
#             32389       V1  381 - Gressoney OUT 330 - RITIRO
#
#                                         Time  Status   aid_stations  \
# TOR330_2023 73     2023-09-11T14:00:51+02:00    True      Donnas IN
#             2381   2023-09-13T10:28:07+02:00    True  Rifugio Magià
#             7267   2023-09-11T14:00:58+02:00    True      Donnas IN
#             8901   2023-09-12T17:18:56+02:00    True     Donnas OUT
#             32389  2023-09-14T01:33:04+02:00    True  Gressoney OUT
#
#                                   RITIRIO            new_Time
# TOR330_2023 73         Donnas IN - RITIRO 2023-09-11 14:00:51
#             2381   Rifugio Magià - RITIRO 2023-09-13 10:28:07
#             7267       Donnas IN - RITIRO 2023-09-11 14:00:58
#             8901      Donnas OUT - RITIRO 2023-09-12 17:18:56
#             32389  Gressoney OUT - RITIRO 2023-09-14 01:33:04

# %%
# Get a list of duplicate names
duplicate_list = ritirio_df['Name'][ritirio_df['Name'].duplicated()].unique()

# Filter the DataFrame to only rows where 'Name' is in the duplicate list
duplicates_in_dataframe = ritirio_df[ritirio_df['Name'].isin(duplicate_list)]

# Display or process the result
duplicates_in_dataframe[['Name', 'Sex', 'Nationality', 'Year', 'Race', 'RITIRIO' ]]
# Out:
#                                Name Sex Nationality  Year    Race  \
# TOR330_2023 36474    Nakajima Mizue   F          JP  2023  TOR330
#             36475    Nakajima Mizue   F          JP  2023  TOR330
#             36667       Brun Fabien   M          FR  2023  TOR330
#             36668       Brun Fabien   M          FR  2023  TOR330
#             36775  Higuchi Hiroyuki   M          JP  2023  TOR330
#             36776  Higuchi Hiroyuki   M          JP  2023  TOR330
#
#                                         RITIRIO
# TOR330_2023 36474        Gressoney OUT - RITIRO
#             36475                Sassa - RITIRO
#             36667        Gressoney OUT - RITIRO
#             36668  Rifugio della Barma - RITIRO
#             36775        Gressoney OUT - RITIRO
#             36776  Rifugio della Barma - RITIRO

# %%
ritirio_df['Name'].nunique()
# Out:
# 132

# %%
print(pivoted_TOR330.shape)
print(pivoted_TOR330.groupby(['Status'])['Status'].count())
# Out:
# (1206, 58)
# Status
# False    576
# True     630
# Name: Status, dtype: int64

# %%
# # Merge the datsets back after pivoting
# pivoted_TOR330 = pivoted_TOR330.merge(
#     ritirio_df[['Bib', 'RITIRIO']].drop_duplicates(),  # Ensure no duplicates in 'Bib' and 'RITIRIO'
#     on='Bib',
#     how='left'
# )

# %%
print(pivoted_TOR330.shape)
print(pivoted_TOR330.groupby(['Status'])['Status'].count())
# Out:
# (1206, 58)
# Status
# False    576
# True     630
# Name: Status, dtype: int64

# %% [markdown]
# ### Dealing with Anomalies
#
# Several anomalies were spotted with the finish times.
#
# Some runners had a timestamp at the finish line, yet failed to be scanned Ollomont IN or OUT or any other refugee or checkpoints on the last stage.
#
#
# ![image.png](attachment:image.png)
#
# SOLUTION: change their status to FALSE and remove the timestamp

# %% [markdown]
# ### 2023 Solution
# 9 participants were incorrectly labelled as finished!
# ![image-2.png](attachment:image-2.png)
#
# 8 participants were identified as labelled finished and had a finish time but missed all stage 7 checkpoints
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 2024 Solution

# %%
# Looking for runners who have FINISHED< BUT have missing values for all last 3 checkpoints!
anomalies_df = pivoted_TOR330[(pivoted_TOR330['Status'] == True) &
               (pivoted_TOR330['Bosses'].isna()) &                
               (pivoted_TOR330['Rifugio Frassati'].isna()) & 
               (pivoted_TOR330['Pas Entre Deux Sauts'].isna()) &
               (pivoted_TOR330['Monte de la Saxe'].isna())]

anomalies_df[[ 'Name', 'Bib', 'Year', 'Race', 'Status',  'START',
    	'Ollomont IN',	'Ollomont OUT',
    'Rifugio Champillon', 'Ponteille Desot',
    'Bosses',	'Rifugio Frassati',	'Pas Entre Deux Sauts',	'Monte de la Saxe',
    'FINISH']].reset_index(drop = True)

### Conclusion: Easily visible that there are several other places that have missing values
# Out:
# aid_stations                   Name   Bib  Year    Race  Status  \
# 0                    Verjee Sabrina    48  2023  TOR330    True
# 1             Houteer Magni Justine   275  2023  TOR330    True
# 2                       Yang Victor   493  2023  TOR330    True
# 3                     Peron Bastien   540  2023  TOR330    True
# 4                Hartmuth Katharina   665  2023  TOR330    True
# 5                    Tang Yuen Ying  1105  2023  TOR330    True
# 6                    Yoshida Shuhei  1143  2023  TOR330    True
# 7                    Smith Jonathan  1321  2023  TOR330    True
#
# aid_stations               START Ollomont IN Ollomont OUT Rifugio Champillon  \
# 0            2023-09-10 09:33:01         NaT          NaT                NaT
# 1            2023-09-10 09:20:29         NaT          NaT                NaT
# 2            2023-09-10 09:49:30         NaT          NaT                NaT
# 3            2023-09-10 09:32:59         NaT          NaT                NaT
# 4            2023-09-10 09:27:48         NaT          NaT                NaT
# 5            2023-09-10 11:52:42         NaT          NaT                NaT
# 6            2023-09-10 11:39:57         NaT          NaT                NaT
# 7            2023-09-10 11:23:04         NaT          NaT                NaT
#
# aid_stations Ponteille Desot Bosses Rifugio Frassati Pas Entre Deux Sauts  \
# 0                        NaT    NaT              NaT                  NaT
# 1                        NaT    NaT              NaT                  NaT
# 2                        NaT    NaT              NaT                  NaT
# 3                        NaT    NaT              NaT                  NaT
# 4                        NaT    NaT              NaT                  NaT
# 5                        NaT    NaT              NaT                  NaT
# 6                        NaT    NaT              NaT                  NaT
# 7                        NaT    NaT              NaT                  NaT
#
# aid_stations Monte de la Saxe              FINISH
# 0                         NaT 2023-09-13 05:38:22
# 1                         NaT 2023-09-16 14:12:20
# 2                         NaT 2023-09-14 00:08:44
# 3                         NaT 2023-09-13 20:12:12
# 4                         NaT 2023-09-15 08:58:31
# 5                         NaT 2023-09-14 17:35:33
# 6                         NaT 2023-09-16 17:07:25
# 7                         NaT 2023-09-15 13:59:51

# %%
# EXECUTING SOLUTION
for name in anomalies_df['Name'].unique():  

    # Fixing the code with .loc[] for proper assignment
    pivoted_TOR330.loc[pivoted_TOR330['Name'] == name, 'FINISH'] = pd.NaT
    pivoted_TOR330.loc[pivoted_TOR330['Name'] == name, 'Status'] = False

# %%
# Looking for runners who have FINISHED< BUT dont haave a finish time!
anomalies_df = pivoted_TOR330[((pivoted_TOR330['Status'] == True) 
#                               &(pivoted_TOR330['FINISH'] == pd.NaT) 
                              )&
                              
                              (
                                  (pivoted_TOR330['Bosses'].isna()) |                
               (pivoted_TOR330['Rifugio Frassati'].isna()) | 
               (pivoted_TOR330['Pas Entre Deux Sauts'].isna()) |
               (pivoted_TOR330['Monte de la Saxe'].isna())
                              )]

anomalies_df[[ 'Name', 'Bib', 'Year', 'Race', 'Status',  'START',
    	'Ollomont IN',	'Ollomont OUT',
    'Rifugio Champillon', 'Ponteille Desot',
    'Bosses',	'Rifugio Frassati',	'Pas Entre Deux Sauts',	'Monte de la Saxe',
    'FINISH']]

### Conclusion: Easily visible that there are several other places that have missing values
# Out:
# aid_stations                             Name   Bib  Year    Race  Status  \
# 80                           Bertrand Ludovic   190  2023  TOR330    True
# 882                             Pupier Samuel   310  2023  TOR330    True
# 807           Parra Hernandez Vicente ( Tito)   658  2023  TOR330    True
# 29                                Arnus Matej  1023  2023  TOR330    True
# 708                            Mondin Placido  1155  2023  TOR330    True
# 1011                        Slobodzian Fabien  1170  2023  TOR330    True
# 1059                         Tanaka Yoshikazu  1219  2023  TOR330    True
# 206                          Cheung Ming Fung  1311  2023  TOR330    True
# 441                             Gostan Bojana  1469  2023  TOR330    True
# 1170                                 Wu Yihua  1514  2023  TOR330    True
# 918                           Rigolli Armando  1550  2023  TOR330    True
# 1145                            Vilardo Alfia  1562  2023  TOR330    True
#
# aid_stations               START         Ollomont IN        Ollomont OUT  \
# 80           2023-09-10 09:27:13 2023-09-15 16:49:39 2023-09-15 18:58:30
# 882          2023-09-10 09:26:21 2023-09-15 14:58:35 2023-09-15 17:24:12
# 807          2023-09-10 09:24:35 2023-09-13 17:39:03 2023-09-13 18:24:25
# 29           2023-09-10 11:50:16 2023-09-15 18:25:45 2023-09-15 20:51:57
# 708          2023-09-10 11:22:22 2023-09-15 18:38:55 2023-09-15 20:07:43
# 1011         2023-09-10 11:29:39 2023-09-15 15:57:01                 NaT
# 1059         2023-09-10 11:29:37 2023-09-15 17:23:46 2023-09-15 20:28:03
# 206                          NaT 2023-09-15 18:50:14 2023-09-15 20:53:50
# 441          2023-09-10 11:50:16 2023-09-15 18:25:43 2023-09-15 20:52:03
# 1170         2023-09-10 11:37:48 2023-09-15 03:40:06 2023-09-15 07:19:56
# 918          2023-09-10 11:39:41 2023-09-15 17:54:33 2023-09-15 20:53:40
# 1145         2023-09-10 11:39:29 2023-09-15 18:04:38 2023-09-15 20:53:43
#
# aid_stations  Rifugio Champillon     Ponteille Desot              Bosses  \
# 80           2023-09-15 21:26:58 2023-09-16 01:12:28 2023-09-16 04:49:52
# 882          2023-09-15 19:36:02 2023-09-15 23:11:20 2023-09-16 02:54:04
# 807          2023-09-13 20:12:45 2023-09-13 22:22:38 2023-09-14 00:35:51
# 29                           NaT 2023-09-16 02:26:03 2023-09-16 05:49:02
# 708                          NaT 2023-09-16 03:40:47 2023-09-16 06:41:41
# 1011         2023-09-15 19:59:07 2023-09-15 23:11:28 2023-09-16 03:31:01
# 1059                         NaT 2023-09-16 02:57:20 2023-09-16 05:35:45
# 206                          NaT 2023-09-16 02:00:11 2023-09-16 04:36:26
# 441                          NaT 2023-09-16 02:25:54 2023-09-16 05:49:24
# 1170         2023-09-15 09:07:56 2023-09-15 11:23:57 2023-09-15 13:14:06
# 918                          NaT 2023-09-16 03:18:03 2023-09-16 06:28:01
# 1145                         NaT 2023-09-16 03:17:56 2023-09-16 06:27:51
#
# aid_stations    Rifugio Frassati Pas Entre Deux Sauts    Monte de la Saxe  \
# 80           2023-09-16 08:32:26                  NaT 2023-09-16 14:57:31
# 882                          NaT  2023-09-16 10:13:44 2023-09-16 12:29:40
# 807          2023-09-14 03:46:25  2023-09-14 07:16:29                 NaT
# 29           2023-09-16 10:06:33                  NaT 2023-09-16 15:26:22
# 708          2023-09-16 10:11:26                  NaT 2023-09-16 17:06:09
# 1011         2023-09-16 09:13:30                  NaT 2023-09-16 15:19:13
# 1059         2023-09-16 09:09:39                  NaT 2023-09-16 14:43:13
# 206          2023-09-16 09:22:07                  NaT 2023-09-16 14:31:01
# 441          2023-09-16 10:06:29                  NaT 2023-09-16 15:26:26
# 1170         2023-09-15 17:01:51  2023-09-15 19:15:45                 NaT
# 918          2023-09-16 09:51:24                  NaT 2023-09-16 15:09:47
# 1145         2023-09-16 09:51:45                  NaT 2023-09-16 15:10:23
#
# aid_stations              FINISH
# 80           2023-09-16 15:50:53
# 882          2023-09-16 13:55:31
# 807          2023-09-14 09:26:12
# 29           2023-09-16 16:52:17
# 708          2023-09-16 20:05:50
# 1011         2023-09-16 17:03:30
# 1059         2023-09-16 16:13:06
# 206          2023-09-16 15:26:37
# 441          2023-09-16 16:52:07
# 1170         2023-09-15 22:12:44
# 918          2023-09-16 16:39:56
# 1145         2023-09-16 16:39:56

# %%
counting_finish_DNF_dataset(pivoted_TOR330)
find_out_the_rows_difference_between_datasets(pivoted_TOR330)
counting_groupby_dataset(pivoted_TOR330,  'Status')
# Out:
# TOR330 2023
# # of Partipants: 1206
# # of Finishers: 622
# # of DNFs: 584
# ********************
# TOR330 2023
# # ITRA rows:  621
# # DUV rows:  621
# # TOR330 rows:  622
#
#  ********************
# TOR330 2023
# # of Partipants: 1206
#
# Status
# False    584
# True     622
# Name: Status, dtype: int64
# ********************

# %% [markdown]
# ### Start Line Issues
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# START times are all over the place and this is a MAJOR issue!
# It is important because if the start is not cleaned, it will affet the race finishing time and all the durations in between.
#
#
# #### SOLUTION
# 1) Made a new TIME column from DUV dates
#
# 2) added start times based on the wave (based on the bib)

# %% [markdown]
# ##### Reading in TORX dates extracted from DUV

# %%
file = f'Database Data/TORX_duv_dates_df.xlsx'
dates_duv_df = pd.read_excel(file)

# Drop the intermediate columns if they're no longer needed
dates_duv_df = dates_duv_df.drop(columns=['Day_of_Week Start_Date'])    
dates_duv_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Race        26 non-null     object
#  1   Year        26 non-null     int64
#  2   Start Date  26 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 752.0+ bytes

# %%
dates_duv_df[dates_duv_df['Race'] =='TOR330']
# Out:
#       Race  Year          Start Date
# 7   TOR330  2023 2023-09-10 10:00:00
# 8   TOR330  2021 2021-09-12 10:00:00
# 9   TOR330  2017 2017-09-10 10:00:00
# 10  TOR330  2024 2024-09-08 10:00:00
# 11  TOR330  2013 2013-09-08 10:00:00
# 12  TOR330  2022 2022-09-11 10:00:00
# 13  TOR330  2014 2014-09-07 10:00:00
# 14  TOR330  2019 2019-09-08 10:00:00
# 15  TOR330  2018 2018-09-09 10:00:00
# 16  TOR330  2016 2016-09-11 10:00:00
# 17  TOR330  2012 2012-09-09 10:00:00
# 18  TOR330  2011 2011-09-11 10:00:00
# 19  TOR330  2015 2015-09-13 10:00:00
# 20  TOR330  2010 2010-09-12 10:00:00

# %% [markdown]
# ### Adding dates into TOR330

# %%
# making sure both columns are years!
pivoted_TOR330['Year'] = pivoted_TOR330['Year'].astype('str')
dates_duv_df['Year'] = dates_duv_df['Year'].astype('str')

# have I dropped any rows?
print(pivoted_TOR330.shape)

# Merging on two columns: 'Race' and 'Year'
pivoted_TOR330_dates = pd.merge(pivoted_TOR330, dates_duv_df, on=['Race', 'Year'], how='inner')

# have I dropped any rows?
print(pivoted_TOR330_dates.shape)
# Out:
# (1206, 58)
# (1206, 59)

# %%
# Following the assumption that every bib prior to 1001 starts at 10:00:00
pivoted_TOR330_dates['new_Start Date'] = np.where(
    pivoted_TOR330_dates['Bib'] < 1001, 
        pivoted_TOR330_dates['Start Date'], 
        pivoted_TOR330_dates['Start Date'] + pd.to_timedelta('02:00:00'))

# Following the assumption that every bib from 1001 onwards starts at 12:00:00
pivoted_TOR330_dates['Wave'] = np.where(
    pivoted_TOR330_dates['Bib'] <= 1001, 
        'Wave1', 
        'Wave2')

# %%
pivoted_TOR330_dates[['Bib','Name', 'Race', 'Year',  
                'new_Start Date', 'La Thuile', 'Valgrisenche IN',
                'Donnas IN', 'Gressoney IN']][pivoted_TOR330_dates['Bib']< 1001].sort_values(by = 'Bib', ascending = True).reset_index(drop = True).head()
# Out:
#    Bib            Name    Race  Year      new_Start Date           La Thuile  \
# 0    1     Russi Jonas  TOR330  2023 2023-09-10 10:00:00                 NaT
# 1    2    Colle Franco  TOR330  2023 2023-09-10 10:00:00 2023-09-10 12:20:19
# 2    3  Corsini Simone  TOR330  2023 2023-09-10 10:00:00                 NaT
# 3    4     Doi Takashi  TOR330  2023 2023-09-10 10:00:00 2023-09-10 12:28:16
# 4    5   Macchi Andrea  TOR330  2023 2023-09-10 10:00:00 2023-09-10 12:20:48
#
#       Valgrisenche IN           Donnas IN        Gressoney IN
# 0                 NaT                 NaT                 NaT
# 1 2023-09-10 17:05:31 2023-09-11 09:49:05 2023-09-11 21:42:32
# 2                 NaT                 NaT                 NaT
# 3 2023-09-10 17:56:34 2023-09-11 13:29:00 2023-09-12 07:38:12
# 4 2023-09-10 17:05:39                 NaT                 NaT

# %%
pivoted_TOR330_dates[['Bib','Name', 'Race', 'Year',  
                'new_Start Date', 'La Thuile', 'Valgrisenche IN',
                'Donnas IN', 'Gressoney IN']][pivoted_TOR330_dates['Bib']> 1001].sort_values(by = 'Bib', ascending = True).reset_index(drop = True).head()
# Out:
#     Bib               Name    Race  Year      new_Start Date  \
# 0  1002       Vukman Marin  TOR330  2023 2023-09-10 12:00:00
# 1  1003      Vezzaro Paolo  TOR330  2023 2023-09-10 12:00:00
# 2  1004  Biarese Raffaella  TOR330  2023 2023-09-10 12:00:00
# 3  1005      Thoma Claudia  TOR330  2023 2023-09-10 12:00:00
# 4  1006    Massalin Andrea  TOR330  2023 2023-09-10 12:00:00
#
#             La Thuile     Valgrisenche IN           Donnas IN  \
# 0 2023-09-10 15:34:59 2023-09-11 00:04:59 2023-09-12 11:42:28
# 1 2023-09-10 15:57:49 2023-09-11 00:45:18 2023-09-12 14:30:53
# 2 2023-09-10 15:57:45 2023-09-11 00:45:06 2023-09-12 14:31:08
# 3 2023-09-10 16:19:04 2023-09-11 02:15:55 2023-09-12 16:35:24
# 4 2023-09-10 16:00:26 2023-09-11 02:26:40 2023-09-12 16:36:28
#
#          Gressoney IN
# 0 2023-09-13 19:27:13
# 1 2023-09-13 18:45:25
# 2 2023-09-13 18:44:47
# 3 2023-09-13 21:21:36
# 4 2023-09-14 00:06:34

# %%
# Plot the histogram
plt.figure(figsize=(10, 6))
plt.hist(pivoted_TOR330_dates['Bib'], bins=16, color='skyblue', edgecolor='black')
plt.title(f'Histogram of Bibs')
plt.xlabel('Bib ')
plt.ylabel('Frequency')
plt.show()

# %%
### WHich wave is more likely to finish? 
### Wave 1 seems to have way more finishers - they do have a higher ITRA score, meaning that they are more
### experienced and stronger than Wave 2..
pivoted_TOR330_dates.groupby(['Wave', 'Status'])['Status'].size()
# Out:
# Wave   Status
# Wave1  False     239
#        True      409
# Wave2  False     345
#        True      213
# Name: Status, dtype: int64

# %% [markdown]
# ### Calculating Duration - THE MOST IMPORTANT!

# %%
# Calculate Duration
pivoted_TOR330_dates['Duration'] = pivoted_TOR330_dates['FINISH'] - pivoted_TOR330_dates['new_Start Date'] 

# Sort the DataFrame by the 'Duration' column
pivoted_TOR330_dates = pivoted_TOR330_dates.sort_values(by='Duration')

# %%
print(f"Processing column: Duration")
print(pivoted_TOR330_dates['Duration'].head())


pivoted_TOR330_dates['Duration']
# Convert to timedelta and get total hours (handling NaT)
pivoted_TOR330_dates['Duration_hours'] = pd.to_timedelta(
    pivoted_TOR330_dates['Duration'], errors='coerce'
).dt.total_seconds() / 3600  # Convert seconds to hours

# Drop NaN values for histogram visualization
data_to_plot = pivoted_TOR330_dates['Duration_hours'].dropna()

# Plot the histogram
plt.figure(figsize=(8, 5))
sns.histplot(data_to_plot, kde=True, bins=30, color="lightcoral")
plt.ticklabel_format(style='plain', axis='x')
plt.title(f"Distribution of Duration (in Hours)")
plt.xlabel("Time (hours)")
plt.ylabel("Frequency")
plt.show()
# Out:
# Processing column: Duration
# 1     2 days 18:39:16
# 643   2 days 21:49:38
# 5     2 days 23:22:30
# 19    3 days 00:04:07
# 629   3 days 00:16:06
# Name: Duration, dtype: timedelta64[ns]

# %%
# Reorder the columns in the correct order
pivoted_TOR330_dates = pivoted_TOR330_dates[[
        'Name', 'Bib', 'Sex', 'Nationality', 'Year', 'Race', 
        'Category', 'Status','Wave', 'Duration', # MOVING DURATION CLOSER TO THE START SO I CAN SEE IT!
        
        'new_Start Date', 'Baite Youlaz', 'La Thuile', 'Rifugio Deffeyes',
         'Planaval', 'Valgrisenche IN', 'Valgrisenche OUT',
        'Chalet Epee', 'Rhemes-Notre-Dame', 'Eaux Rousse', 'Rifugio Sella',
        'Cogne IN', 'Cogne OUT', 'Goilles', 'Rifugio Dondena', 'Chardonney',
        'Pontboset', 'Donnas IN', 'Donnas OUT', 'Perloz', 'Sassa',
        'Rifugio Coda', 'Rifugio della Barma', 'Lago Chiaro',
        'Col della Vecchia', 'Niel La Gruba', 'Loo', 'Gressoney IN',
        'Gressoney OUT', 'Rifugio Alpenzu', 'Champoluc',
        'Rifugio Grand Tournalin', 'Valtournenche IN', 'Valtournenche OUT',
        'Rifugio Barmasse', 'Vareton', 'Rifugio Magià', 'Rifugio Cuney',
        'Bivacco R. Clermont', 'Oyace', 'Bruson Arp', 
         'Ollomont IN', 'Ollomont OUT', 'Rifugio Champillon',
        'Ponteille Desot', 'Bosses', 'Rifugio Frassati', 'Pas Entre Deux Sauts',
        'Monte de la Saxe', 'FINISH'
]]

# %% [markdown]
# ### Checking accuracy of the Duration calculation
#
# Because of issues with Start Date, it was thought that it would be a good idea to try and compare the DUV and ITRA duration time to establish accuracy of the calculation...
#
# There are issues with the names, so some will be not be successfully merged.

# %%
# print(pivoted_TOR330_dates['Duration'][pivoted_TOR330_dates['Name'].str.contains('Jonina')])
# # print(TORX_duv_df['Performance'][TORX_duv_df['Name'].str.contains('Jonina')])
# # Finished in 144:46:43 hours and

# %%
counting_finish_DNF_dataset(pivoted_TOR330)
find_out_the_rows_difference_between_datasets(pivoted_TOR330)
counting_groupby_dataset(pivoted_TOR330,  'Status')
# Out:
# TOR330 2023
# # of Partipants: 1206
# # of Finishers: 622
# # of DNFs: 584
# ********************
# TOR330 2023
# # ITRA rows:  621
# # DUV rows:  621
# # TOR330 rows:  622
#
#  ********************
# TOR330 2023
# # of Partipants: 1206
#
# Status
# False    584
# True     622
# Name: Status, dtype: int64
# ********************

# %% [markdown]
# ## extracting DNF and FInisher's for more cleaning!

# %%
pivoted_TOR330_dates_noDNF = pivoted_TOR330_dates[
                        # extracting runners whose status is True (Finished)
                        (pivoted_TOR330_dates['Status'] == True) &
                    ~(pivoted_TOR330_dates['FINISH'].isna())].reset_index()

# %%
pivoted_TOR330_dates_DNF = pivoted_TOR330_dates[
                    # selecting all rows that DNFed
                    (pivoted_TOR330_dates['Status'] == False) & # AND
                    # selecting all rows where FINISH does not have a time
                    (pivoted_TOR330_dates['FINISH'].isna())]

# %%
print(pivoted_TOR330_dates_noDNF.shape)
print(pivoted_TOR330_dates_DNF.shape)
print('MUST ADD UP TO:')
print(pivoted_TOR330_dates.shape)
# Out:
# (622, 61)
# (584, 60)
# MUST ADD UP TO:
# (1206, 60)

# %% [markdown]
# ### FINISHER'S Missing Timestamps
# From time to time, timestamps are missing, even for finishers. Here is the missing values count for all finishers.
#
# THis is could be for several issues:
# 1) Participant's Fatigue - they forget to ask to be scanned
#
# 2) Volunteer's Fatigue - they forget to scan participants /  they thought they had already scanned the runer
#
# 3) Technology Failure - something goes wrong... ?
# ![image.png](attachment:image.png)
#
# This is just a screenshot, more can be seen below!

# %%
print(f'{year} - FINISHER\'S Timestamp Missing Values')
for i in pivoted_TOR330_dates_noDNF.columns:
    missing_value_count =  pivoted_TOR330_dates_noDNF[i].isna().sum()
    
    if missing_value_count != 0:
        print(' ',i,missing_value_count)
# Out:
# 2023 - FINISHER'S Timestamp Missing Values
#   Baite Youlaz 1
#   La Thuile 1
#   Rifugio Deffeyes 1
#   Valgrisenche OUT 1
#   Chalet Epee 5
#   Rhemes-Notre-Dame 2
#   Rifugio Sella 148
#   Cogne IN 3
#   Cogne OUT 31
#   Goilles 1
#   Rifugio Dondena 7
#   Pontboset 7
#   Donnas IN 4
#   Donnas OUT 9
#   Perloz 2
#   Sassa 5
#   Rifugio della Barma 2
#   Lago Chiaro 8
#   Col della Vecchia 4
#   Niel La Gruba 1
#   Gressoney OUT 3
#   Rifugio Alpenzu 1
#   Champoluc 1
#   Rifugio Grand Tournalin 4
#   Valtournenche OUT 5
#   Rifugio Barmasse 2
#   Vareton 3
#   Rifugio Magià 2
#   Rifugio Cuney 2
#   Bruson Arp 10
#   Ollomont IN 5
#   Ollomont OUT 16
#   Rifugio Champillon 32
#   Ponteille Desot 2
#   Rifugio Frassati 1
#   Pas Entre Deux Sauts 9
#   Monte de la Saxe 2

# %% [markdown]
# ### DNFs

# %%
#### What missing values are there? 
### Some missing value is okay due to the fact that they DNFed so they wont have a timestamp
pivoted_TOR330_dates_DNF.isna().sum()
# Out:
# Name                         0
# Bib                          0
# Sex                          0
# Nationality                  0
# Year                         0
# Race                         0
# Category                     0
# Status                       0
# Wave                         0
# Duration                   584
# new_Start Date               0
# Baite Youlaz               117
# La Thuile                  119
# Rifugio Deffeyes           131
# Planaval                   149
# Valgrisenche IN            155
# Valgrisenche OUT           202
# Chalet Epee                248
# Rhemes-Notre-Dame          222
# Eaux Rousse                253
# Rifugio Sella              334
# Cogne IN                   316
# Cogne OUT                  347
# Goilles                    344
# Rifugio Dondena            353
# Chardonney                 353
# Pontboset                  363
# Donnas IN                  358
# Donnas OUT                 362
# Perloz                     374
# Sassa                      384
# Rifugio Coda               391
# Rifugio della Barma        400
# Lago Chiaro                422
# Col della Vecchia          431
# Niel La Gruba              449
# Loo                        477
# Gressoney IN               502
# Gressoney OUT              470
# Rifugio Alpenzu            523
# Champoluc                  522
# Rifugio Grand Tournalin    534
# Valtournenche IN           535
# Valtournenche OUT          533
# Rifugio Barmasse           540
# Vareton                    541
# Rifugio Magià              543
# Rifugio Cuney              553
# Bivacco R. Clermont        557
# Oyace                      554
# Bruson Arp                 564
# Ollomont IN                572
# Ollomont OUT               571
# Rifugio Champillon         578
# Ponteille Desot            576
# Bosses                     579
# Rifugio Frassati           584
# Pas Entre Deux Sauts       584
# Monte de la Saxe           584
# FINISH                     584
# dtype: int64

# %% [markdown]
# ### What is the last place that DNFers reached?

# %%
# Function to find the last non-blank column
def get_last_non_blank(row):
    for col in reversed(row.index):
        if pd.notna(row[col]):  # Check if the value is not NaN
#             print(col)
            return col
#     return None  # In case all columns are blank

# # Apply the function to each row and assign the result to 'Retired'
pivoted_TOR330_dates['Retired'] = np.where(pivoted_TOR330_dates['Status'] == False, 
                                               pivoted_TOR330_dates.apply(get_last_non_blank, axis=1),
                                               np.nan)

# %%
pivoted_TOR330_dates = pivoted_TOR330_dates[['Name', 'Bib',
                                                     'Sex', 'Nationality',
                                                     'Year', 'Race', 
                                                     'Category', 'Status', 'Wave', 'Duration', 
                                                      'Retired', # putting retired at the from and not the back
                                                     'new_Start Date',
       'Baite Youlaz', 'La Thuile', 'Rifugio Deffeyes', 
       'Planaval', 'Valgrisenche IN', 'Valgrisenche OUT', 'Chalet Epee',
       'Rhemes-Notre-Dame', 'Eaux Rousse', 'Rifugio Sella', 'Cogne IN',
       'Cogne OUT', 'Goilles', 'Rifugio Dondena', 'Chardonney', 'Pontboset',
       'Donnas IN', 'Donnas OUT', 'Perloz', 'Sassa', 'Rifugio Coda',
       'Rifugio della Barma', 'Lago Chiaro', 'Col della Vecchia',
       'Niel La Gruba', 'Loo', 'Gressoney IN', 'Gressoney OUT',
       'Rifugio Alpenzu', 'Champoluc', 'Rifugio Grand Tournalin',
       'Valtournenche IN', 'Valtournenche OUT', 'Rifugio Barmasse', 'Vareton',
       'Rifugio Magià', 'Rifugio Cuney', 'Bivacco R. Clermont', 'Oyace',
       'Bruson Arp',   'Ollomont IN',
       'Ollomont OUT', 'Rifugio Champillon', 'Ponteille Desot', 'Bosses',
       'Rifugio Frassati', 'Pas Entre Deux Sauts', 'Monte de la Saxe',
       'FINISH']]

# %%
# creating a dataset to examine DNFs in the excel
pivoted_TOR330_dates_DNF_for_excel = pivoted_TOR330_dates_DNF.copy().drop(columns=['Sex', 'Nationality',
                                                          'Category', 'Status', 
                                                          'Wave', 'Duration'])    
# for year in years:
#     pivoted_TOR330_dates_DNF_for_excel.to_excel(f'TOR330 Data/DNF/DNF_df_{year}.xlsx', index = False)

# %%
pivoted_TOR330_dates[pivoted_TOR330_dates['Status'] == True].head(1)
# Out:
#            Name  Bib Sex Nationality  Year    Race Category  Status   Wave  \
# 1  Colle Franco    2   M          IT  2023  TOR330       V1    True  Wave1
#
#          Duration  ... Bruson Arp         Ollomont IN        Ollomont OUT  \
# 1 2 days 18:39:16  ...        NaT 2023-09-12 17:57:48 2023-09-12 17:57:55
#
#    Rifugio Champillon     Ponteille Desot              Bosses  \
# 1 2023-09-12 19:36:02 2023-09-12 21:04:38 2023-09-12 22:30:41
#
#      Rifugio Frassati Pas Entre Deux Sauts    Monte de la Saxe  \
# 1 2023-09-13 00:45:25  2023-09-13 02:23:36 2023-09-13 03:52:25
#
#                FINISH
# 1 2023-09-13 04:39:16
#
# [1 rows x 61 columns]

# %% [markdown]
# ### Issues with Last location Detected
# Some people who too far of a distance between last lifebase /  refuge / checkpoint for it to be an accurate representation of their last location.
#
# 2023
# ![image-2.png](attachment:image-2.png)
#
# 2024
#
# ![image-3.png](attachment:image-3.png)
#
# ##### Solution
# Create a loop that would clean those timestamps.

# %%
try:
    if year == '2023':

        names_that_DNFed_and_then_popped_up_miles_away =['Utinek Vaclav', 'Walsh Padraic',
                                                        'Ferraris Maurizio', 
    # 'Buonocore Gian Mario', 'Forestiero Alessandro', ## Have 2 timestamps of time travel
                                                         'Forrest Steve','Koehling Sebastien'
                                                        ]
        retired_list = list(pivoted_TOR330_dates['Retired'][
            pivoted_TOR330_dates['Name'].isin(names_that_DNFed_and_then_popped_up_miles_away)].unique())
        print(retired_list)

        for index, row in pivoted_TOR330_dates[pivoted_TOR330_dates['Name'].isin(names_that_DNFed_and_then_popped_up_miles_away)].iterrows():
            retired_column = row['Retired']  # Get the column name in 'Retired'


            if retired_column in retired_list:
                pivoted_TOR330_dates.at[index, retired_column] = pd.NaT

        # Prepending 'Name' and 'Bib' to the list
        retired_list = ['Name', 'Bib'] + retired_list  + ['Retired']
        print(retired_list)

    elif year == '2024':
        names_that_DNFed_and_then_popped_up_miles_away =['Micheletti Luciano', 'Minoggio Sergio','Minoggio Stefano', 
                                                        'Park Kwangwon',  ## Has 2 time teleportation 
                                                        'Peretto Cristiana', ## Has 2 time teleportation 
                                                        'Sebastien Gerard', 'Vazzoler Enrico', 'Vinzia Alain']

        for index, row in pivoted_TOR330_dates[pivoted_TOR330_dates['Name'].isin(names_that_DNFed_and_then_popped_up_miles_away)].iterrows():
            # Get the column name in 'Retired'
            retired_column = row['Retired']

            retired_list = list(pivoted_TOR330_dates['Retired'][
                pivoted_TOR330_dates['Name'].isin(names_that_DNFed_and_then_popped_up_miles_away)].unique())

            if row['Name'] == 'Park Kwangwon':
                # Has 2 cases of teletransportation
                pivoted_TOR330_dates.at[index, 'Pas Entre Deux Sauts'] = pd.NaT
                pivoted_TOR330_dates.at[index, 'Monte de la Saxe'] = pd.NaT

            elif row['Name'] == 'Peretto Cristiana':
                # Has 2 cases of teletransportation
                pivoted_TOR330_dates.at[index, 'Rifugio Champillon'] = pd.NaT
                pivoted_TOR330_dates.at[index, 'Bruson Arp'] = pd.NaT

            else:

                if retired_column in retired_list:
                    pivoted_TOR330_dates.at[index, retired_column] = pd.NaT

        retired_list = ['Name', 'Bib'] + retired_list + ['Retired']
        print(retired_list)

     # Display the updated DataFrame
    pivoted_TOR330_dates[retired_list][pivoted_TOR330_dates['Name'].isin(names_that_DNFed_and_then_popped_up_miles_away)]

except:
    pass
# Out:
# ['Rifugio Dondena', 'Bruson Arp', 'Gressoney OUT', 'Gressoney IN']
# ['Name', 'Bib', 'Rifugio Dondena', 'Bruson Arp', 'Gressoney OUT', 'Gressoney IN', 'Retired']

# %%
# Dropping the column retired otherwise it is going to think that RETIRED is the last column
pivoted_TOR330_dates = pivoted_TOR330_dates.drop(columns=['Retired'])    

# # Apply the function to each row and assign the result to 'Retired'
pivoted_TOR330_dates['Retired'] = np.where(pivoted_TOR330_dates['Status'] == False, 
                                               pivoted_TOR330_dates.apply(get_last_non_blank, axis=1),
                                               np.nan)

# %%
pivoted_TOR330_dates.head()
# Out:
#                  Name  Bib Sex Nationality  Year    Race Category  Status  \
# 1        Colle Franco    2   M          IT  2023  TOR330       V1    True
# 643    Romain Olivier  662   M          FR  2023  TOR330      SEN    True
# 5      Reynolds Galen    6   M          CA  2023  TOR330      SEN    True
# 19        Hall Damian   20   M          GB  2023  TOR330       V1    True
# 629  Galeati Gianluca  647   M          IT  2023  TOR330       V1    True
#
#       Wave        Duration  ...         Ollomont IN        Ollomont OUT  \
# 1    Wave1 2 days 18:39:16  ... 2023-09-12 17:57:48 2023-09-12 17:57:55
# 643  Wave1 2 days 21:49:38  ... 2023-09-12 18:42:27 2023-09-12 19:18:53
# 5    Wave1 2 days 23:22:30  ... 2023-09-12 22:44:14 2023-09-12 23:12:37
# 19   Wave1 3 days 00:04:07  ... 2023-09-12 22:44:22 2023-09-12 23:12:43
# 629  Wave1 3 days 00:16:06  ... 2023-09-12 22:42:45 2023-09-12 23:04:24
#
#      Rifugio Champillon     Ponteille Desot              Bosses  \
# 1   2023-09-12 19:36:02 2023-09-12 21:04:38 2023-09-12 22:30:41
# 643 2023-09-12 20:52:03 2023-09-12 22:37:52 2023-09-13 00:19:25
# 5   2023-09-13 00:32:25 2023-09-13 01:52:21 2023-09-13 03:10:12
# 19  2023-09-13 00:36:43 2023-09-13 01:59:30 2023-09-13 03:33:35
# 629 2023-09-13 00:39:06 2023-09-13 02:09:40 2023-09-13 03:58:37
#
#        Rifugio Frassati Pas Entre Deux Sauts    Monte de la Saxe  \
# 1   2023-09-13 00:45:25  2023-09-13 02:23:36 2023-09-13 03:52:25
# 643 2023-09-13 03:29:59  2023-09-13 05:45:09 2023-09-13 07:13:28
# 5   2023-09-13 05:36:50  2023-09-13 07:12:51 2023-09-13 08:41:42
# 19  2023-09-13 06:28:38  2023-09-13 08:03:24 2023-09-13 09:29:29
# 629 2023-09-13 06:28:51  2023-09-13 08:04:05 2023-09-13 09:33:49
#
#                  FINISH Retired
# 1   2023-09-13 04:39:16     NaN
# 643 2023-09-13 07:49:38     NaN
# 5   2023-09-13 09:22:30     NaN
# 19  2023-09-13 10:04:07     NaN
# 629 2023-09-13 10:16:06     NaN
#
# [5 rows x 61 columns]

# %% [markdown]
# ###  Unpredictable Weather of 2022
# In 2022, due to the weather,  the race directors decided to stop the race at Bosses and Refuge Frassati.

# %%
pivoted_TOR330_dates['Status1'] = pivoted_TOR330_dates['Status'].astype('str')
# print(pivoted_TOR330_dates['Status1'].unique())

for year in years:
    if year == '2022':
        # Update 'Status1' for year 2022
        pivoted_TOR330_dates.loc[
            pivoted_TOR330_dates['Year'] == year, 'Status1'
        ] = pivoted_TOR330_dates.loc[
            pivoted_TOR330_dates['Year'] == year, 'Status1'
        ].str.replace('True', 'Finished')

        # For finishers at Bosses
        pivoted_TOR330_dates.loc[
            (pivoted_TOR330_dates['Year'] == year) & (pivoted_TOR330_dates['Retired'] == 'Bosses'), 'Status1'
        ] = pivoted_TOR330_dates.loc[
            (pivoted_TOR330_dates['Year'] == year) & (pivoted_TOR330_dates['Retired'] == 'Bosses'), 'Status1'
        ].str.replace('False', 'Finished at Bosses')

        # For finishers at Rifugio Frassati
        pivoted_TOR330_dates.loc[
            (pivoted_TOR330_dates['Year'] == year) & (pivoted_TOR330_dates['Retired'] == 'Rifugio Frassati'), 'Status1'
        ] = pivoted_TOR330_dates.loc[
            (pivoted_TOR330_dates['Year'] == year) & (pivoted_TOR330_dates['Retired'] == 'Rifugio Frassati'), 'Status1'
        ].str.replace('False', 'Rifugio Frassati')

        # For finishers at Rifugio Frassati
        pivoted_TOR330_dates.loc[
            (pivoted_TOR330_dates['Year'] == year) & (pivoted_TOR330_dates['Retired'] == 'Rifugio Frassati'), 'Status1'
        ] = pivoted_TOR330_dates.loc[
            (pivoted_TOR330_dates['Year'] == year) & (pivoted_TOR330_dates['Retired'] == 'Rifugio Frassati'), 'Status1'
        ].str.replace('False', 'Rifugio Frassati')

        
        
        # All other DNFs
        pivoted_TOR330_dates.loc[
            (pivoted_TOR330_dates['Year'] == year)
            & ~(pivoted_TOR330_dates['Retired'].isin(['Bosses', 'Rifugio Frassati'])), 'Status1'
        ] = pivoted_TOR330_dates.loc[
            (pivoted_TOR330_dates['Year'] == year)
            & ~(pivoted_TOR330_dates['Retired'].isin(['Bosses', 'Rifugio Frassati'])), 'Status1'
        ].str.replace('False', 'DNFs')
        
        
        
        
        
    else:
        
        print(year)
        # Update 'Status1' for years other than 2022
        pivoted_TOR330_dates.loc[pivoted_TOR330_dates['Year'] == year, 'Status1'] = (
            pivoted_TOR330_dates.loc[pivoted_TOR330_dates['Year'] == year, 'Status1']
            .str.replace('True', 'Finished')
            .str.replace('False', 'DNF')
        )
        print(pivoted_TOR330_dates['Status1'].unique())
# Out:
# 2023
# ['Finished' 'DNF']

# %%
pivoted_TOR330_dates['Status1'].unique()
# Out:
# array(['Finished', 'DNF'], dtype=object)

# %%
counting_finish_DNF_dataset(pivoted_TOR330_dates)
find_out_the_rows_difference_between_datasets(pivoted_TOR330_dates)
pivoted_TOR330_dates.groupby('Status1')['Status1'].count()
# Out:
# TOR330 2023
# # of Partipants: 1206
# # of Finishers: 622
# # of DNFs: 584
# ********************
# TOR330 2023
# # ITRA rows:  621
# # DUV rows:  621
# # TOR330 rows:  622
#
#  ********************
# Status1
# DNF         584
# Finished    622
# Name: Status1, dtype: int64

# %%
# pd.set_option('display.max_columns', None)  # Show all columns
# pd.set_option('display.max_rows', None)     # Show all rows

# %% [markdown]
# ### Where did the DNFs occur?

# %%
pivoted_TOR330_dates['Retired'] = pivoted_TOR330_dates['Retired'].str.replace(' IN', '')
pivoted_TOR330_dates['Retired'] = pivoted_TOR330_dates['Retired'].str.replace(' OUT', '')

# %%
Stage1 = ['Baite Youlaz', 'La Thuile', 'Rifugio Deffeyes', 
             'Planaval', 'Valgrisenche']
Stage2 = [ 'Chalet Epee', 'Rhemes-Notre-Dame',
            'Eaux Rousse', 'Rifugio Sella', 'Cogne']

Stage3 = [ 'Goilles', 'Rifugio Dondena', 'Chardonney', 'Pontboset', 'Donnas']
Stage4  = ['Perloz', 'Sassa', 'Rifugio Coda',
            'Rifugio della Barma', 'Lago Chiaro', 'Col della Vecchia',
            'Niel La Gruba', 'Loo', 'Gressoney']

Stage5 = ['Rifugio Alpenzu', 'Champoluc', 'Rifugio Grand Tournalin', 'Valtournenche'] 

Stage6 = [ 'Vareton', 'Rifugio Barmasse',
            'Rifugio Magià', 'Rifugio Cuney', 'Bivacco R. Clermont', 'Oyace',
            'Bruson Arp',   'Ollomont']
        
Stage7 = [ 'Rifugio Champillon', 'Ponteille Desot', 'Bosses',
            'Rifugio Frassati', 'Pas Entre Deux Sauts', 'Monte de la Saxe',
            'FINISH']

# finding the low / high season by date
pivoted_TOR330_dates.loc[pivoted_TOR330_dates['Retired'].isin(Stage1), 'Retired_Stage'] = 'Stage 1'
pivoted_TOR330_dates.loc[pivoted_TOR330_dates['Retired'].isin(Stage2), 'Retired_Stage'] = 'Stage 2'
pivoted_TOR330_dates.loc[pivoted_TOR330_dates['Retired'].isin(Stage3), 'Retired_Stage'] = 'Stage 3'
pivoted_TOR330_dates.loc[pivoted_TOR330_dates['Retired'].isin(Stage4), 'Retired_Stage'] = 'Stage 4'
pivoted_TOR330_dates.loc[pivoted_TOR330_dates['Retired'].isin(Stage5), 'Retired_Stage'] = 'Stage 5'
pivoted_TOR330_dates.loc[pivoted_TOR330_dates['Retired'].isin(Stage6), 'Retired_Stage'] = 'Stage 6'
pivoted_TOR330_dates.loc[pivoted_TOR330_dates['Retired'].isin(Stage7), 'Retired_Stage'] = 'Stage 7'
pivoted_TOR330_dates.loc[pivoted_TOR330_dates['Retired'] == 'new_Start Date', 'Retired_Stage'] = 'DNS'
pivoted_TOR330_dates[(pivoted_TOR330_dates['Retired'].isnull())]
# Out:
#                  Name   Bib Sex Nationality  Year    Race Category  Status  \
# 1        Colle Franco     2   M          IT  2023  TOR330       V1    True
# 643    Romain Olivier   662   M          FR  2023  TOR330      SEN    True
# 5      Reynolds Galen     6   M          CA  2023  TOR330      SEN    True
# 19        Hall Damian    20   M          GB  2023  TOR330       V1    True
# 629  Galeati Gianluca   647   M          IT  2023  TOR330       V1    True
# ..                ...   ...  ..         ...   ...     ...      ...     ...
# 407     Tora Lodovico   418   M          IT  2023  TOR330       V2    True
# 575       Tsui Stella   593   F          SG  2023  TOR330      SEN    True
# 184  Bertrand Ludovic   190   M          FR  2023  TOR330       V2    True
# 800    Mondin Placido  1155   M          IT  2023  TOR330       V1    True
# 517      Tibaldi Erik   533   M          IT  2023  TOR330       V1    True
#
#       Wave        Duration  ...  Rifugio Champillon     Ponteille Desot  \
# 1    Wave1 2 days 18:39:16  ... 2023-09-12 19:36:02 2023-09-12 21:04:38
# 643  Wave1 2 days 21:49:38  ... 2023-09-12 20:52:03 2023-09-12 22:37:52
# 5    Wave1 2 days 23:22:30  ... 2023-09-13 00:32:25 2023-09-13 01:52:21
# 19   Wave1 3 days 00:04:07  ... 2023-09-13 00:36:43 2023-09-13 01:59:30
# 629  Wave1 3 days 00:16:06  ... 2023-09-13 00:39:06 2023-09-13 02:09:40
# ..     ...             ...  ...                 ...                 ...
# 407  Wave1 6 days 05:18:23  ... 2023-09-15 21:39:51 2023-09-16 01:52:50
# 575  Wave1 6 days 05:44:12  ...                 NaT 2023-09-16 02:41:44
# 184  Wave1 6 days 05:50:53  ... 2023-09-15 21:26:58 2023-09-16 01:12:28
# 800  Wave2 6 days 08:05:50  ...                 NaT 2023-09-16 03:40:47
# 517  Wave1 6 days 08:15:44  ... 2023-09-15 20:06:59 2023-09-15 23:02:22
#
#                  Bosses    Rifugio Frassati Pas Entre Deux Sauts  \
# 1   2023-09-12 22:30:41 2023-09-13 00:45:25  2023-09-13 02:23:36
# 643 2023-09-13 00:19:25 2023-09-13 03:29:59  2023-09-13 05:45:09
# 5   2023-09-13 03:10:12 2023-09-13 05:36:50  2023-09-13 07:12:51
# 19  2023-09-13 03:33:35 2023-09-13 06:28:38  2023-09-13 08:03:24
# 629 2023-09-13 03:58:37 2023-09-13 06:28:51  2023-09-13 08:04:05
# ..                  ...                 ...                  ...
# 407 2023-09-16 04:04:19 2023-09-16 07:39:05  2023-09-16 11:18:26
# 575 2023-09-16 05:55:16 2023-09-16 09:06:52  2023-09-16 12:15:06
# 184 2023-09-16 04:49:52 2023-09-16 08:32:26                  NaT
# 800 2023-09-16 06:41:41 2023-09-16 10:11:26                  NaT
# 517 2023-09-16 02:20:25 2023-09-16 07:45:53  2023-09-16 12:41:59
#
#        Monte de la Saxe              FINISH Retired   Status1 Retired_Stage
# 1   2023-09-13 03:52:25 2023-09-13 04:39:16     NaN  Finished           NaN
# 643 2023-09-13 07:13:28 2023-09-13 07:49:38     NaN  Finished           NaN
# 5   2023-09-13 08:41:42 2023-09-13 09:22:30     NaN  Finished           NaN
# 19  2023-09-13 09:29:29 2023-09-13 10:04:07     NaN  Finished           NaN
# 629 2023-09-13 09:33:49 2023-09-13 10:16:06     NaN  Finished           NaN
# ..                  ...                 ...     ...       ...           ...
# 407 2023-09-16 14:00:49 2023-09-16 15:18:23     NaN  Finished           NaN
# 575 2023-09-16 14:27:02 2023-09-16 15:44:12     NaN  Finished           NaN
# 184 2023-09-16 14:57:31 2023-09-16 15:50:53     NaN  Finished           NaN
# 800 2023-09-16 17:06:09 2023-09-16 20:05:50     NaN  Finished           NaN
# 517 2023-09-16 16:28:43 2023-09-16 18:15:44     NaN  Finished           NaN
#
# [622 rows x 63 columns]

# %%
# making sure that I caught all aid stations!!!!
pivoted_TOR330_dates[
    (pivoted_TOR330_dates['Status'] == False) &
    
    (pivoted_TOR330_dates['Retired_Stage'].isnull())
                    ]
# Out:
# Empty DataFrame
# Columns: [Name, Bib, Sex, Nationality, Year, Race, Category, Status, Wave, Duration, new_Start Date, Baite Youlaz, La Thuile, Rifugio Deffeyes, Planaval, Valgrisenche IN, Valgrisenche OUT, Chalet Epee, Rhemes-Notre-Dame, Eaux Rousse, Rifugio Sella, Cogne IN, Cogne OUT, Goilles, Rifugio Dondena, Chardonney, Pontboset, Donnas IN, Donnas OUT, Perloz, Sassa, Rifugio Coda, Rifugio della Barma, Lago Chiaro, Col della Vecchia, Niel La Gruba, Loo, Gressoney IN, Gressoney OUT, Rifugio Alpenzu, Champoluc, Rifugio Grand Tournalin, Valtournenche IN, Valtournenche OUT, Rifugio Barmasse, Vareton, Rifugio Magià, Rifugio Cuney, Bivacco R. Clermont, Oyace, Bruson Arp, Ollomont IN, Ollomont OUT, Rifugio Champillon, Ponteille Desot, Bosses, Rifugio Frassati, Pas Entre Deux Sauts, Monte de la Saxe, FINISH, Retired, Status1, Retired_Stage]
# Index: []
#
# [0 rows x 63 columns]

# %%
pivoted_TOR330_dates['Retired_Stage'].unique()
# Out:
# array([nan, 'DNS', 'Stage 3', 'Stage 2', 'Stage 4', 'Stage 6', 'Stage 1',
#        'Stage 5', 'Stage 7'], dtype=object)

# %%
# finding the pre-post Gressoney
pivoted_TOR330_dates.loc[pivoted_TOR330_dates['Retired_Stage'] == 'Stage 1' , 'Pre-Post Gressoney'] ='Pre Gressoney' 
pivoted_TOR330_dates.loc[pivoted_TOR330_dates['Retired_Stage'] == 'Stage 2' , 'Pre-Post Gressoney'] ='Pre Gressoney' 
pivoted_TOR330_dates.loc[pivoted_TOR330_dates['Retired_Stage'] == 'Stage 3' , 'Pre-Post Gressoney'] ='Pre Gressoney' 
pivoted_TOR330_dates.loc[pivoted_TOR330_dates['Retired_Stage'] == 'Stage 4' , 'Pre-Post Gressoney'] ='Pre Gressoney' 
pivoted_TOR330_dates.loc[pivoted_TOR330_dates['Retired_Stage'] == 'Stage 5' , 'Pre-Post Gressoney'] ='Post Gressoney' 
pivoted_TOR330_dates.loc[pivoted_TOR330_dates['Retired_Stage'] == 'Stage 6' , 'Pre-Post Gressoney'] ='Post Gressoney' 
pivoted_TOR330_dates.loc[pivoted_TOR330_dates['Retired_Stage'] == 'Stage 7' , 'Pre-Post Gressoney'] ='Post Gressoney' 
pivoted_TOR330_dates.loc[pivoted_TOR330_dates['Retired'] == 'new_Start Date', 'Pre-Post Gressoney'] = 'Pre Gressoney'

# %%
pivoted_TOR330_dates.groupby('Pre-Post Gressoney')['Pre-Post Gressoney'].count()
# Out:
# Pre-Post Gressoney
# Post Gressoney     64
# Pre Gressoney     520
# Name: Pre-Post Gressoney, dtype: int64

# %%
pivoted_TOR330_dates.groupby('Retired_Stage')['Retired_Stage'].count()
# Out:
# Retired_Stage
# DNS        116
# Stage 1     99
# Stage 2    128
# Stage 3     30
# Stage 4    147
# Stage 5     19
# Stage 6     37
# Stage 7      8
# Name: Retired_Stage, dtype: int64

# %%
counting_retired_Stage_and_wave = pivoted_TOR330_dates[pivoted_TOR330_dates['Status'] == False].groupby(['Retired_Stage', 'Wave'] ).size().to_frame()

# Reset the index to make it more readable
counting_retired_Stage_and_wave.index = pd.MultiIndex.from_tuples(counting_retired_Stage_and_wave.index, 
                                            names=["Retired_Stage", "Wave"])

# Unstack the Wave level to create columns for Wave1 and Wave2
counting_retired_Stage_and_wave = counting_retired_Stage_and_wave.unstack(level="Wave")
counting_retired_Stage_and_wave.reset_index(drop =  False)
counting_retired_Stage_and_wave.columns = counting_retired_Stage_and_wave.columns.droplevel(0)


# counting_retired_Stage_and_wave.columns = counting_retired_Stage_and_wave.columns.droplevel(0)
counting_retired_Stage_and_wave['Total'] = counting_retired_Stage_and_wave['Wave1'] +counting_retired_Stage_and_wave['Wave2']

counting_retired_Stage_and_wave['Wave1_%'] = counting_retired_Stage_and_wave['Wave1']/counting_retired_Stage_and_wave['Total']
counting_retired_Stage_and_wave['Wave2_%'] = counting_retired_Stage_and_wave['Wave2']/counting_retired_Stage_and_wave['Total']

counting_retired_Stage_and_wave['Wave1_%'] = round(counting_retired_Stage_and_wave['Wave1_%']*100, 1)
counting_retired_Stage_and_wave['Wave2_%']= round(counting_retired_Stage_and_wave['Wave2_%']*100, 2)

counting_retired_Stage_and_wave
# Out:
# Wave           Wave1  Wave2  Total  Wave1_%  Wave2_%
# Retired_Stage
# DNS               47     69    116     40.5    59.48
# Stage 1           36     63     99     36.4    63.64
# Stage 2           54     74    128     42.2    57.81
# Stage 3           18     12     30     60.0    40.00
# Stage 4           48     99    147     32.7    67.35
# Stage 5           12      7     19     63.2    36.84
# Stage 6           19     18     37     51.4    48.65
# Stage 7            5      3      8     62.5    37.50

# %%
# DNS
pivoted_TOR330_dates[pivoted_TOR330_dates['Retired'] == 'new_Start Date']
# Out:
#                           Name   Bib Sex Nationality  Year    Race Category  \
# 0                  Russi Jonas     1   M          CH  2023  TOR330      SEN
# 2               Corsini Simone     3   M          IT  2023  TOR330      SEN
# 8                Collins Avery     9   M          US  2023  TOR330      SEN
# 33         Schjolberg Hallvard    34   M          NO  2023  TOR330       V1
# 37               Roberts Simon    38   M          GB  2023  TOR330      SEN
# ...                        ...   ...  ..         ...   ...     ...      ...
# 1119  Jimenez Roqhuett Marcelo  1487   M          CR  2023  TOR330       V1
# 1137              Campion Mark  1505   M          GB  2023  TOR330       V1
# 1152             Torre Silvere  1520   M          FR  2023  TOR330       V3
# 1155         Vlatkovic Tatiana  1523   F          CH  2023  TOR330      SEN
# 1157          Dohrmann Michael  1525   M          US  2023  TOR330       V1
#
#       Status   Wave Duration  ... Ponteille Desot Bosses Rifugio Frassati  \
# 0      False  Wave1      NaT  ...             NaT    NaT              NaT
# 2      False  Wave1      NaT  ...             NaT    NaT              NaT
# 8      False  Wave1      NaT  ...             NaT    NaT              NaT
# 33     False  Wave1      NaT  ...             NaT    NaT              NaT
# 37     False  Wave1      NaT  ...             NaT    NaT              NaT
# ...      ...    ...      ...  ...             ...    ...              ...
# 1119   False  Wave2      NaT  ...             NaT    NaT              NaT
# 1137   False  Wave2      NaT  ...             NaT    NaT              NaT
# 1152   False  Wave2      NaT  ...             NaT    NaT              NaT
# 1155   False  Wave2      NaT  ...             NaT    NaT              NaT
# 1157   False  Wave2      NaT  ...             NaT    NaT              NaT
#
#      Pas Entre Deux Sauts Monte de la Saxe FINISH         Retired Status1  \
# 0                     NaT              NaT    NaT  new_Start Date     DNF
# 2                     NaT              NaT    NaT  new_Start Date     DNF
# 8                     NaT              NaT    NaT  new_Start Date     DNF
# 33                    NaT              NaT    NaT  new_Start Date     DNF
# 37                    NaT              NaT    NaT  new_Start Date     DNF
# ...                   ...              ...    ...             ...     ...
# 1119                  NaT              NaT    NaT  new_Start Date     DNF
# 1137                  NaT              NaT    NaT  new_Start Date     DNF
# 1152                  NaT              NaT    NaT  new_Start Date     DNF
# 1155                  NaT              NaT    NaT  new_Start Date     DNF
# 1157                  NaT              NaT    NaT  new_Start Date     DNF
#
#      Retired_Stage Pre-Post Gressoney
# 0              DNS      Pre Gressoney
# 2              DNS      Pre Gressoney
# 8              DNS      Pre Gressoney
# 33             DNS      Pre Gressoney
# 37             DNS      Pre Gressoney
# ...            ...                ...
# 1119           DNS      Pre Gressoney
# 1137           DNS      Pre Gressoney
# 1152           DNS      Pre Gressoney
# 1155           DNS      Pre Gressoney
# 1157           DNS      Pre Gressoney
#
# [116 rows x 64 columns]

# %%
pivoted_TOR330_dates = pivoted_TOR330_dates[[
    'Name', 'Bib', 'Sex', 'Nationality', 'Year', 'Race', 'Category',
    'Status', 'Status1', 'Wave', 'Duration',  
    'Retired', 'Retired_Stage', 
    'new_Start Date', 'Baite Youlaz', 'La Thuile', 'Rifugio Deffeyes', 
    'Planaval', 'Valgrisenche IN', 'Valgrisenche OUT', 'Chalet Epee',
    'Rhemes-Notre-Dame', 'Eaux Rousse', 'Rifugio Sella', 'Cogne IN',
    'Cogne OUT', 'Goilles', 'Rifugio Dondena', 'Chardonney', 'Pontboset',
    'Donnas IN', 'Donnas OUT', 'Perloz', 'Sassa', 'Rifugio Coda',
    'Rifugio della Barma', 'Lago Chiaro', 'Col della Vecchia',
    'Niel La Gruba', 'Loo', 'Gressoney IN', 'Gressoney OUT',
    'Rifugio Alpenzu', 'Champoluc', 'Rifugio Grand Tournalin',
    'Valtournenche IN', 'Valtournenche OUT', 'Rifugio Barmasse', 'Vareton',
    'Rifugio Magià', 'Rifugio Cuney', 'Bivacco R. Clermont', 'Oyace',
    'Bruson Arp',   'Ollomont IN',
    'Ollomont OUT', 'Rifugio Champillon', 'Ponteille Desot', 'Bosses',
    'Rifugio Frassati', 'Pas Entre Deux Sauts', 'Monte de la Saxe',
    'FINISH']]

# %% [markdown]
# ### Calculating the Times for each Stage

# %%
pivoted_TOR330_dates['Stage 1 Time'] = pivoted_TOR330_dates['Valgrisenche IN'] - pivoted_TOR330_dates['new_Start Date']

pivoted_TOR330_dates['Time Spent in Valgrisenche'] = pivoted_TOR330_dates['Valgrisenche OUT'] - pivoted_TOR330_dates['Valgrisenche IN']

pivoted_TOR330_dates['Stage 2 Time'] = pivoted_TOR330_dates['Cogne IN'] - pivoted_TOR330_dates['Valgrisenche OUT']
pivoted_TOR330_dates['Time Spent in Cogne'] = pivoted_TOR330_dates['Cogne OUT'] - pivoted_TOR330_dates['Cogne IN']


pivoted_TOR330_dates['Stage 3 Time'] = pivoted_TOR330_dates['Donnas IN'] - pivoted_TOR330_dates['Cogne OUT']
pivoted_TOR330_dates['Time Spent in Donnas'] = pivoted_TOR330_dates['Donnas OUT'] - pivoted_TOR330_dates['Donnas IN']


pivoted_TOR330_dates['Stage 4 Time'] = pivoted_TOR330_dates['Gressoney IN'] - pivoted_TOR330_dates['Donnas OUT']
pivoted_TOR330_dates['Time Spent in Gressoney'] = pivoted_TOR330_dates['Gressoney OUT'] - pivoted_TOR330_dates['Gressoney IN']

pivoted_TOR330_dates['Stage 5 Time'] = pivoted_TOR330_dates['Valtournenche IN'] - pivoted_TOR330_dates['Gressoney OUT']
pivoted_TOR330_dates['Time Spent in Valtournenche'] = pivoted_TOR330_dates['Valtournenche OUT'] - pivoted_TOR330_dates['Valtournenche IN']

pivoted_TOR330_dates['Stage 6 Time'] = pivoted_TOR330_dates['Ollomont IN'] - pivoted_TOR330_dates['Valtournenche OUT']
pivoted_TOR330_dates['Time Spent in Ollomont'] = pivoted_TOR330_dates['Ollomont OUT'] - pivoted_TOR330_dates['Ollomont IN']

pivoted_TOR330_dates['Stage 7 Time'] = pivoted_TOR330_dates['FINISH'] - pivoted_TOR330_dates['Ollomont OUT']

# %%
pivoted_TOR330_dates_noDNF = pivoted_TOR330_dates[
                        # extracting runners whose status is True (Finished)
                        (pivoted_TOR330_dates['Status'] == True) &
                    ~(pivoted_TOR330_dates['FINISH'].isna())].reset_index()
pivoted_TOR330_dates_noDNF.isnull().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of      index   Name    Bib    Sex  Nationality   Year   Race  Category  Status  \
# 0    False  False  False  False        False  False  False     False   False
# 1    False  False  False  False        False  False  False     False   False
# 2    False  False  False  False        False  False  False     False   False
# 3    False  False  False  False        False  False  False     False   False
# 4    False  False  False  False        False  False  False     False   False
# ..     ...    ...    ...    ...          ...    ...    ...       ...     ...
# 617  False  False  False  False        False  False  False     False   False
# 618  False  False  False  False        False  False  False     False   False
# 619  False  False  False  False        False  False  False     False   False
# 620  False  False  False  False        False  False  False     False   False
# 621  False  False  False  False        False  False  False     False   False
#
#      Status1  ...  Time Spent in Cogne  Stage 3 Time  Time Spent in Donnas  \
# 0      False  ...                False         False                 False
# 1      False  ...                False         False                 False
# 2      False  ...                False         False                 False
# 3      False  ...                False         False                 False
# 4      False  ...                False         False                 False
# ..       ...  ...                  ...           ...                   ...
# 617    False  ...                False         False                 False
# 618    False  ...                False         False                 False
# 619    False  ...                False         False                 False
# 620    False  ...                False         False                 False
# 621    False  ...                False         False                 False
#
#      Stage 4 Time  Time Spent in Gressoney  Stage 5 Time  \
# 0           False                    False         False
# 1           False                    False         False
# 2           False                    False         False
# 3           False                    False         False
# 4           False                    False         False
# ..            ...                      ...           ...
# 617         False                    False         False
# 618         False                    False         False
# 619         False                    False         False
# 620         False                    False         False
# 621         False                    False         False
#
#      Time Spent in Valtournenche  Stage 6 Time  Time Spent in Ollomont  \
# 0                          False         False                   False
# 1                          False         False                   False
# 2                          False         False                   False
# 3                          False         False                   False
# 4                          False         False                   False
# ..                           ...           ...                     ...
# 617                        False         False                   False
# 618                         True          True                   False
# 619                        False         False                   False
# 620                        False         False                   False
# 621                        False         False                   False
#
#      Stage 7 Time
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
# ..            ...
# 617         False
# 618         False
# 619         False
# 620         False
# 621         False
#
# [622 rows x 77 columns]>

# %% [markdown]
# ### Converting to seconds for Tableau Analysis

# %%
tableau_pivoted_TOR330_dates = pivoted_TOR330_dates[[
    'Name', 'Bib', 'Sex', 'Nationality', 'Year', 'Race', 'Category',
    'Status', 'Status1', 'Wave',
    'Retired', 'Retired_Stage', 
    'new_Start Date',
    'Stage 1 Time', 'Time Spent in Valgrisenche', 
    'Stage 2 Time', 'Time Spent in Cogne',
    'Stage 3 Time', 'Time Spent in Donnas',
    'Stage 4 Time', 'Time Spent in Gressoney',
    'Stage 5 Time', 'Time Spent in Valtournenche',
    'Stage 6 Time', 'Time Spent in Ollomont',
    'Stage 7 Time',  'Duration']].copy()

# %%
pivoted_TOR330_dates[[
    'Name', 'Bib', 'Sex', 'Nationality', 'Year', 'Race', 'Category',
    'Status', 'Status1', 'Wave', 
    'Retired', 'Retired_Stage', 
    'new_Start Date',
    'Stage 1 Time', 'Time Spent in Valgrisenche', 
    'Stage 2 Time', 'Time Spent in Cogne', 'Cogne OUT',
    'Stage 3 Time', 'Time Spent in Donnas',
    'Stage 4 Time', 'Time Spent in Gressoney',
    'Stage 5 Time', 'Time Spent in Valtournenche',
    'Stage 6 Time', 'Time Spent in Ollomont',
    'Stage 7 Time',  'Duration']][pivoted_TOR330_dates['Name'].str.contains('Williams John')].transpose()
# Out:
#                                             1167
# Name                               Williams John
# Bib                                         1535
# Sex                                            M
# Nationality                                   IE
# Year                                        2023
# Race                                      TOR330
# Category                                      V1
# Status                                      True
# Status1                                 Finished
# Wave                                       Wave2
# Retired                                      NaN
# Retired_Stage                                NaN
# new_Start Date               2023-09-10 12:00:00
# Stage 1 Time                     0 days 14:06:32
# Time Spent in Valgrisenche       0 days 02:15:52
# Stage 2 Time                     0 days 19:26:57
# Time Spent in Cogne              0 days 03:49:58
# Cogne OUT                    2023-09-12 03:39:19
# Stage 3 Time                     0 days 11:24:09
# Time Spent in Donnas             0 days 02:39:27
# Stage 4 Time                     0 days 23:44:36
# Time Spent in Gressoney          0 days 04:36:02
# Stage 5 Time                     0 days 12:22:23
# Time Spent in Valtournenche      0 days 01:15:25
# Stage 6 Time                     0 days 20:02:08
# Time Spent in Ollomont           0 days 03:33:58
# Stage 7 Time                     0 days 14:27:51
# Duration                         5 days 13:45:18

# %%
pivoted_TOR330_dates[[
    'Name', 'Bib', 'Sex', 'Nationality', 'Year', 'Race', 'Category',
    'Status', 'Status1', 'Wave', 'Duration',  
    'Retired', 'Retired_Stage', 
    'new_Start Date',
    'Stage 1 Time', 'Time Spent in Valgrisenche', 
    'Stage 2 Time', 'Time Spent in Cogne', 'Cogne OUT',
    'Stage 3 Time', 'Time Spent in Donnas',
    'Stage 4 Time', 'Time Spent in Gressoney',
    'Stage 5 Time', 'Time Spent in Valtournenche',
    'Stage 6 Time', 'Time Spent in Ollomont',
    'Stage 7 Time',  'Duration']].isnull().sum()
# Out:
# Name                             0
# Bib                              0
# Sex                              0
# Nationality                      0
# Year                             0
# Race                             0
# Category                         0
# Status                           0
# Status1                          0
# Wave                             0
# Duration                       584
# Retired                        622
# Retired_Stage                  622
# new_Start Date                   0
# Stage 1 Time                   155
# Time Spent in Valgrisenche     203
# Stage 2 Time                   320
# Time Spent in Cogne            383
# Cogne OUT                      378
# Stage 3 Time                   412
# Time Spent in Donnas           378
# Stage 4 Time                   512
# Time Spent in Gressoney        511
# Stage 5 Time                   538
# Time Spent in Valtournenche    541
# Stage 6 Time                   582
# Time Spent in Ollomont         594
# Stage 7 Time                   600
# Duration                       584
# dtype: int64

# %%
for i in tableau_pivoted_TOR330_dates.columns:
    print(i)
# Out:
# Name
# Bib
# Sex
# Nationality
# Year
# Race
# Category
# Status
# Status1
# Wave
# Retired
# Retired_Stage
# new_Start Date
# Stage 1 Time
# Time Spent in Valgrisenche
# Stage 2 Time
# Time Spent in Cogne
# Stage 3 Time
# Time Spent in Donnas
# Stage 4 Time
# Time Spent in Gressoney
# Stage 5 Time
# Time Spent in Valtournenche
# Stage 6 Time
# Time Spent in Ollomont
# Stage 7 Time
# Duration

# %%
# Define the columns to process
time_columns = ['Stage 1 Time', 'Time Spent in Valgrisenche', 
                'Stage 2 Time', 'Time Spent in Cogne',
                'Stage 3 Time', 'Time Spent in Donnas',
                'Stage 4 Time', 'Time Spent in Gressoney',
                'Stage 5 Time', 'Time Spent in Valtournenche',
                'Stage 6 Time', 'Time Spent in Ollomont',
                'Stage 7 Time', 'Duration']

# Loop through the columns
for column in time_columns:
    print(f"Processing column: {column}")
    print(tableau_pivoted_TOR330_dates[column].describe())
    
    
    
    
    # Convert to timedelta and get total hours (handling NaT)
    tableau_pivoted_TOR330_dates[f'{column}_hours'] = pd.to_timedelta(
        tableau_pivoted_TOR330_dates[f'{column}'], errors='coerce'
    ).dt.total_seconds() / 3600  # Convert seconds to hours

    # Drop NaN values for histogram visualization
    data_to_plot = tableau_pivoted_TOR330_dates[f'{column}_hours'].dropna()

    # Plot the histogram
    plt.figure(figsize=(8, 5))
    sns.histplot(data_to_plot, kde=True, bins=30, color="lightcoral")
    plt.ticklabel_format(style='plain', axis='x')
    plt.title(f"Distribution of {column} (in Hours) in {year}")
    plt.xlabel("Time (hours)")
    plt.ylabel("Frequency")
    plt.show()
    
    print('*'*80)
# Out:
# Processing column: Stage 1 Time
# count                         1051
# mean     0 days 12:39:59.897240723
# std      0 days 02:10:05.496041764
# min                0 days 07:05:31
# 25%         0 days 11:10:29.500000
# 50%                0 days 12:39:44
# 75%                0 days 14:11:59
# max                0 days 18:59:40
# Name: Stage 1 Time, dtype: object
# ********************************************************************************
# Processing column: Time Spent in Valgrisenche
# count                         1003
# mean     0 days 01:21:15.020937188
# std      0 days 00:55:27.360589052
# min                0 days 00:00:36
# 25%         0 days 00:41:59.500000
# 50%                0 days 01:04:39
# 75%                0 days 01:49:28
# max                0 days 07:31:10
# Name: Time Spent in Valgrisenche, dtype: object
# ********************************************************************************
# Processing column: Stage 2 Time
# count                          886
# mean     0 days 18:30:00.065462753
# std      0 days 03:07:46.680286098
# min                0 days 09:42:55
# 25%         0 days 16:30:00.500000
# 50%                0 days 18:35:59
# 75%                0 days 20:34:50
# max                1 days 02:46:44
# Name: Stage 2 Time, dtype: object
# ********************************************************************************
# Processing column: Time Spent in Cogne
# count                          823
# mean     0 days 02:33:57.122721749
# std      0 days 01:28:51.379066901
# min              -1 days +23:59:42
# 25%         0 days 01:24:49.500000
# 50%                0 days 02:27:06
# 75%                0 days 03:36:05
# max                0 days 11:32:57
# Name: Time Spent in Cogne, dtype: object
# ********************************************************************************
# Processing column: Stage 3 Time
# count                          794
# mean     0 days 12:29:16.614609571
# std      0 days 02:01:02.004749980
# min              -1 days +22:37:53
# 25%         0 days 11:22:55.500000
# 50%                0 days 12:41:32
# 75%                0 days 13:49:45
# max                0 days 17:30:31
# Name: Stage 3 Time, dtype: object
# ********************************************************************************
# Processing column: Time Spent in Donnas
# count                          828
# mean     0 days 02:40:43.404589371
# std      0 days 01:24:58.289866379
# min                0 days 00:00:27
# 25%         0 days 01:42:25.750000
# 50%                0 days 02:35:32
# 75%                0 days 03:30:27
# max                0 days 18:06:51
# Name: Time Spent in Donnas, dtype: object
# ********************************************************************************
# Processing column: Stage 4 Time
# count                          694
# mean     0 days 23:32:32.497118155
# std      0 days 03:28:20.324667038
# min                0 days 11:21:58
# 25%                0 days 21:14:45
# 50%                1 days 00:14:18
# 75%                1 days 02:01:51
# max                1 days 07:19:28
# Name: Stage 4 Time, dtype: object
# ********************************************************************************
# Processing column: Time Spent in Gressoney
# count                          695
# mean     0 days 03:14:26.913669064
# std      0 days 01:35:09.165792086
# min              -1 days +23:59:26
# 25%                0 days 02:14:47
# 50%                0 days 03:13:29
# 75%         0 days 04:03:28.500000
# max                0 days 12:14:56
# Name: Time Spent in Gressoney, dtype: object
# ********************************************************************************
# Processing column: Stage 5 Time
# count                          668
# mean     0 days 12:35:35.208083832
# std      0 days 02:15:05.541661622
# min                0 days 07:08:23
# 25%         0 days 11:01:48.250000
# 50%                0 days 12:39:06
# 75%         0 days 14:02:22.750000
# max                0 days 22:27:00
# Name: Stage 5 Time, dtype: object
# ********************************************************************************
# Processing column: Time Spent in Valtournenche
# count                          665
# mean     0 days 02:46:32.264661654
# std      0 days 01:28:33.586060979
# min                0 days 00:03:38
# 25%                0 days 01:38:27
# 50%                0 days 02:46:28
# 75%                0 days 03:40:32
# max                0 days 09:52:00
# Name: Time Spent in Valtournenche, dtype: object
# ********************************************************************************
# Processing column: Stage 6 Time
# count                          624
# mean     0 days 20:03:45.884615384
# std      0 days 02:51:24.014907256
# min                0 days 11:37:58
# 25%                0 days 18:11:23
# 50%                0 days 20:14:13
# 75%                0 days 21:58:31
# max                1 days 05:03:50
# Name: Stage 6 Time, dtype: object
# ********************************************************************************
# Processing column: Time Spent in Ollomont
# count                          612
# mean     0 days 02:28:25.325163398
# std      0 days 01:27:42.756907637
# min              -1 days +23:24:09
# 25%         0 days 01:25:54.500000
# 50%         0 days 02:18:37.500000
# 75%         0 days 03:15:50.500000
# max                0 days 08:49:43
# Name: Time Spent in Ollomont, dtype: object
# ********************************************************************************
# Processing column: Stage 7 Time
# count                          606
# mean     0 days 17:01:49.691419141
# std      0 days 03:16:45.141012546
# min                0 days 10:09:53
# 25%                0 days 14:36:02
# 50%                0 days 17:05:56
# 75%                0 days 19:22:35
# max                1 days 17:34:31
# Name: Stage 7 Time, dtype: object
# ********************************************************************************
# Processing column: Duration
# count                          622
# mean     5 days 09:30:33.818327974
# std      0 days 17:06:51.041668145
# min                2 days 18:39:16
# 25%         5 days 01:25:48.750000
# 50%         5 days 12:26:55.500000
# 75%                5 days 23:55:49
# max                6 days 08:15:44
# Name: Duration, dtype: object
# ********************************************************************************

# %%
for column in ['Stage 1 Time', 'Time Spent in Valgrisenche', 
                'Stage 2 Time', 'Time Spent in Cogne',
                'Stage 3 Time', 'Time Spent in Donnas',
                'Stage 4 Time', 'Time Spent in Gressoney',
                'Stage 5 Time', 'Time Spent in Valtournenche',
                'Stage 6 Time', 'Time Spent in Ollomont',
                'Stage 7 Time', 'Duration']:
#     print(tableau_pivoted_TOR330_dates[column].head())

    
    # Convert to timedelta while handling NaT
    tableau_pivoted_TOR330_dates[f'{column}_in_seconds'] = (
        pd.to_timedelta(tableau_pivoted_TOR330_dates[column], errors='coerce')
        .dt.total_seconds()
    )
    
    # Mark missing values explicitly for Tableau
    tableau_pivoted_TOR330_dates[f'{column}_in_seconds'] = (
        tableau_pivoted_TOR330_dates[f'{column}_in_seconds']
        .fillna('Missing')  # Replace NaT with 'Missing'
    )
            
#     print(f'{column}_in_seconds')
#     print('*'*20)

# %%
tableau_pivoted_TOR330_dates.columns
# Out:
# Index(['Name', 'Bib', 'Sex', 'Nationality', 'Year', 'Race', 'Category',
#        'Status', 'Status1', 'Wave', 'Retired', 'Retired_Stage',
#        'new_Start Date', 'Stage 1 Time', 'Time Spent in Valgrisenche',
#        'Stage 2 Time', 'Time Spent in Cogne', 'Stage 3 Time',
#        'Time Spent in Donnas', 'Stage 4 Time', 'Time Spent in Gressoney',
#        'Stage 5 Time', 'Time Spent in Valtournenche', 'Stage 6 Time',
#        'Time Spent in Ollomont', 'Stage 7 Time', 'Duration',
#        'Stage 1 Time_hours', 'Time Spent in Valgrisenche_hours',
#        'Stage 2 Time_hours', 'Time Spent in Cogne_hours', 'Stage 3 Time_hours',
#        'Time Spent in Donnas_hours', 'Stage 4 Time_hours',
#        'Time Spent in Gressoney_hours', 'Stage 5 Time_hours',
#        'Time Spent in Valtournenche_hours', 'Stage 6 Time_hours',
#        'Time Spent in Ollomont_hours', 'Stage 7 Time_hours', 'Duration_hours',
#        'Stage 1 Time_in_seconds', 'Time Spent in Valgrisenche_in_seconds',
#        'Stage 2 Time_in_seconds', 'Time Spent in Cogne_in_seconds',
#        'Stage 3 Time_in_seconds', 'Time Spent in Donnas_in_seconds',
#        'Stage 4 Time_in_seconds', 'Time Spent in Gressoney_in_seconds',
#        'Stage 5 Time_in_seconds', 'Time Spent in Valtournenche_in_seconds',
#        'Stage 6 Time_in_seconds', 'Time Spent in Ollomont_in_seconds',
#        'Stage 7 Time_in_seconds', 'Duration_in_seconds'],
#       dtype='object')

# %%
# tableau_pivoted_TOR330_dates = tableau_pivoted_TOR330_dates[[
    
#     'Name', 'Bib', 'Sex', 'Nationality', 'Year', 'Race', 'Category',
#        'Status', 'Status1', 'Wave', 'Retired', 'Retired_Stage',
#        'new_Start Date', 'Stage 1 Time_in_seconds',
#        'Time Spent in Valgrisenche_in_seconds', 'Stage 2 Time_in_seconds',
#        'Time Spent in Cogne_in_seconds', 'Stage 3 Time_in_seconds',
#        'Time Spent in Donnas_in_seconds', 'Stage 4 Time_in_seconds',
#        'Time Spent in Gressoney_in_seconds', 'Stage 5 Time_in_seconds',
#        'Time Spent in Valtournenche_in_seconds', 'Stage 6 Time_in_seconds',
#        'Time Spent in Ollomont_in_seconds', 'Stage 7 Time_in_seconds',  'Duration_in_seconds'
# ]]

# %% [markdown]
# ### Saving for Tableau

# %%
# tableau_pivoted_TOR330_dates.to_excel(f'{race} Data/tableau_{race}_aid_stations_{year}.xlsx' )

# %%
# pivoted_TOR330_dates.to_excel(f'{race} Data/clean_{race}_aid_stations_{year}.xlsx' )

# %% [markdown]
# ## Cutoffs
# The cutoffs table was used to establish whether individuals missed the cutoffs or not.
#
#
# ![image.png](attachment:image.png)
#
#
# #### Stage Cutoffs
# ![image-3.png](attachment:image-3.png)
#
# After cleaning the CSV and attaching dates instead of D1/ D2/ D3 etc, this is what the cut off talbe looks like:
#
# #### Dates Cutoffs
# ![image-2.png](attachment:image-2.png)

# %%
stages_cut_offs_df = pd.read_excel('Database Data/TOR33_stages_cut_offs_df.xlsx')
stages_cut_offs_df
# Out:
#          aid_stations  distance_difference (km)  D+ difference (m)  \
# 0     Valgrisenche IN                     48.55               4339
# 1    Valgrisenche OUT                      0.00                  0
# 2            Cogne IN                     55.45               4943
# 3           Cogne OUT                      0.00                  0
# 4           Donnas IN                     45.77               2768
# 5          Donnas OUT                      0.00                  0
# 6        Gressoney IN                     54.23               5933
# 7       Gressoney OUT                      0.00                  0
# 8    Valtournenche IN                     33.62               3094
# 9   Valtournenche OUT                      0.00                  0
# 10        Ollomont IN                     48.04               4625
# 11       Ollomont OUT                      0.00                  0
# 12   TORX Finish Line                     49.66               3906
#
#                  Wave1  Stage Duration                  stage
# 0  2023-09-11 05:00:00        0.791667                Stage 1
# 1  2023-09-11 07:00:00        0.083333   Time in Valgrisenche
# 2  2023-09-12 04:00:00        0.875000                Stage 2
# 3  2023-09-12 06:00:00        0.083333          Time in Cogne
# 4  2023-09-13 00:00:00        0.750000                Stage 3
# 5  2023-09-13 02:00:00        0.083333         Time in Donnas
# 6  2023-09-13 23:00:00        0.875000                Stage 4
# 7  2023-09-14 01:00:00        0.083333      Time in Gressoney
# 8  2023-09-14 19:00:00        0.750000                Stage 5
# 9  2023-09-14 21:00:00        0.083333  Time in Valtournenche
# 10 2023-09-15 17:00:00        0.833333                Stage 6
# 11 2023-09-15 19:00:00        0.083333       Time in Ollomont
# 12 2023-09-16 16:00:00        0.875000                Stage 7

# %%
cutoffs_df_pivot = pd.read_excel('Database Data/TOR33_aid_station_for_each_year_cut_offs_df.xlsx')
cutoffs_df_pivot['Year'] = cutoffs_df_pivot['Year'].astype('str')
cutoffs_df_pivot = cutoffs_df_pivot[cutoffs_df_pivot['Year'] == f'{year}']
cutoffs_df_pivot
# Out:
#    Year   Wave Cut Off | La Thuile Cut Off | Valgrisenche IN  \
# 6  2023  Wave1 2023-09-10 15:30:00       2023-09-11 05:00:00
# 7  2023  Wave2 2023-09-10 17:30:00       2023-09-11 07:00:00
#
#   Cut Off | Valgrisenche OUT Cut Off | Eaux Rousse  Cut Off | Cogne IN  \
# 6        2023-09-11 07:00:00   2023-09-11 19:30:00 2023-09-12 04:00:00
# 7        2023-09-11 09:00:00   2023-09-11 21:30:00 2023-09-12 06:00:00
#
#   Cut Off | Cogne OUT Cut Off | Donnas IN Cut Off | Donnas OUT  ...  \
# 6 2023-09-12 06:00:00 2023-09-13 00:00:00  2023-09-13 02:00:00  ...
# 7 2023-09-12 08:00:00 2023-09-13 02:00:00  2023-09-13 04:00:00  ...
#
#   Cut Off | Niel La Gruba Cut Off | Gressoney IN Cut Off | Gressoney OUT  \
# 6     2023-09-13 19:30:00    2023-09-13 23:00:00     2023-09-14 01:00:00
# 7     2023-09-13 21:30:00    2023-09-14 01:00:00     2023-09-14 03:00:00
#
#   Cut Off | Champoluc Cut Off | Valtournenche IN Cut Off | Valtournenche OUT  \
# 6 2023-09-14 13:00:00        2023-09-14 19:00:00         2023-09-14 21:00:00
# 7 2023-09-14 15:00:00        2023-09-14 21:00:00         2023-09-14 23:00:00
#
#    Cut Off | Oyace IN Cut Off | Ollomont IN Cut Off | Ollomont OUT  \
# 6 2023-09-15 12:00:00   2023-09-15 17:00:00    2023-09-15 19:00:00
# 7 2023-09-15 14:00:00   2023-09-15 19:00:00    2023-09-15 21:00:00
#
#      Cut Off | FINISH
# 6 2023-09-16 16:00:00
# 7 2023-09-16 18:00:00
#
# [2 rows x 21 columns]

# %% [markdown]
# <!-- ### Adding Cut off Times -->

# %%
cutoffs_df_pivot_2023 = cutoffs_df_pivot[cutoffs_df_pivot['Year'] == year]
cutoffs_df_pivot_2023['Year'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 2 entries, 6 to 7
# Series name: Year
# Non-Null Count  Dtype
# --------------  -----
# 2 non-null      object
# dtypes: object(1)
# memory usage: 32.0+ bytes

# %%
### Check the year as int or str!
pivoted_TOR330_dates['Year'] = pivoted_TOR330_dates['Year'].astype('str')

# %%
# # Merging the new D1  dataframe and pivoted_TOR450_dates_duv_df
# TORX_pivot_cutoffs = pivoted_TOR330_dates.merge(
#     cutoffs_df_pivot_2023, 
#     on=['Year', 'Wave'],
#     how='left'
# )

# TORX_pivot_cutoffs.head()

# %% [markdown]
# ### Finding everyone who missed a cut off

# %%
pivoted_TOR330_dates_DNF = pivoted_TOR330_dates[
                    # selecting all rows that DNFed
                    (pivoted_TOR330_dates['Status'] == False) & # AND
                    # selecting all rows where FINISH does not have a time
                    (pivoted_TOR330_dates['FINISH'].isna())]
pivoted_TOR330_dates_DNF['Wave']
# Out:
# 0       Wave1
# 2       Wave1
# 4       Wave1
# 6       Wave1
# 8       Wave1
#         ...
# 1192    Wave2
# 1199    Wave2
# 1202    Wave2
# 1203    Wave2
# 1205    Wave2
# Name: Wave, Length: 584, dtype: object

# %%
for column in [
#             'Valgrisenche IN','Valgrisenche OUT', 
            'Cogne IN', 'Cogne OUT', 
            'Donnas IN', 'Donnas OUT', 
            'Gressoney IN', 'Gressoney OUT', 
            'Valtournenche IN','Valtournenche OUT',
            'Ollomont IN', 'Ollomont OUT',
#             'TORX Finish Line' 
]:


    print(f"Processing column: {column}")
    for wave in ['Wave1', 'Wave2']:
        # Define the new column dynamically
        new_column = f'Cut Off | {column}'
        
        # Extract the stage cutoff value for the specific wave
        stage_cut_off = cutoffs_df_pivot_2023.loc[
            cutoffs_df_pivot_2023['Wave'] == wave, new_column
        ].values[0]  # Using .values[0] for the first value found in the condition

        print(f"Stage cut-off for {column}, {wave}: {stage_cut_off}")
#         print(pivoted_TOR330_dates_noDNF[column].head())
#         print(pivoted_TOR330_dates_noDNF.info())
#         print(cutoffs_df_pivot_2023[new_column].head())
        
        # Perform the calculation and store it in the dataframe
        condition = pivoted_TOR330_dates_DNF['Wave'] == wave
        
        pivoted_TOR330_dates_DNF.loc[condition, f'Difference between {column} Timestamp and {column} {wave} Cut Off'] = (
            stage_cut_off - pivoted_TOR330_dates_DNF.loc[condition, column]
        )
#         print(pivoted_TOR330_dates_noDNF[f'Difference between {column} Timestamp and {column} {wave} Cut Off '])

        # Filter for negative values and display them for debugging
        negative_values = pivoted_TOR330_dates_DNF.loc[
            condition & (pivoted_TOR330_dates_DNF[f'Difference between {column} Timestamp and {column} {wave} Cut Off'] < pd.to_timedelta('00:00:00')
                        ),
            [column, f'Difference between {column} Timestamp and {column} {wave} Cut Off']
        ]
        
        print( negative_values)


        # Convert to timedelta and get total hours (handling NaT)
        pivoted_TOR330_dates_DNF[f'Difference between {column} Timestamp and {column} {wave} Cut Off_hours'] = pd.to_timedelta(
            pivoted_TOR330_dates_DNF[f'Difference between {column} Timestamp and {column} {wave} Cut Off'], errors='coerce'
        ).dt.total_seconds() / 3600  # Convert seconds to hours


#         print( negative_values)
      # Drop NaN values for histogram visualization
        data_to_plot = pivoted_TOR330_dates_DNF[f'Difference between {column} Timestamp and {column} {wave} Cut Off_hours'].dropna()
        # Plot the histogram
        plt.figure(figsize=(8, 5))
        sns.histplot(data_to_plot, kde=True, bins=30, color="lightcoral")
        plt.ticklabel_format(style='plain', axis='x')
        plt.title(f"Difference between {column} Timestamp and {column} {wave} Cut Off")
        plt.xlabel("Time (hours)")
        plt.ylabel("Frequency")
        plt.show()


#         print("Negative values for calculation:")
#         print(negative_values.head())
#         print('*' * 20)
# Out:
# Processing column: Cogne IN
# Stage cut-off for Cogne IN, Wave1: 2023-09-12T04:00:00.000000000
#                Cogne IN  \
# 488 2023-09-12 04:12:47
# 549 2023-09-12 04:04:34
#
#     Difference between Cogne IN Timestamp and Cogne IN Wave1 Cut Off
# 488                                  -1 days +23:47:13
# 549                                  -1 days +23:55:26
# C:\Users\Karina\AppData\Local\Temp\ipykernel_20632\3384109751.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pivoted_TOR330_dates_DNF.loc[condition, f'Difference between {column} Timestamp and {column} {wave} Cut Off'] = (
# C:\Users\Karina\AppData\Local\Temp\ipykernel_20632\3384109751.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pivoted_TOR330_dates_DNF[f'Difference between {column} Timestamp and {column} {wave} Cut Off_hours'] = pd.to_timedelta(
# Stage cut-off for Cogne IN, Wave2: 2023-09-12T06:00:00.000000000
# Empty DataFrame
# Columns: [Cogne IN, Difference between Cogne IN Timestamp and Cogne IN Wave2 Cut Off]
# Index: []
# C:\Users\Karina\AppData\Local\Temp\ipykernel_20632\3384109751.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pivoted_TOR330_dates_DNF.loc[condition, f'Difference between {column} Timestamp and {column} {wave} Cut Off'] = (
# C:\Users\Karina\AppData\Local\Temp\ipykernel_20632\3384109751.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pivoted_TOR330_dates_DNF[f'Difference between {column} Timestamp and {column} {wave} Cut Off_hours'] = pd.to_timedelta(
# Processing column: Cogne OUT
# Stage cut-off for Cogne OUT, Wave1: 2023-09-12T06:00:00.000000000
#               Cogne OUT  \
# 242 2023-09-12 07:35:15
#
#     Difference between Cogne OUT Timestamp and Cogne OUT Wave1 Cut Off
# 242                                  -1 days +22:24:45
# C:\Users\Karina\AppData\Local\Temp\ipykernel_20632\3384109751.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pivoted_TOR330_dates_DNF.loc[condition, f'Difference between {column} Timestamp and {column} {wave} Cut Off'] = (
# C:\Users\Karina\AppData\Local\Temp\ipykernel_20632\3384109751.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pivoted_TOR330_dates_DNF[f'Difference between {column} Timestamp and {column} {wave} Cut Off_hours'] = pd.to_timedelta(
# Stage cut-off for Cogne OUT, Wave2: 2023-09-12T08:00:00.000000000
#               Cogne OUT  \
# 869 2023-09-12 08:05:12
#
#     Difference between Cogne OUT Timestamp and Cogne OUT Wave2 Cut Off
# 869                                  -1 days +23:54:48
# C:\Users\Karina\AppData\Local\Temp\ipykernel_20632\3384109751.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pivoted_TOR330_dates_DNF.loc[condition, f'Difference between {column} Timestamp and {column} {wave} Cut Off'] = (
# C:\Users\Karina\AppData\Local\Temp\ipykernel_20632\3384109751.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pivoted_TOR330_dates_DNF[f'Difference between {column} Timestamp and {column} {wave} Cut Off_hours'] = pd.to_timedelta(
# Processing column: Donnas IN
# Stage cut-off for Donnas IN, Wave1: 2023-09-13T00:00:00.000000000
# Empty DataFrame
# Columns: [Donnas IN, Difference between Donnas IN Timestamp and Donnas IN Wave1 Cut Off]
# Index: []
# C:\Users\Karina\AppData\Local\Temp\ipykernel_20632\3384109751.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pivoted_TOR330_dates_DNF.loc[condition, f'Difference between {column} Timestamp and {column} {wave} Cut Off'] = (
# C:\Users\Karina\AppData\Local\Temp\ipykernel_20632\3384109751.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pivoted_TOR330_dates_DNF[f'Difference between {column} Timestamp and {column} {wave} Cut Off_hours'] = pd.to_timedelta(
# Stage cut-off for Donnas IN, Wave2: 2023-09-13T02:00:00.000000000
# Empty DataFrame
# Columns: [Donnas IN, Difference between Donnas IN Timestamp and Donnas IN Wave2 Cut Off]
# Index: []
# C:\Users\Karina\AppData\Local\Temp\ipykernel_20632\3384109751.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pivoted_TOR330_dates_DNF.loc[condition, f'Difference between {column} Timestamp and {column} {wave} Cut Off'] = (
# C:\Users\Karina\AppData\Local\Temp\ipykernel_20632\3384109751.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pivoted_TOR330_dates_DNF[f'Difference between {column} Timestamp and {column} {wave} Cut Off_hours'] = pd.to_timedelta(
# Processing column: Donnas OUT
# Stage cut-off for Donnas OUT, Wave1: 2023-09-13T02:00:00.000000000
#              Donnas OUT  \
# 549 2023-09-13 02:20:36
#
#     Difference between Donnas OUT Timestamp and Donnas OUT Wave1 Cut Off
# 549                                  -1 days +23:39:24
# C:\Users\Karina\AppData\Local\Temp\ipykernel_20632\3384109751.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pivoted_TOR330_dates_DNF.loc[condition, f'Difference between {column} Timestamp and {column} {wave} Cut Off'] = (
# C:\Users\Karina\AppData\Local\Temp\ipykernel_20632\3384109751.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pivoted_TOR330_dates_DNF[f'Difference between {column} Timestamp and {column} {wave} Cut Off_hours'] = pd.to_timedelta(
# Stage cut-off for Donnas OUT, Wave2: 2023-09-13T04:00:00.000000000
# Empty DataFrame
# Columns: [Donnas OUT, Difference between Donnas OUT Timestamp and Donnas OUT Wave2 Cut Off]
# Index: []
# C:\Users\Karina\AppData\Local\Temp\ipykernel_20632\3384109751.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pivoted_TOR330_dates_DNF.loc[condition, f'Difference between {column} Timestamp and {column} {wave} Cut Off'] = (
# C:\Users\Karina\AppData\Local\Temp\ipykernel_20632\3384109751.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pivoted_TOR330_dates_DNF[f'Difference between {column} Timestamp and {column} {wave} Cut Off_hours'] = pd.to_timedelta(
# Processing column: Gressoney IN
# Stage cut-off for Gressoney IN, Wave1: 2023-09-13T23:00:00.000000000
# Empty DataFrame
# Columns: [Gressoney IN, Difference between Gressoney IN Timestamp and Gressoney IN Wave1 Cut Off]
# Index: []
# C:\Users\Karina\AppData\Local\Temp\ipykernel_20632\3384109751.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pivoted_TOR330_dates_DNF.loc[condition, f'Difference between {column} Timestamp and {column} {wave} Cut Off'] = (
# C:\Users\Karina\AppData\Local\Temp\ipykernel_20632\3384109751.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pivoted_TOR330_dates_DNF[f'Difference between {column} Timestamp and {column} {wave} Cut Off_hours'] = pd.to_timedelta(
# Stage cut-off for Gressoney IN, Wave2: 2023-09-14T01:00:00.000000000
#            Gressoney IN  \
# 673 2023-09-14 01:01:01
# 820 2023-09-14 04:16:11
# 834 2023-09-14 04:15:53
# 881 2023-09-14 04:15:36
#
#     Difference between Gressoney IN Timestamp and Gressoney IN Wave2 Cut Off
# 673                                  -1 days +23:58:59
# 820                                  -1 days +20:43:49
# 834                                  -1 days +20:44:07
# 881                                  -1 days +20:44:24
# C:\Users\Karina\AppData\Local\Temp\ipykernel_20632\3384109751.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pivoted_TOR330_dates_DNF.loc[condition, f'Difference between {column} Timestamp and {column} {wave} Cut Off'] = (
# C:\Users\Karina\AppData\Local\Temp\ipykernel_20632\3384109751.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pivoted_TOR330_dates_DNF[f'Difference between {column} Timestamp and {column} {wave} Cut Off_hours'] = pd.to_timedelta(
# Processing column: Gressoney OUT
# Stage cut-off for Gressoney OUT, Wave1: 2023-09-14T01:00:00.000000000
#           Gressoney OUT  \
# 267 2023-09-14 01:33:04
# 301 2023-09-14 01:05:41
# 333 2023-09-14 02:08:42
# 476 2023-09-14 02:19:30
# 484 2023-09-14 01:05:30
# 499 2023-09-14 01:58:42
# 525 2023-09-14 01:00:22
# 549 2023-09-14 02:43:51
#
#     Difference between Gressoney OUT Timestamp and Gressoney OUT Wave1 Cut Off
# 267                                  -1 days +23:26:56
# 301                                  -1 days +23:54:19
# 333                                  -1 days +22:51:18
# 476                                  -1 days +22:40:30
# 484                                  -1 days +23:54:30
# 499                                  -1 days +23:01:18
# 525                                  -1 days +23:59:38
# 549                                  -1 days +22:16:09
# C:\Users\Karina\AppData\Local\Temp\ipykernel_20632\3384109751.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pivoted_TOR330_dates_DNF.loc[condition, f'Difference between {column} Timestamp and {column} {wave} Cut Off'] = (
# C:\Users\Karina\AppData\Local\Temp\ipykernel_20632\3384109751.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pivoted_TOR330_dates_DNF[f'Difference between {column} Timestamp and {column} {wave} Cut Off_hours'] = pd.to_timedelta(
# Stage cut-off for Gressoney OUT, Wave2: 2023-09-14T03:00:00.000000000
#            Gressoney OUT  \
# 726  2023-09-14 03:03:06
# 741  2023-09-14 03:04:49
# 1078 2023-09-14 03:46:27
# 1171 2023-09-14 03:01:12
#
#      Difference between Gressoney OUT Timestamp and Gressoney OUT Wave2 Cut Off
# 726                                   -1 days +23:56:54
# 741                                   -1 days +23:55:11
# 1078                                  -1 days +23:13:33
# 1171                                  -1 days +23:58:48
# C:\Users\Karina\AppData\Local\Temp\ipykernel_20632\3384109751.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pivoted_TOR330_dates_DNF.loc[condition, f'Difference between {column} Timestamp and {column} {wave} Cut Off'] = (
# C:\Users\Karina\AppData\Local\Temp\ipykernel_20632\3384109751.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pivoted_TOR330_dates_DNF[f'Difference between {column} Timestamp and {column} {wave} Cut Off_hours'] = pd.to_timedelta(
# Processing column: Valtournenche IN
# Stage cut-off for Valtournenche IN, Wave1: 2023-09-14T19:00:00.000000000
# Empty DataFrame
# Columns: [Valtournenche IN, Difference between Valtournenche IN Timestamp and Valtournenche IN Wave1 Cut Off]
# Index: []
# C:\Users\Karina\AppData\Local\Temp\ipykernel_20632\3384109751.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pivoted_TOR330_dates_DNF.loc[condition, f'Difference between {column} Timestamp and {column} {wave} Cut Off'] = (
# C:\Users\Karina\AppData\Local\Temp\ipykernel_20632\3384109751.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pivoted_TOR330_dates_DNF[f'Difference between {column} Timestamp and {column} {wave} Cut Off_hours'] = pd.to_timedelta(
# Stage cut-off for Valtournenche IN, Wave2: 2023-09-14T21:00:00.000000000
# Empty DataFrame
# Columns: [Valtournenche IN, Difference between Valtournenche IN Timestamp and Valtournenche IN Wave2 Cut Off]
# Index: []
# C:\Users\Karina\AppData\Local\Temp\ipykernel_20632\3384109751.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pivoted_TOR330_dates_DNF.loc[condition, f'Difference between {column} Timestamp and {column} {wave} Cut Off'] = (
# C:\Users\Karina\AppData\Local\Temp\ipykernel_20632\3384109751.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pivoted_TOR330_dates_DNF[f'Difference between {column} Timestamp and {column} {wave} Cut Off_hours'] = pd.to_timedelta(
# Processing column: Valtournenche OUT
# Stage cut-off for Valtournenche OUT, Wave1: 2023-09-14T21:00:00.000000000
# Empty DataFrame
# Columns: [Valtournenche OUT, Difference between Valtournenche OUT Timestamp and Valtournenche OUT Wave1 Cut Off]
# Index: []
# C:\Users\Karina\AppData\Local\Temp\ipykernel_20632\3384109751.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pivoted_TOR330_dates_DNF.loc[condition, f'Difference between {column} Timestamp and {column} {wave} Cut Off'] = (
# C:\Users\Karina\AppData\Local\Temp\ipykernel_20632\3384109751.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pivoted_TOR330_dates_DNF[f'Difference between {column} Timestamp and {column} {wave} Cut Off_hours'] = pd.to_timedelta(
# Stage cut-off for Valtournenche OUT, Wave2: 2023-09-14T23:00:00.000000000
# Empty DataFrame
# Columns: [Valtournenche OUT, Difference between Valtournenche OUT Timestamp and Valtournenche OUT Wave2 Cut Off]
# Index: []
# C:\Users\Karina\AppData\Local\Temp\ipykernel_20632\3384109751.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pivoted_TOR330_dates_DNF.loc[condition, f'Difference between {column} Timestamp and {column} {wave} Cut Off'] = (
# C:\Users\Karina\AppData\Local\Temp\ipykernel_20632\3384109751.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pivoted_TOR330_dates_DNF[f'Difference between {column} Timestamp and {column} {wave} Cut Off_hours'] = pd.to_timedelta(
# Processing column: Ollomont IN
# Stage cut-off for Ollomont IN, Wave1: 2023-09-15T17:00:00.000000000
# C:\Users\Karina\AppData\Local\Temp\ipykernel_20632\3384109751.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pivoted_TOR330_dates_DNF.loc[condition, f'Difference between {column} Timestamp and {column} {wave} Cut Off'] = (
#             Ollomont IN  \
# 256 2023-09-15 17:41:21
# 353 2023-09-15 19:27:41
# 542 2023-09-15 17:59:07
# 569 2023-09-15 18:40:36
#
#     Difference between Ollomont IN Timestamp and Ollomont IN Wave1 Cut Off
# 256                                  -1 days +23:18:39
# 353                                  -1 days +21:32:19
# 542                                  -1 days +23:00:53
# 569                                  -1 days +22:19:24
# C:\Users\Karina\AppData\Local\Temp\ipykernel_20632\3384109751.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pivoted_TOR330_dates_DNF[f'Difference between {column} Timestamp and {column} {wave} Cut Off_hours'] = pd.to_timedelta(
# Stage cut-off for Ollomont IN, Wave2: 2023-09-15T19:00:00.000000000
# Empty DataFrame
# Columns: [Ollomont IN, Difference between Ollomont IN Timestamp and Ollomont IN Wave2 Cut Off]
# Index: []
# C:\Users\Karina\AppData\Local\Temp\ipykernel_20632\3384109751.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pivoted_TOR330_dates_DNF.loc[condition, f'Difference between {column} Timestamp and {column} {wave} Cut Off'] = (
# C:\Users\Karina\AppData\Local\Temp\ipykernel_20632\3384109751.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pivoted_TOR330_dates_DNF[f'Difference between {column} Timestamp and {column} {wave} Cut Off_hours'] = pd.to_timedelta(
# Processing column: Ollomont OUT
# Stage cut-off for Ollomont OUT, Wave1: 2023-09-15T19:00:00.000000000
#            Ollomont OUT  \
# 256 2023-09-15 19:04:40
#
#     Difference between Ollomont OUT Timestamp and Ollomont OUT Wave1 Cut Off
# 256                                  -1 days +23:55:20
# C:\Users\Karina\AppData\Local\Temp\ipykernel_20632\3384109751.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pivoted_TOR330_dates_DNF.loc[condition, f'Difference between {column} Timestamp and {column} {wave} Cut Off'] = (
# C:\Users\Karina\AppData\Local\Temp\ipykernel_20632\3384109751.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pivoted_TOR330_dates_DNF[f'Difference between {column} Timestamp and {column} {wave} Cut Off_hours'] = pd.to_timedelta(
# Stage cut-off for Ollomont OUT, Wave2: 2023-09-15T21:00:00.000000000
#            Ollomont OUT  \
# 700 2023-09-15 21:24:20
#
#     Difference between Ollomont OUT Timestamp and Ollomont OUT Wave2 Cut Off
# 700                                  -1 days +23:35:40
# C:\Users\Karina\AppData\Local\Temp\ipykernel_20632\3384109751.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pivoted_TOR330_dates_DNF.loc[condition, f'Difference between {column} Timestamp and {column} {wave} Cut Off'] = (
# C:\Users\Karina\AppData\Local\Temp\ipykernel_20632\3384109751.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pivoted_TOR330_dates_DNF[f'Difference between {column} Timestamp and {column} {wave} Cut Off_hours'] = pd.to_timedelta(

# %% [markdown]
# ### Looking for the Polish Fella!
#
# When I ran TOR 2023, I distingly remember running into a Polish fella as I was leaving Gressoney. I was hiking with him from Rifugio Barma, he was in Wave 1. I remember running up to him at the lifebase, all excited "Hey, you made it!"
#
# The reply I recieved was "WHat are you talking about? I missed the cutoff"
#
# So I began looking for him to find out why I dont have more people who missed the cut off!
#
# Here I am leaving Gressoney!
#
# ![image-4.png](attachment:image-4.png)
#
# This is the cut off times
# ![image-2.png](attachment:image-2.png)
#
# I looked for all the Poles that DNFed the race
#
# ![image-6.png](attachment:image-6.png)!
#
# It is clear that he DNFed at 'Gressoney OUT - RITIRIO'
# ![image-3.png](attachment:image-3.png)
# This is what is causing my heartache!

# %%
pivoted_TOR330_dates_DNF[['Bib','Nationality','Wave', 'Gressoney IN',
                          'Difference between Gressoney IN Timestamp and Gressoney IN Wave1 Cut Off', 
                          'Retired']][
    pivoted_TOR330_dates_DNF['Nationality'] == 'PL']
# Out:
#        Bib Nationality   Wave        Gressoney IN  \
# 439    451          PL  Wave1                 NaT
# 516    532          PL  Wave1                 NaT
# 534    550          PL  Wave1                 NaT
# 1058  1422          PL  Wave2 2023-09-13 23:26:29
#
#      Difference between Gressoney IN Timestamp and Gressoney IN Wave1 Cut Off  \
# 439                                                 NaT
# 516                                                 NaT
# 534                                                 NaT
# 1058                                                NaT
#
#             Retired
# 439       La Thuile
# 516       Gressoney
# 534        Planaval
# 1058  Rifugio Magià

# %%
pivoted_TOR330_dates[[ 'Bib', 'Nationality','Wave', 'Gressoney OUT']][
    pivoted_TOR330_dates['Bib'] == 1440]
# Out:
#        Bib Nationality   Wave       Gressoney OUT
# 1074  1440          IE  Wave2 2023-09-13 23:37:01

# %%
cutoffs_df_pivot_2023[['Year', 'Wave', 'Cut Off | Gressoney IN']]
# Out:
#    Year   Wave Cut Off | Gressoney IN
# 6  2023  Wave1    2023-09-13 23:00:00
# 7  2023  Wave2    2023-09-14 01:00:00

# %%
# Pivot the data so that each participant has its own column
polish =  TOR330[['Bib', 'Sex', 
           'Nationality', 'Category', 'Race','Year', 'Status' , 'Place', 'new_Time'
          ]].reset_index(drop = True)


polish[polish['Bib'] == 532].sort_values(by= 'new_Time', ascending = True)[-10:]
# Out:
#        Bib Sex Nationality Category    Race  Year  Status  \
# 37172  532   M          PL       V1  TOR330  2023   False
# 37171  532   M          PL       V1  TOR330  2023   False
# 37170  532   M          PL       V1  TOR330  2023   False
# 37169  532   M          PL       V1  TOR330  2023   False
# 37168  532   M          PL       V1  TOR330  2023   False
# 37167  532   M          PL       V1  TOR330  2023   False
# 37166  532   M          PL       V1  TOR330  2023   False
# 37165  532   M          PL       V1  TOR330  2023   False
# 37164  532   M          PL       V1  TOR330  2023   False
# 37193  532   M          PL       V1  TOR330  2023   False
#
#                                   Place            new_Time
# 37172              291 - Donnas OUT 450 2023-09-12 20:06:33
# 37171                      300 - Perloz 2023-09-12 22:06:03
# 37170                       310 - Sassa 2023-09-13 01:35:04
# 37169               320 - Rif. Coda 450 2023-09-13 04:20:48
# 37168        330 - Rif. della Barma 450 2023-09-13 10:09:27
# 37167                 340 - Lago Chiaro 2023-09-13 12:42:50
# 37166           350 - Col della Vecchia 2023-09-13 14:50:17
# 37165           360 - Niel La Gruba 450 2023-09-13 17:23:49
# 37164                         370 - Loo 2023-09-13 21:25:39
# 37193  381 - Gressoney OUT 330 - RITIRO 2023-09-13 23:36:16

# %% [markdown]
# #### RITIRIO
#
# ![image.png](attachment:image.png)
#
#
#
# ![image-2.png](attachment:image-2.png)

# %%
# Pattern to match "OUT Number - RITIRO"
pattern = r'OUT \d+ - RITIRO'

TOR330[TOR330['Place'].str.contains(pattern, na=False)]
# Out:
#                                     Name   Bib Sex Nationality    Race  Year  \
# TOR330_2023 8901          Smith Jonathan  1321   M          AU  TOR330  2023
#             32389  Houteer Magni Justine   275   F          FR  TOR330  2023
#             33742        Delafond Sandra  1560   F          FR  TOR330  2023
#             33764   Compan Jean Philippe  1403   M          FR  TOR330  2023
#             34266           Pang Kin Sun   610   M          HK  TOR330  2023
# ...                                  ...   ...  ..         ...     ...   ...
#             40846        Barraud Laurent   492   M          FR  TOR330  2023
#             40875             Crump Neil  1203   M          GB  TOR330  2023
#             40890              Noma Yoko   618   F          JP  TOR330  2023
#             40918            Ozawa Morio  1225   M          JP  TOR330  2023
#             40933         Comoglio Peter   250   M          FR  TOR330  2023
#
#                   Category                             Place  \
# TOR330_2023 8901        V2     291 - Donnas OUT 450 - RITIRO
#             32389       V1  381 - Gressoney OUT 330 - RITIRO
#             33742       V1     291 - Donnas OUT 450 - RITIRO
#             33764       V1     291 - Donnas OUT 450 - RITIRO
#             34266       V2   581 - Ollomont OUT 330 - RITIRO
# ...                    ...                               ...
#             40846       V1      201 - Cogne OUT 330 - RITIRO
#             40875       V1      201 - Cogne OUT 330 - RITIRO
#             40890       V2      201 - Cogne OUT 330 - RITIRO
#             40918       V2      201 - Cogne OUT 330 - RITIRO
#             40933      SEN      201 - Cogne OUT 330 - RITIRO
#
#                                         Time  Status   aid_stations  \
# TOR330_2023 8901   2023-09-12T17:18:56+02:00    True     Donnas OUT
#             32389  2023-09-14T01:33:04+02:00    True  Gressoney OUT
#             33742  2023-09-13T03:44:36+02:00   False     Donnas OUT
#             33764  2023-09-13T03:44:00+02:00   False     Donnas OUT
#             34266  2023-09-15T11:34:58+02:00   False   Ollomont OUT
# ...                                      ...     ...            ...
#             40846  2023-09-12T03:22:18+02:00   False      Cogne OUT
#             40875  2023-09-12T06:40:03+02:00   False      Cogne OUT
#             40890  2023-09-12T05:41:37+02:00   False      Cogne OUT
#             40918  2023-09-12T08:05:12+02:00   False      Cogne OUT
#             40933  2023-09-12T07:35:15+02:00   False      Cogne OUT
#
#                                   RITIRIO            new_Time
# TOR330_2023 8901      Donnas OUT - RITIRO 2023-09-12 17:18:56
#             32389  Gressoney OUT - RITIRO 2023-09-14 01:33:04
#             33742     Donnas OUT - RITIRO 2023-09-13 03:44:36
#             33764     Donnas OUT - RITIRO 2023-09-13 03:44:00
#             34266   Ollomont OUT - RITIRO 2023-09-15 11:34:58
# ...                                   ...                 ...
#             40846      Cogne OUT - RITIRO 2023-09-12 03:22:18
#             40875      Cogne OUT - RITIRO 2023-09-12 06:40:03
#             40890      Cogne OUT - RITIRO 2023-09-12 05:41:37
#             40918      Cogne OUT - RITIRO 2023-09-12 08:05:12
#             40933      Cogne OUT - RITIRO 2023-09-12 07:35:15
#
# [79 rows x 13 columns]

# %%
for i in TOR330['RITIRIO'].unique():
    print(i)
# Out:
# Donnas IN - RITIRO
# Rifugio Magià - RITIRO
# Donnas OUT - RITIRO
# Gressoney OUT - RITIRO
# Ollomont OUT - RITIRO
# Ollomont IN - RITIRO
# Lago Chiaro - RITIRO
# Oyace - RITIRO
# Valtournenche OUT - RITIRO
# Champoluc - RITIRO
# Sassa - RITIRO
# Rifugio della Barma - RITIRO
# Gressoney IN - RITIRO
# Niel La Gruba - RITIRO
# Col della Vecchia - RITIRO
# Chardonney - RITIRO
# Valgrisenche OUT - RITIRO
# Rifugio Dondena - RITIRO
# Goilles - RITIRO
# Cogne OUT - RITIRO
# Cogne IN - RITIRO
# Rifugio Sella - RITIRO
# Eaux Rousse - RITIRO
# Rhemes-Notre-Dame - RITIRO
# Chalet Epee - RITIRO
# Valgrisenche IN - RITIRO
# La Thuile - RITIRO
# Baite Youlaz - RITIRO

# %% [markdown]
# ### FIxing issue with Cut Offs

# %%
for column in [
    'Gressoney IN', 'Gressoney OUT',
    # Uncomment more columns as needed
]:
    print(f"Processing column: {column}")
    for wave in ['Wave1', 'Wave2']:
        # Define the new cutoff column dynamically
        new_column = f'Cut Off | {column}'
        
        # Extract the stage cutoff value for the specific wave
        try:
            stage_cut_off = cutoffs_df_pivot_2023.loc[
                cutoffs_df_pivot_2023['Wave'] == wave, new_column
            ].values[0]  # Using .values[0] for the first value found
        except IndexError:
            print(f"No stage cutoff found for {column}, {wave}")
            continue
        
        print(f"Stage cut-off for {column}, {wave}: {stage_cut_off}")
        
        # Add 'Missed' column if not already present
        if 'Missed IN' not in pivoted_TOR330_dates_DNF.columns:
            pivoted_TOR330_dates_DNF['Missed IN'] = None
        
        
        if 'Missed OUT' not in pivoted_TOR330_dates_DNF.columns:
            pivoted_TOR330_dates_DNF['Missed OUT'] = None
        
        # Condition to filter data for the specific wave
        condition = pivoted_TOR330_dates_DNF['Wave'] == wave
        
        # Create column to hold differences, initialized to None
        difference_col = f'Difference between {column} Timestamp and {column} {wave} Cut Off'
        pivoted_TOR330_dates_DNF[difference_col] = None
        
#         print(pivoted_TOR330_dates_DNF[column].loc[condition].unique())
        
        # Iterate over rows under the condition
        for idx, row in pivoted_TOR330_dates_DNF.loc[condition].iterrows():
            if pd.isna(row.get('Gressoney IN')) and not pd.isna(row.get('Gressoney OUT')):
                # If 'Gressoney IN' is missing but 'Gressoney OUT' exists
                difference = stage_cut_off - row['Gressoney OUT']
                pivoted_TOR330_dates_DNF.loc[idx, 'Missed IN'] = 'Gressoney IN'

                
            elif not pd.isna(row.get('Gressoney IN')) and pd.isna(row.get('Gressoney OUT')):
                # If 'Gressoney IN' exists, calculate difference
                difference = stage_cut_off - row['Gressoney OUT']
                pivoted_TOR330_dates_DNF.loc[idx, 'Missed OUT'] = 'Gressoney OUT'
                print('Missed Gressoney')
                
            elif not pd.isna(row.get('Gressoney IN')) and not pd.isna(row.get('Gressoney OUT')):
                # If 'Gressoney IN' is missing but 'Gressoney OUT' exists
                difference = stage_cut_off - row['Gressoney OUT']
                pivoted_TOR330_dates_DNF.loc[idx, 'Missed IN'] = 'Gressoney IN'
                pivoted_TOR330_dates_DNF.loc[idx, 'Missed OUT'] = 'Gressoney OUT'
            
            else:
                # If both are missing, skip processing this row
                difference = None
#                 print('No Value')
#                 pivoted_TOR330_dates_DNF.loc[idx, 'Missed'] = f'{column} (Both values missing)'
            
            # Save the result in the difference column
            pivoted_TOR330_dates_DNF.loc[idx, difference_col] = difference

        # Convert to timedelta and extract total hours (handling NaT)
        hours_col = f'{difference_col}_hours'
        pivoted_TOR330_dates_DNF[hours_col] = pd.to_timedelta(
            pivoted_TOR330_dates_DNF[difference_col], errors='coerce'
        ).dt.total_seconds() / 3600  # Convert seconds to hours
        
        # Identify and print negative values
        negative_values = pivoted_TOR330_dates_DNF.loc[
            condition & (pivoted_TOR330_dates_DNF[difference_col] < pd.to_timedelta('00:00:00')),
            [column, difference_col]
        ]
        if not negative_values.empty:
            print(f"Negative values for {column}, {wave}:")
            print(negative_values)
        
        # Plot the histogram
        data_to_plot = pivoted_TOR330_dates_DNF[hours_col].dropna()
        if not data_to_plot.empty:
            plt.figure(figsize=(8, 5))
            sns.histplot(data_to_plot, kde=True, bins=30, color="lightcoral")
            plt.title(f"Difference between {column} Timestamp and {column} {wave} Cut Off")
            plt.xlabel("Time (hours)")
            plt.ylabel("Frequency")
            plt.grid(True)
            plt.show()
        else:
            print(f"No valid data to plot for {column}, {wave}.")
# Out:
# Processing column: Gressoney IN
# Stage cut-off for Gressoney IN, Wave1: 2023-09-13T23:00:00.000000000
# C:\Users\Karina\AppData\Local\Temp\ipykernel_20632\1776555581.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pivoted_TOR330_dates_DNF[difference_col] = None
# Missed Gressoney
# C:\Users\Karina\AppData\Local\Temp\ipykernel_20632\1776555581.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pivoted_TOR330_dates_DNF[hours_col] = pd.to_timedelta(
# Negative values for Gressoney IN, Wave1:
#            Gressoney IN  \
# 180 2023-09-13 21:01:54
# 267                 NaT
# 293 2023-09-13 21:37:43
# 301 2023-09-13 21:06:28
# 333                 NaT
# 337                 NaT
# 352 2023-09-13 16:38:29
# 353 2023-09-13 20:43:45
# 387 2023-09-13 18:24:38
# 476                 NaT
# 484 2023-09-13 22:57:42
# 498 2023-09-13 18:57:33
# 499                 NaT
# 516                 NaT
# 525 2023-09-13 22:28:17
# 541 2023-09-13 20:16:22
# 542 2023-09-13 22:45:48
# 549                 NaT
# 554 2023-09-13 21:37:39
# 569 2023-09-13 19:58:34
# 585                 NaT
# 589 2023-09-13 21:12:53
#
#     Difference between Gressoney IN Timestamp and Gressoney IN Wave1 Cut Off
# 180                                  -1 days +23:44:43
# 267                                  -1 days +21:26:56
# 293                                  -1 days +22:19:33
# 301                                  -1 days +21:54:19
# 333                                  -1 days +20:51:18
# 337                                  -1 days +23:51:59
# 352                                  -1 days +22:38:14
# 353                                  -1 days +22:18:48
# 387                                  -1 days +23:51:29
# 476                                  -1 days +20:40:30
# 484                                  -1 days +21:54:30
# 498                                  -1 days +22:21:35
# 499                                  -1 days +21:01:18
# 516                                  -1 days +23:23:44
# 525                                  -1 days +21:59:38
# 541                                  -1 days +23:51:11
# 542                                  -1 days +23:00:59
# 549                                  -1 days +20:16:09
# 554                                  -1 days +22:19:22
# 569                                  -1 days +22:02:21
# 585                                  -1 days +22:24:54
# 589                                  -1 days +23:09:37
# Stage cut-off for Gressoney IN, Wave2: 2023-09-14T01:00:00.000000000
# C:\Users\Karina\AppData\Local\Temp\ipykernel_20632\1776555581.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pivoted_TOR330_dates_DNF[difference_col] = None
# Missed Gressoney
# Missed Gressoney
# Missed Gressoney
# Missed Gressoney
# C:\Users\Karina\AppData\Local\Temp\ipykernel_20632\1776555581.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pivoted_TOR330_dates_DNF[hours_col] = pd.to_timedelta(
# Negative values for Gressoney IN, Wave2:
#             Gressoney IN  \
# 648  2023-09-13 19:27:13
# 652  2023-09-14 00:06:34
# 654  2023-09-13 23:54:45
# 655  2023-09-13 22:51:31
# 664  2023-09-14 00:42:41
# 673  2023-09-14 01:01:01
# 710                  NaT
# 721                  NaT
# 725                  NaT
# 726  2023-09-13 17:46:56
# 732  2023-09-13 21:53:29
# 733                  NaT
# 741  2023-09-14 00:58:47
# 752                  NaT
# 754                  NaT
# 755  2023-09-14 00:48:15
# 761  2023-09-14 00:44:05
# 763                  NaT
# 768                  NaT
# 783                  NaT
# 855  2023-09-14 00:54:07
# 856                  NaT
# 879  2023-09-14 00:39:14
# 883  2023-09-13 23:14:50
# 913                  NaT
# 922  2023-09-13 23:33:36
# 941                  NaT
# 999  2023-09-14 00:44:36
# 1023 2023-09-14 00:52:59
# 1055 2023-09-13 21:42:49
# 1057 2023-09-13 22:50:46
# 1058 2023-09-13 23:26:29
# 1078                 NaT
# 1103 2023-09-14 00:41:37
# 1139 2023-09-13 23:28:32
# 1171 2023-09-13 18:20:14
#
#      Difference between Gressoney IN Timestamp and Gressoney IN Wave2 Cut Off
# 648                                   -1 days +23:45:30
# 652                                   -1 days +22:03:55
# 654                                   -1 days +22:12:04
# 655                                   -1 days +22:14:29
# 664                                   -1 days +22:00:24
# 673                                   -1 days +22:01:33
# 710                                   -1 days +22:58:15
# 721                                   -1 days +23:26:44
# 725                                   -1 days +23:17:46
# 726                                   -1 days +21:56:54
# 732                                   -1 days +22:56:03
# 733                                   -1 days +23:17:53
# 741                                   -1 days +21:55:11
# 752                                   -1 days +22:10:22
# 754                                   -1 days +22:45:56
# 755                                   -1 days +22:44:52
# 761                                   -1 days +22:00:56
# 763                                   -1 days +23:35:17
# 768                                   -1 days +23:07:13
# 783                                   -1 days +22:12:16
# 855                                   -1 days +22:05:31
# 856                                   -1 days +23:37:50
# 879                                   -1 days +22:03:43
# 883                                   -1 days +23:26:32
# 913                                   -1 days +22:48:05
# 922                                   -1 days +22:02:08
# 941                                   -1 days +22:32:05
# 999                                   -1 days +22:00:38
# 1023                                  -1 days +22:06:55
# 1055                                  -1 days +22:04:07
# 1057                                  -1 days +22:11:37
# 1058                                  -1 days +22:04:42
# 1078                                  -1 days +21:13:33
# 1103                                  -1 days +22:05:04
# 1139                                  -1 days +22:14:15
# 1171                                  -1 days +21:58:48
# Processing column: Gressoney OUT
# Stage cut-off for Gressoney OUT, Wave1: 2023-09-14T01:00:00.000000000
# Missed Gressoney
# C:\Users\Karina\AppData\Local\Temp\ipykernel_20632\1776555581.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pivoted_TOR330_dates_DNF[difference_col] = None
# C:\Users\Karina\AppData\Local\Temp\ipykernel_20632\1776555581.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pivoted_TOR330_dates_DNF[hours_col] = pd.to_timedelta(
# Negative values for Gressoney OUT, Wave1:
#           Gressoney OUT  \
# 267 2023-09-14 01:33:04
# 301 2023-09-14 01:05:41
# 333 2023-09-14 02:08:42
# 476 2023-09-14 02:19:30
# 484 2023-09-14 01:05:30
# 499 2023-09-14 01:58:42
# 525 2023-09-14 01:00:22
# 549 2023-09-14 02:43:51
#
#     Difference between Gressoney OUT Timestamp and Gressoney OUT Wave1 Cut Off
# 267                                  -1 days +23:26:56
# 301                                  -1 days +23:54:19
# 333                                  -1 days +22:51:18
# 476                                  -1 days +22:40:30
# 484                                  -1 days +23:54:30
# 499                                  -1 days +23:01:18
# 525                                  -1 days +23:59:38
# 549                                  -1 days +22:16:09
# Stage cut-off for Gressoney OUT, Wave2: 2023-09-14T03:00:00.000000000
# C:\Users\Karina\AppData\Local\Temp\ipykernel_20632\1776555581.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pivoted_TOR330_dates_DNF[difference_col] = None
# Missed Gressoney
# Missed Gressoney
# Missed Gressoney
# Missed Gressoney
# C:\Users\Karina\AppData\Local\Temp\ipykernel_20632\1776555581.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pivoted_TOR330_dates_DNF[hours_col] = pd.to_timedelta(
# Negative values for Gressoney OUT, Wave2:
#            Gressoney OUT  \
# 726  2023-09-14 03:03:06
# 741  2023-09-14 03:04:49
# 1078 2023-09-14 03:46:27
# 1171 2023-09-14 03:01:12
#
#      Difference between Gressoney OUT Timestamp and Gressoney OUT Wave2 Cut Off
# 726                                   -1 days +23:56:54
# 741                                   -1 days +23:55:11
# 1078                                  -1 days +23:13:33
# 1171                                  -1 days +23:58:48

# %%
pivoted_TOR330_dates_DNF.groupby(['Wave', 'Missed IN'])['Missed IN'].count()
# Out:
# Wave   Missed IN
# Wave1  Gressoney IN    51
# Wave2  Gressoney IN    66
# Name: Missed IN, dtype: int64

# %%
pivoted_TOR330_dates_DNF.groupby(['Wave', 'Missed OUT'])['Missed OUT'].count()
# Out:
# Wave   Missed OUT
# Wave1  Gressoney OUT    42
# Wave2  Gressoney OUT    39
# Name: Missed OUT, dtype: int64

# %%
pivoted_TOR330_dates_DNF[
    ~(pivoted_TOR330_dates_DNF['Missed IN'].isnull()) |
    ~(pivoted_TOR330_dates_DNF['Missed OUT'].isnull())
].shape
# Out:
# (117, 119)

# %%
missed_gressoney_pivoted_TOR330_dates_DNF =  pivoted_TOR330_dates_DNF[
    ~(pivoted_TOR330_dates_DNF['Missed IN'].isnull()) |
    ~(pivoted_TOR330_dates_DNF['Missed OUT'].isnull())
]
missed_gressoney_pivoted_TOR330_dates_DNF
# Out:
#                   Name   Bib Sex Nationality  Year    Race Category  Status  \
# 9       Chorier Julien    10   M          FR  2023  TOR330       V1   False
# 15    Antonov Bozhidar    16   M          BG  2023  TOR330      SEN   False
# 29      Minami Keisuke    30   M          JP  2023  TOR330      SEN   False
# 31        Negro Mattia    32   M          IT  2023  TOR330      SEN   False
# 55          Moberg Max    56   M          FI  2023  TOR330      SEN   False
# ...                ...   ...  ..         ...   ...     ...      ...     ...
# 1103   Vagaggini Paolo  1470   M          IT  2023  TOR330       V2   False
# 1113     Pitetti Fabio  1481   M          IT  2023  TOR330       V1   False
# 1139     Prosperi Luca  1507   M          BR  2023  TOR330       V1   False
# 1171   Vitale Giovanni  1539   M          IT  2023  TOR330       V2   False
# 1183     Lainema Tommi  1551   M          FI  2023  TOR330       V2   False
#
#      Status1   Wave  ...  \
# 9        DNF  Wave1  ...
# 15       DNF  Wave1  ...
# 29       DNF  Wave1  ...
# 31       DNF  Wave1  ...
# 55       DNF  Wave1  ...
# ...      ...    ...  ...
# 1103     DNF  Wave2  ...
# 1113     DNF  Wave2  ...
# 1139     DNF  Wave2  ...
# 1171     DNF  Wave2  ...
# 1183     DNF  Wave2  ...
#
#      Difference between Ollomont IN Timestamp and Ollomont IN Wave1 Cut Off_hours  \
# 9                                                   NaN
# 15                                                  NaN
# 29                                                  NaN
# 31                                                  NaN
# 55                                            57.206111
# ...                                                 ...
# 1103                                                NaN
# 1113                                                NaN
# 1139                                                NaN
# 1171                                                NaN
# 1183                                                NaN
#
#      Difference between Ollomont IN Timestamp and Ollomont IN Wave2 Cut Off  \
# 9                                                   NaT
# 15                                                  NaT
# 29                                                  NaT
# 31                                                  NaT
# 55                                                  NaT
# ...                                                 ...
# 1103                                                NaT
# 1113                                                NaT
# 1139                                                NaT
# 1171                                                NaT
# 1183                                                NaT
#
#      Difference between Ollomont IN Timestamp and Ollomont IN Wave2 Cut Off_hours  \
# 9                                                   NaN
# 15                                                  NaN
# 29                                                  NaN
# 31                                                  NaN
# 55                                                  NaN
# ...                                                 ...
# 1103                                                NaN
# 1113                                                NaN
# 1139                                                NaN
# 1171                                                NaN
# 1183                                                NaN
#
#      Difference between Ollomont OUT Timestamp and Ollomont OUT Wave1 Cut Off  \
# 9                                                   NaT
# 15                                                  NaT
# 29                                                  NaT
# 31                                                  NaT
# 55                                      2 days 10:27:49
# ...                                                 ...
# 1103                                                NaT
# 1113                                                NaT
# 1139                                                NaT
# 1171                                                NaT
# 1183                                                NaT
#
#      Difference between Ollomont OUT Timestamp and Ollomont OUT Wave1 Cut Off_hours  \
# 9                                                   NaN
# 15                                                  NaN
# 29                                                  NaN
# 31                                                  NaN
# 55                                            58.463611
# ...                                                 ...
# 1103                                                NaN
# 1113                                                NaN
# 1139                                                NaN
# 1171                                                NaN
# 1183                                                NaN
#
#      Difference between Ollomont OUT Timestamp and Ollomont OUT Wave2 Cut Off  \
# 9                                                   NaT
# 15                                                  NaT
# 29                                                  NaT
# 31                                                  NaT
# 55                                                  NaT
# ...                                                 ...
# 1103                                                NaT
# 1113                                                NaT
# 1139                                                NaT
# 1171                                                NaT
# 1183                                                NaT
#
#      Difference between Ollomont OUT Timestamp and Ollomont OUT Wave2 Cut Off_hours  \
# 9                                                   NaN
# 15                                                  NaN
# 29                                                  NaN
# 31                                                  NaN
# 55                                                  NaN
# ...                                                 ...
# 1103                                                NaN
# 1113                                                NaN
# 1139                                                NaN
# 1171                                                NaN
# 1183                                                NaN
#
#             Missed     Missed IN     Missed OUT
# 9     Gressoney IN  Gressoney IN  Gressoney OUT
# 15    Gressoney IN  Gressoney IN  Gressoney OUT
# 29    Gressoney IN  Gressoney IN  Gressoney OUT
# 31    Gressoney IN  Gressoney IN  Gressoney OUT
# 55    Gressoney IN  Gressoney IN  Gressoney OUT
# ...            ...           ...            ...
# 1103  Gressoney IN  Gressoney IN  Gressoney OUT
# 1113  Gressoney IN  Gressoney IN            NaN
# 1139  Gressoney IN  Gressoney IN  Gressoney OUT
# 1171  Gressoney IN  Gressoney IN  Gressoney OUT
# 1183  Gressoney IN  Gressoney IN  Gressoney OUT
#
# [117 rows x 119 columns]

# %%
for column in [
    'Gressoney IN', 'Gressoney OUT',
    # Uncomment more columns as needed
]:
    print(f"Processing column: {column}")
    for wave in ['Wave1', 'Wave2']:

    # Identify and print negative values
        negative_values = missed_gressoney_pivoted_TOR330_dates_DNF.loc[
            condition & (missed_gressoney_pivoted_TOR330_dates_DNF[difference_col] < pd.to_timedelta('00:00:00')),
            [column, difference_col]
        ]
        if not negative_values.empty:
            print(f"Negative values for {column}, {wave}:")
            print(negative_values)

        # Plot the histogram
        data_to_plot = missed_gressoney_pivoted_TOR330_dates_DNF[hours_col].dropna()
        if not data_to_plot.empty:
            plt.figure(figsize=(8, 5))
            sns.histplot(data_to_plot, kde=True, bins=30, color="lightcoral")
            plt.title(f"Difference between {column} Timestamp and {column} {wave} Cut Off")
            plt.xlabel("Time (hours)")
            plt.ylabel("Frequency")
            plt.grid(True)
            plt.show()
        else:
            print(f"No valid data to plot for {column}, {wave}.")
# Out:
# Processing column: Gressoney IN
# Negative values for Gressoney IN, Wave1:
#             Gressoney IN  \
# 726  2023-09-13 17:46:56
# 741  2023-09-14 00:58:47
# 1078                 NaT
# 1171 2023-09-13 18:20:14
#
#      Difference between Gressoney OUT Timestamp and Gressoney OUT Wave2 Cut Off
# 726                                   -1 days +23:56:54
# 741                                   -1 days +23:55:11
# 1078                                  -1 days +23:13:33
# 1171                                  -1 days +23:58:48
# Negative values for Gressoney IN, Wave2:
#             Gressoney IN  \
# 726  2023-09-13 17:46:56
# 741  2023-09-14 00:58:47
# 1078                 NaT
# 1171 2023-09-13 18:20:14
#
#      Difference between Gressoney OUT Timestamp and Gressoney OUT Wave2 Cut Off
# 726                                   -1 days +23:56:54
# 741                                   -1 days +23:55:11
# 1078                                  -1 days +23:13:33
# 1171                                  -1 days +23:58:48
# Processing column: Gressoney OUT
# Negative values for Gressoney OUT, Wave1:
#            Gressoney OUT  \
# 726  2023-09-14 03:03:06
# 741  2023-09-14 03:04:49
# 1078 2023-09-14 03:46:27
# 1171 2023-09-14 03:01:12
#
#      Difference between Gressoney OUT Timestamp and Gressoney OUT Wave2 Cut Off
# 726                                   -1 days +23:56:54
# 741                                   -1 days +23:55:11
# 1078                                  -1 days +23:13:33
# 1171                                  -1 days +23:58:48
# Negative values for Gressoney OUT, Wave2:
#            Gressoney OUT  \
# 726  2023-09-14 03:03:06
# 741  2023-09-14 03:04:49
# 1078 2023-09-14 03:46:27
# 1171 2023-09-14 03:01:12
#
#      Difference between Gressoney OUT Timestamp and Gressoney OUT Wave2 Cut Off
# 726                                   -1 days +23:56:54
# 741                                   -1 days +23:55:11
# 1078                                  -1 days +23:13:33
# 1171                                  -1 days +23:58:48
