# %%
import requests
import json
import html
import pandas as pd
import time
import numpy as np
import matplotlib.pyplot as plt
import unicodedata
import re
# Out:
# C:\Users\Karina\miniconda3\lib\site-packages\requests\__init__.py:109: RequestsDependencyWarning: urllib3 (2.2.2) or chardet (3.0.4)/charset_normalizer (2.0.4) doesn't match a supported version!
#   warnings.warn(

# %%
# Function to remove special characters
def normalize_name(name):
    # Normalize to remove accents and special characters
    name = unicodedata.normalize('NFD', name)
    # Encode to ASCII and ignore errors, then decode back to string
    name = name.encode('ascii', 'ignore').decode('utf-8')
    return name

# %%
# # URL of the JSON file
# url = "https://itra.run/Races/RaceResults/TOR330.Tor.des.G%C3%A9ants%C2%AE/2023/80226"

# # Send a GET request to fetch the JSON data
# response = requests.get(url)
# response

# %%
years = [ '2024', '2023', 
         '2022', 
         '2022_HOTEL_ITALIA',  # bad weather at the end 
         '2022_RIFUGIO_FRASSATI',
         '2022_BOSSES',
         '2021', 
         '2019',
#          '2020', # cancelled due to covid
         '2018', '2017', '2016', 
         #'2015', # having issues with 2015
         '2014', '2013', '2012', '2011', '2010']

races = ['TOR130', 'TOR330', 'TOR450'
        ]

# %% [markdown]
# #### Loading ITRA

# %%
TORX_itra_df = {}
# races = ['TOR450']

for race in races:
    for year in years:
        try:

            file = f'{race} Data/3. ITRA/TXT/{race}_{year}.txt'
            df = pd.read_csv(file, delimiter='\t', 
                         dtype={'Time': 'string'})    

            # renaming columns so it is easier later to compare
            df = df.rename(columns={"Runner": "Name",
                                    "Gender": "Sex",
                                    "Nationality": "ITRA_Nationality",
                                   })

            # change the name to a title case
            df['Name'] = df['Name'].str.title()
            df['Name'] = df['Name'].apply(normalize_name)

            # Convert 'Time' to timedelta format
            df['Performance'] = pd.to_timedelta(df['Time'], errors='coerce')
            # Calculate total seconds and create 'Performance_Seconds' column
            df['Performance_Seconds'] = df['Performance'].dt.total_seconds()

            if year == '2022_HOTEL_ITALIA':
            # Create the 'Status' column
                df['Status'] =  'Finished at Hotel Italia'
                df['Year'] = '2022'    
            elif year == '2022_RIFUGIO_FRASSATI':
                df['Status'] = 'Finished at Rifugio Frassati'
                df['Year'] = '2022'
            elif year == '2022_BOSSES':
                df['Status'] =  'Finished at Bosses'
                df['Year'] = '2022'
            else:
                df['Status'] = np.where(df['Performance'].isna(), 'DNF', 'Finished')
                df['Year'] = f'{year}'

            df['Race'] = f'{race}'

    #             # Drop the intermediate columns if they're no longer needed
            df = df.drop(columns=['Time', '#'])

            df['Name'] = df['Name'].str.strip()
            df['Name'] = df['Name'].str.replace(',', '')
            df['Name'] = df['Name'].str.replace('\'', '')
            df['Name'] = df['Name'].str.replace('-', '')
            df['Name'] = df['Name'].str.replace(r"\s+", " ")

    #             print(race, year, '\n', df.head())

            # Store the DataFrame in the dictionary with a key like 'TOR330_2021'
            TORX_itra_df[f'{race}_{year}'] = df
            print('* ',f'{race}_{year} {df.shape}', '\n')
        except:
            
            if file == 'TOR330 Data/3. ITRA/TXT/TOR330_2022_HOTEL_ITALIA.txt':
                pass
            elif file == 'TOR450 Data/3. ITRA/TXT/TOR450_2022_RIFUGIO_FRASSATI.txt':
                pass
            elif file == 'TOR450 Data/3. ITRA/TXT/TOR330_2022_BOSSES.txt':
                pass
            
            else:
                print(f'issues with {race}_{year}')
                print(f'{file}')
                print('\n')
# Out:
# issues with TOR130_2024
# TOR130 Data/3. ITRA/TXT/TOR130_2024.txt
#
#
# issues with TOR130_2023
# TOR130 Data/3. ITRA/TXT/TOR130_2023.txt
#
#
# issues with TOR130_2022
# TOR130 Data/3. ITRA/TXT/TOR130_2022.txt
#
#
# issues with TOR130_2022_HOTEL_ITALIA
# TOR130 Data/3. ITRA/TXT/TOR130_2022_HOTEL_ITALIA.txt
#
#
# issues with TOR130_2022_RIFUGIO_FRASSATI
# TOR130 Data/3. ITRA/TXT/TOR130_2022_RIFUGIO_FRASSATI.txt
#
#
# issues with TOR130_2022_BOSSES
# TOR130 Data/3. ITRA/TXT/TOR130_2022_BOSSES.txt
#
#
# issues with TOR130_2021
# TOR130 Data/3. ITRA/TXT/TOR130_2021.txt
#
#
# issues with TOR130_2019
# TOR130 Data/3. ITRA/TXT/TOR130_2019.txt
#
#
# issues with TOR130_2018
# TOR130 Data/3. ITRA/TXT/TOR130_2018.txt
#
#
# issues with TOR130_2017
# TOR130 Data/3. ITRA/TXT/TOR130_2017.txt
#
#
# issues with TOR130_2016
# TOR130 Data/3. ITRA/TXT/TOR130_2016.txt
#
#
# issues with TOR130_2014
# TOR130 Data/3. ITRA/TXT/TOR130_2014.txt
#
#
# issues with TOR130_2013
# TOR130 Data/3. ITRA/TXT/TOR130_2013.txt
#
#
# issues with TOR130_2012
# TOR130 Data/3. ITRA/TXT/TOR130_2012.txt
#
#
# issues with TOR130_2011
# TOR130 Data/3. ITRA/TXT/TOR130_2011.txt
#
#
# issues with TOR130_2010
# TOR130 Data/3. ITRA/TXT/TOR130_2010.txt
#
#
# *  TOR330_2024 (1085, 9)
#
# *  TOR330_2023 (1093, 9)
#
# *  TOR330_2022 (408, 9)
#
# *  TOR330_2022_RIFUGIO_FRASSATI (101, 9)
#
# *  TOR330_2022_BOSSES (81, 9)
# C:\Users\Karina\AppData\Local\Temp\ipykernel_8604\2679965923.py:50: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Name'] = df['Name'].str.replace(r"\s+", " ")
# C:\Users\Karina\AppData\Local\Temp\ipykernel_8604\2679965923.py:50: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Name'] = df['Name'].str.replace(r"\s+", " ")
# C:\Users\Karina\AppData\Local\Temp\ipykernel_8604\2679965923.py:50: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Name'] = df['Name'].str.replace(r"\s+", " ")
# C:\Users\Karina\AppData\Local\Temp\ipykernel_8604\2679965923.py:50: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Name'] = df['Name'].str.replace(r"\s+", " ")
# C:\Users\Karina\AppData\Local\Temp\ipykernel_8604\2679965923.py:50: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Name'] = df['Name'].str.replace(r"\s+", " ")
# C:\Users\Karina\AppData\Local\Temp\ipykernel_8604\2679965923.py:50: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Name'] = df['Name'].str.replace(r"\s+", " ")
# *  TOR330_2021 (712, 9)
#
# *  TOR330_2019 (941, 9)
#
# *  TOR330_2018 (879, 9)
#
# *  TOR330_2017 (461, 9)
#
# *  TOR330_2016 (445, 9)
#
# *  TOR330_2014 (443, 9)
# C:\Users\Karina\AppData\Local\Temp\ipykernel_8604\2679965923.py:50: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Name'] = df['Name'].str.replace(r"\s+", " ")
# C:\Users\Karina\AppData\Local\Temp\ipykernel_8604\2679965923.py:50: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Name'] = df['Name'].str.replace(r"\s+", " ")
# C:\Users\Karina\AppData\Local\Temp\ipykernel_8604\2679965923.py:50: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Name'] = df['Name'].str.replace(r"\s+", " ")
# C:\Users\Karina\AppData\Local\Temp\ipykernel_8604\2679965923.py:50: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Name'] = df['Name'].str.replace(r"\s+", " ")
# C:\Users\Karina\AppData\Local\Temp\ipykernel_8604\2679965923.py:50: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Name'] = df['Name'].str.replace(r"\s+", " ")
# C:\Users\Karina\AppData\Local\Temp\ipykernel_8604\2679965923.py:50: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Name'] = df['Name'].str.replace(r"\s+", " ")
# *  TOR330_2013 (383, 9)
#
# *  TOR330_2012 (391, 9)
#
# *  TOR330_2011 (300, 9)
#
# *  TOR330_2010 (179, 9)
#
# *  TOR450_2024 (168, 9)
#
# *  TOR450_2023 (173, 9)
#
# *  TOR450_2022 (46, 9)
# C:\Users\Karina\AppData\Local\Temp\ipykernel_8604\2679965923.py:50: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Name'] = df['Name'].str.replace(r"\s+", " ")
# C:\Users\Karina\AppData\Local\Temp\ipykernel_8604\2679965923.py:50: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Name'] = df['Name'].str.replace(r"\s+", " ")
# C:\Users\Karina\AppData\Local\Temp\ipykernel_8604\2679965923.py:50: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Name'] = df['Name'].str.replace(r"\s+", " ")
# C:\Users\Karina\AppData\Local\Temp\ipykernel_8604\2679965923.py:50: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Name'] = df['Name'].str.replace(r"\s+", " ")
# C:\Users\Karina\AppData\Local\Temp\ipykernel_8604\2679965923.py:50: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Name'] = df['Name'].str.replace(r"\s+", " ")
# C:\Users\Karina\AppData\Local\Temp\ipykernel_8604\2679965923.py:50: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Name'] = df['Name'].str.replace(r"\s+", " ")
# C:\Users\Karina\AppData\Local\Temp\ipykernel_8604\2679965923.py:50: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Name'] = df['Name'].str.replace(r"\s+", " ")
# *  TOR450_2022_HOTEL_ITALIA (11, 9)
#
# issues with TOR450_2022_BOSSES
# TOR450 Data/3. ITRA/TXT/TOR450_2022_BOSSES.txt
#
#
# *  TOR450_2021 (56, 9)
#
# *  TOR450_2019 (100, 9)
#
# issues with TOR450_2018
# TOR450 Data/3. ITRA/TXT/TOR450_2018.txt
#
#
# issues with TOR450_2017
# TOR450 Data/3. ITRA/TXT/TOR450_2017.txt
#
#
# issues with TOR450_2016
# TOR450 Data/3. ITRA/TXT/TOR450_2016.txt
#
#
# issues with TOR450_2014
# TOR450 Data/3. ITRA/TXT/TOR450_2014.txt
#
#
# issues with TOR450_2013
# TOR450 Data/3. ITRA/TXT/TOR450_2013.txt
#
#
# issues with TOR450_2012
# TOR450 Data/3. ITRA/TXT/TOR450_2012.txt
#
#
# issues with TOR450_2011
# TOR450 Data/3. ITRA/TXT/TOR450_2011.txt
#
#
# issues with TOR450_2010
# TOR450 Data/3. ITRA/TXT/TOR450_2010.txt
# C:\Users\Karina\AppData\Local\Temp\ipykernel_8604\2679965923.py:50: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Name'] = df['Name'].str.replace(r"\s+", " ")
# C:\Users\Karina\AppData\Local\Temp\ipykernel_8604\2679965923.py:50: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Name'] = df['Name'].str.replace(r"\s+", " ")

# %%
for race in races:
    for year in years:
        try:
            tor_year = TORX_itra_df[f'{race}_{year}']
            # Count the occurrences of each status
            status_counts = tor_year['Status'].value_counts()
            print(race, year, '\n', status_counts, '\n', '*'*40)
        except:
            pass
# Out:
# TOR330 2024
#  DNF         552
# Finished    533
# Name: Status, dtype: int64
#  ****************************************
# TOR330 2023
#  Finished    621
# DNF         472
# Name: Status, dtype: int64
#  ****************************************
# TOR330 2022
#  Finished    408
# Name: Status, dtype: int64
#  ****************************************
# TOR330 2022_RIFUGIO_FRASSATI
#  Finished at Rifugio Frassati    101
# Name: Status, dtype: int64
#  ****************************************
# TOR330 2022_BOSSES
#  Finished at Bosses    81
# Name: Status, dtype: int64
#  ****************************************
# TOR330 2021
#  Finished    431
# DNF         281
# Name: Status, dtype: int64
#  ****************************************
# TOR330 2019
#  Finished    563
# DNF         378
# Name: Status, dtype: int64
#  ****************************************
# TOR330 2018
#  Finished    534
# DNF         345
# Name: Status, dtype: int64
#  ****************************************
# TOR330 2017
#  Finished    461
# Name: Status, dtype: int64
#  ****************************************
# TOR330 2016
#  Finished    445
# Name: Status, dtype: int64
#  ****************************************
# TOR330 2014
#  Finished    443
# Name: Status, dtype: int64
#  ****************************************
# TOR330 2013
#  Finished    383
# Name: Status, dtype: int64
#  ****************************************
# TOR330 2012
#  Finished    391
# Name: Status, dtype: int64
#  ****************************************
# TOR330 2011
#  Finished    300
# Name: Status, dtype: int64
#  ****************************************
# TOR330 2010
#  Finished    179
# Name: Status, dtype: int64
#  ****************************************
# TOR450 2024
#  DNF         100
# Finished     68
# Name: Status, dtype: int64
#  ****************************************
# TOR450 2023
#  DNF         88
# Finished    85
# Name: Status, dtype: int64
#  ****************************************
# TOR450 2022
#  Finished    46
# Name: Status, dtype: int64
#  ****************************************
# TOR450 2022_HOTEL_ITALIA
#  Finished at Hotel Italia    11
# Name: Status, dtype: int64
#  ****************************************
# TOR450 2021
#  Finished    31
# DNF         25
# Name: Status, dtype: int64
#  ****************************************
# TOR450 2019
#  DNF         60
# Finished    40
# Name: Status, dtype: int64
#  ****************************************

# %%
TORX_itra_df
# Out:
# {'TOR330_2024':                     Name Age Sex ITRA_Nationality     Performance  \
#  0       D Haene Francois  39   M              FRA 2 days 21:08:32
#  1      Marmissolle Benat  43   M              FRA 3 days 01:10:18
#  2         Perrier Martin  34   M              FRA 3 days 03:35:59
#  3          Macchi Andrea  38   M              ITA 3 days 04:43:09
#  4            Hall Damian  49   M              GBR 3 days 04:49:20
#  ...                  ...  ..  ..              ...             ...
#  1080        Zimei Andrea  44   M              ITA             NaT
#  1081  Zinfolino Federica  47   F              ITA             NaT
#  1082       Zoratti Mauro  36   M              ITA             NaT
#  1083       Zou Hongjiang  43   M              CHN             NaT
#  1084                      56   M              JPN             NaT
#
#        Performance_Seconds    Status  Year    Race
#  0                248912.0  Finished  2024  TOR330
#  1                263418.0  Finished  2024  TOR330
#  2                272159.0  Finished  2024  TOR330
#  3                276189.0  Finished  2024  TOR330
#  4                276560.0  Finished  2024  TOR330
#  ...                   ...       ...   ...     ...
#  1080                  NaN       DNF  2024  TOR330
#  1081                  NaN       DNF  2024  TOR330
#  1082                  NaN       DNF  2024  TOR330
#  1083                  NaN       DNF  2024  TOR330
#  1084                  NaN       DNF  2024  TOR330
#
#  [1085 rows x 9 columns],
#  'TOR330_2023':                   Name Age Sex ITRA_Nationality     Performance  \
#  3               293460.0  Finished  2021  TOR330
#  4               297952.0  Finished  2021  TOR330
#  ..                   ...       ...   ...     ...
#  707                  NaN       DNF  2021  TOR330
#  708                  NaN       DNF  2021  TOR330
#  709                  NaN       DNF  2021  TOR330
#  710                  NaN       DNF  2021  TOR330
#  711                  NaN       DNF  2021  TOR330
#
#  [712 rows x 9 columns],
#  'TOR330_2019':                    Name Age Sex ITRA_Nationality     Performance  \
#  0    Bosatelli Oliviero  50   M              ITA 3 days 00:37:13
#  1        Reynolds Galen  35   M              CAN 3 days 05:06:12
#  2     Lantermino Danilo  38   M              ITA 3 days 07:09:46
#  3           Erwee Tiaan  32   M              RSA 3 days 08:18:24
#  4            Lukas Jens  53   M              GER 3 days 13:04:04
#  ..                  ...  ..  ..              ...             ...
#  936         Zhang Yuren  48   M              CHN             NaT
#  937        Zhao Yingkai  39   M              CHN             NaT
#  938        Zheng Junyue  33   F              CHN             NaT
#  939   Zimmermann Denise  44   F              SUI             NaT
#  940       Zoppi Filippo  48   M              ITA             NaT
#
#       Performance_Seconds    Status  Year    Race
#  0               261433.0  Finished  2019  TOR330
#  1               277572.0  Finished  2019  TOR330
#  2               284986.0  Finished  2019  TOR330
#  3               289104.0  Finished  2019  TOR330
#  4               306244.0  Finished  2019  TOR330
#  ..                   ...       ...   ...     ...
#  936                  NaN       DNF  2019  TOR330
#  937                  NaN       DNF  2019  TOR330
#  938                  NaN       DNF  2019  TOR330
#  939                  NaN       DNF  2019  TOR330
#  940                  NaN       DNF  2019  TOR330
#
#  [941 rows x 9 columns],
#  'TOR330_2018':                    Name Age Sex ITRA_Nationality     Performance  \
#  0          Colle Franco  40   M              ITA 3 days 02:03:00
#  1        Reynolds Galen  34   M              CAN 3 days 02:40:36
#  2          Kienzl Peter  43   M              ITA 3 days 05:31:11
#  3    Bosatelli Oliviero  49   M              ITA 3 days 08:49:26
#  4         Toriumi Kouta  33   M              JPN 3 days 08:58:35
#  ..                  ...  ..  ..              ...             ...
#  874           Zdon Bill  33   M              USA             NaT
#  875      Zennaro Davide  57   M              ITA             NaT
#  876        Zimei Andrea  38   M              ITA             NaT
#  877   Zimmermann Denise  43   F              SUI             NaT
#  878        Zugna Davide  42   M              ITA             NaT
#
#       Performance_Seconds    Status  Year    Race
#  0               266580.0  Finished  2018  TOR330
#  1               268836.0  Finished  2018  TOR330
#  2               279071.0  Finished  2018  TOR330
#  3               290966.0  Finished  2018  TOR330
#  4               291515.0  Finished  2018  TOR330
#  ..                   ...       ...   ...     ...
#  874                  NaN       DNF  2018  TOR330
#  875                  NaN       DNF  2018  TOR330
#  876                  NaN       DNF  2018  TOR330
#  877                  NaN       DNF  2018  TOR330
#  878                  NaN       DNF  2018  TOR330
#
#  [879 rows x 9 columns],
#  'TOR330_2017':                       Name Age Sex ITRA_Nationality     Performance  \
#  0    Dominguez Ledo Javier  43   M              ESP 2 days 19:52:15
#  1       Bosatelli Oliviero  48   M              ITA 2 days 21:16:19
#  2            Macchi Andrea  31   M              ITA 3 days 02:51:14
#  3                Sa Carlos  44   M              POR 3 days 08:20:34
#  22             661564.0  Finished  2021  TOR450
#  23             662454.0  Finished  2021  TOR450
#  24             663871.0  Finished  2021  TOR450
#  25             664267.0  Finished  2021  TOR450
#  26             666024.0  Finished  2021  TOR450
#  27             666024.0  Finished  2021  TOR450
#  28             668260.0  Finished  2021  TOR450
#  29             672641.0  Finished  2021  TOR450
#  30             672641.0  Finished  2021  TOR450
#  31                  NaN       DNF  2021  TOR450
#  32                  NaN       DNF  2021  TOR450
#  33                  NaN       DNF  2021  TOR450
#  34                  NaN       DNF  2021  TOR450
#  35                  NaN       DNF  2021  TOR450
#  36                  NaN       DNF  2021  TOR450
#  37                  NaN       DNF  2021  TOR450
#  38                  NaN       DNF  2021  TOR450
#  39                  NaN       DNF  2021  TOR450
#  40                  NaN       DNF  2021  TOR450
#  41                  NaN       DNF  2021  TOR450
#  42                  NaN       DNF  2021  TOR450
#  43                  NaN       DNF  2021  TOR450
#  44                  NaN       DNF  2021  TOR450
#  45                  NaN       DNF  2021  TOR450
#  46                  NaN       DNF  2021  TOR450
#  47                  NaN       DNF  2021  TOR450
#  48                  NaN       DNF  2021  TOR450
#  49                  NaN       DNF  2021  TOR450
#  50                  NaN       DNF  2021  TOR450
#  51                  NaN       DNF  2021  TOR450
#  52                  NaN       DNF  2021  TOR450
#  53                  NaN       DNF  2021  TOR450
#  54                  NaN       DNF  2021  TOR450
#  55                  NaN       DNF  2021  TOR450  ,
#  'TOR450_2019':                  Name  Age Sex ITRA_Nationality     Performance  \
#  0           Papi Luca   39   M              ITA 5 days 14:10:01
#  1      Richard Victor   33   M              BEL 5 days 19:46:59
#  2        Ono Masahiro   38   M              JPN 5 days 20:22:52
#  3        Dove Matthew   35   M              RSA 6 days 13:36:52
#  4        Kuchimi Taro   38   M              JPN 6 days 14:22:48
#  ..                ...  ...  ..              ...             ...
#  95    Thiebat Orlando   65   M              ITA             NaT
#  96       Thierry Ador   48   M              FRA             NaT
#  97   Tribolo Philippe   44   M              FRA             NaT
#  98   Viglino Frederic   48   M              FRA             NaT
#  99  Zapata Munoz Juan   46   M              ESP             NaT
#
#      Performance_Seconds    Status  Year    Race
#  0              483001.0  Finished  2019  TOR450
#  1              503219.0  Finished  2019  TOR450
#  2              505372.0  Finished  2019  TOR450
#  3              567412.0  Finished  2019  TOR450
#  4              570168.0  Finished  2019  TOR450
#  ..                  ...       ...   ...     ...
#  95                  NaN       DNF  2019  TOR450
#  96                  NaN       DNF  2019  TOR450
#  97                  NaN       DNF  2019  TOR450
#  98                  NaN       DNF  2019  TOR450
#  99                  NaN       DNF  2019  TOR450
#
#  [100 rows x 9 columns]}

# %%
# Append using pd.concat
TORX_itra_df = pd.concat(TORX_itra_df)
TORX_itra_df = TORX_itra_df.reset_index(drop = True)
TORX_itra_df.isna().sum()
# Out:
# Name                      0
# Age                       0
# Sex                      13
# ITRA_Nationality          0
# Performance            2301
# Performance_Seconds    2301
# Status                    0
# Year                      0
# Race                      0
# dtype: int64

# %%
years_list = TORX_itra_df['Year'].unique()
race_list = TORX_itra_df['Race'].unique()

for race in races:
    for year in years_list:
        year_df = TORX_itra_df[(TORX_itra_df['Year'] == year) &
                              (TORX_itra_df['Race'] == race)]
        status_df = year_df['Status'].value_counts()
        
        if race == 'TOR450' and year in [ 
            #'2020', # cancelled due to covid
         '2018', '2017', '2016', 
         '2015', 
         '2014', '2013', '2012', '2011', '2010']:
            pass
        else:
            print(race, year,'\n',status_df, '\n', '*'*40)
# Out:
# TOR130 2024
#  Series([], Name: Status, dtype: int64)
#  ****************************************
# TOR130 2023
#  Series([], Name: Status, dtype: int64)
#  ****************************************
# TOR130 2022
#  Series([], Name: Status, dtype: int64)
#  ****************************************
# TOR130 2021
#  Series([], Name: Status, dtype: int64)
#  ****************************************
# TOR130 2019
#  Series([], Name: Status, dtype: int64)
#  ****************************************
# TOR130 2018
#  Series([], Name: Status, dtype: int64)
#  ****************************************
# TOR130 2017
#  Series([], Name: Status, dtype: int64)
#  ****************************************
# TOR130 2016
#  Series([], Name: Status, dtype: int64)
#  ****************************************
# TOR130 2014
#  Series([], Name: Status, dtype: int64)
#  ****************************************
# TOR130 2013
#  Series([], Name: Status, dtype: int64)
#  ****************************************
# TOR130 2012
#  Series([], Name: Status, dtype: int64)
#  ****************************************
# TOR130 2011
#  Series([], Name: Status, dtype: int64)
#  ****************************************
# TOR130 2010
#  Series([], Name: Status, dtype: int64)
#  ****************************************
# TOR330 2024
#  DNF         552
# Finished    533
# Name: Status, dtype: int64
#  ****************************************
# TOR330 2023
#  Finished    621
# DNF         472
# Name: Status, dtype: int64
#  ****************************************
# TOR330 2022
#  Finished                        408
# Finished at Rifugio Frassati    101
# Finished at Bosses               81
# Name: Status, dtype: int64
#  ****************************************
# TOR330 2021
#  Finished    431
# DNF         281
# Name: Status, dtype: int64
#  ****************************************
# TOR330 2019
#  Finished    563
# DNF         378
# Name: Status, dtype: int64
#  ****************************************
# TOR330 2018
#  Finished    534
# DNF         345
# Name: Status, dtype: int64
#  ****************************************
# TOR330 2017
#  Finished    461
# Name: Status, dtype: int64
#  ****************************************
# TOR330 2016
#  Finished    445
# Name: Status, dtype: int64
#  ****************************************
# TOR330 2014
#  Finished    443
# Name: Status, dtype: int64
#  ****************************************
# TOR330 2013
#  Finished    383
# Name: Status, dtype: int64
#  ****************************************
# TOR330 2012
#  Finished    391
# Name: Status, dtype: int64
#  ****************************************
# TOR330 2011
#  Finished    300
# Name: Status, dtype: int64
#  ****************************************
# TOR330 2010
#  Finished    179
# Name: Status, dtype: int64
#  ****************************************
# TOR450 2024
#  DNF         100
# Finished     68
# Name: Status, dtype: int64
#  ****************************************
# TOR450 2023
#  DNF         88
# Finished    85
# Name: Status, dtype: int64
#  ****************************************
# TOR450 2022
#  Finished                    46
# Finished at Hotel Italia    11
# Name: Status, dtype: int64
#  ****************************************
# TOR450 2021
#  Finished    31
# DNF         25
# Name: Status, dtype: int64
#  ****************************************
# TOR450 2019
#  DNF         60
# Finished    40
# Name: Status, dtype: int64
#  ****************************************

# %% [markdown]
# ## EDA of ITRA

# %%
TORX_itra_df[TORX_itra_df['Sex'].isna()]
# Out:
#                        Name Age  Sex ITRA_Nationality     Performance  \
# 643       Coluccio Pasquale  60  NaN              ITA             NaT
# 1223           Bryant Shane  45  NaN              USA 4 days 23:30:03
# 1608           DAngelo Deva  33  NaN              ITA 6 days 01:56:32
# 1760   Cailleau Marie Aline  56  NaN              FRA             NaT
# 2307         Carlier Julien  43  NaN              FRA 4 days 20:36:16
# 2419            Barrot Loic  41  NaN              FRA 5 days 06:22:53
# 2698      Coluccio Pasquale  58  NaN              ITA 5 days 13:42:05
# 3180          Polotti Diego  49  NaN              ITA 6 days 05:02:17
# 3259      Coluccio Pasquale  57  NaN              ITA             NaT
# 4831  Martignoni Alessandro  40  NaN              ITA 6 days 00:29:36
# 5023      Coluccio Pasquale  54  NaN              ITA             NaT
# 5638            Oktem Ozgur  41  NaN              TUR 6 days 01:23:58
# 7018      Coluccio Pasquale  49  NaN              ITA 6 days 04:24:39
#
#       Performance_Seconds              Status  Year    Race
# 643                   NaN                 DNF  2024  TOR330
# 1223             430203.0            Finished  2023  TOR330
# 1608             525392.0            Finished  2023  TOR330
# 1760                  NaN                 DNF  2023  TOR330
# 2307             419776.0            Finished  2022  TOR330
# 2419             454973.0            Finished  2022  TOR330
# 2698             481325.0  Finished at Bosses  2022  TOR330
# 3180             536537.0            Finished  2021  TOR330
# 3259                  NaN                 DNF  2021  TOR330
# 4831             520176.0            Finished  2018  TOR330
# 5023                  NaN                 DNF  2018  TOR330
# 5638             523438.0            Finished  2017  TOR330
# 7018             534279.0            Finished  2013  TOR330

# %%
TORX_itra_df[TORX_itra_df['Name'] == 'D Haene Francois']
# Out:
#                Name Age Sex ITRA_Nationality     Performance  \
# 0  D Haene Francois  39   M              FRA 2 days 21:08:32
#
#    Performance_Seconds    Status  Year    Race
# 0             248912.0  Finished  2024  TOR330

# %%
TORX_itra_df[TORX_itra_df['Name'] == 'Tierney Paul']
# Out:
#               Name Age Sex ITRA_Nationality     Performance  \
# 2779  Tierney Paul  39   M              IRL 3 days 16:05:51
# 4441  Tierney Paul  36   M              IRL 3 days 22:39:26
# 5324  Tierney Paul  35   M              IRL 4 days 03:09:44
# 8064  Tierney Paul  42   M              IRL             NaT
# 8076  Tierney Paul  41   M              IRL 5 days 15:22:00
# 8246  Tierney Paul  40   M              IRL 5 days 16:23:20
#
#       Performance_Seconds    Status  Year    Race
# 2779             317151.0  Finished  2021  TOR330
# 4441             340766.0  Finished  2018  TOR330
# 5324             356984.0  Finished  2017  TOR330
# 8064                  NaN       DNF  2024  TOR450
# 8076             487320.0  Finished  2023  TOR450
# 8246             491000.0  Finished  2022  TOR450

# %%
TORX_itra_df[TORX_itra_df['Name'].str.contains('Girolami Paolo')]
# Out:
#                 Name Age Sex ITRA_Nationality     Performance  \
# 1508  Girolami Paolo  51   M              ITA 5 days 21:59:50
# 2723  Girolami Paolo  50   M              ITA 5 days 15:49:42
# 3818  Girolami Paolo  47   M              ITA 5 days 19:57:42
# 4824  Girolami Paolo  46   M              ITA 5 days 23:54:43
# 5654  Girolami Paolo  45   M              ITA 6 days 01:52:54
#
#       Performance_Seconds              Status  Year    Race
# 1508             511190.0            Finished  2023  TOR330
# 2723             488982.0  Finished at Bosses  2022  TOR330
# 3818             503862.0            Finished  2019  TOR330
# 4824             518083.0            Finished  2018  TOR330
# 5654             525174.0            Finished  2017  TOR330

# %% [markdown]
# ### Extracting only Finishers

# %%
# TORX_itra_df
TORX_itra_no_DNF = TORX_itra_df[(TORX_itra_df['Status'] != 'DNF') &
                                (TORX_itra_df['Race'] != race) 
                                 # & (TORX_itra_df['Year'] != year)
                               ].reset_index(drop = True)
TORX_itra_no_DNF = TORX_itra_no_DNF[[
    'Name', 'ITRA_Nationality', 'Sex',  'Age', 
    'Performance','Performance_Seconds','Status', 
    'Race', 'Year'
]]

# %%
TORX_itra_no_DNF['Status'].unique()
# Out:
# array(['Finished', 'Finished at Rifugio Frassati', 'Finished at Bosses'],
#       dtype=object)

# %%
TORX_itra_no_DNF.isna().sum()
# Out:
# Name                   0
# ITRA_Nationality       0
# Sex                    9
# Age                    0
# Performance            0
# Performance_Seconds    0
# Status                 0
# Race                   0
# Year                   0
# dtype: int64

# %%
TORX_itra_no_DNF.head()
# Out:
#                 Name ITRA_Nationality Sex Age     Performance  \
# 0   D Haene Francois              FRA   M  39 2 days 21:08:32
# 1  Marmissolle Benat              FRA   M  43 3 days 01:10:18
# 2     Perrier Martin              FRA   M  34 3 days 03:35:59
# 3      Macchi Andrea              ITA   M  38 3 days 04:43:09
# 4        Hall Damian              GBR   M  49 3 days 04:49:20
#
#    Performance_Seconds    Status    Race  Year
# 0             248912.0  Finished  TOR330  2024
# 1             263418.0  Finished  TOR330  2024
# 2             272159.0  Finished  TOR330  2024
# 3             276189.0  Finished  TOR330  2024
# 4             276560.0  Finished  TOR330  2024

# %% [markdown]
# ### This data might be used later data Visualisations

# %%
# grabbing all finishers 
TORX_itra_no_DNF['Performance'] = TORX_itra_no_DNF['Performance'].astype('str')



for race in ['TOR130', 'TOR330', 'TOR450']:
    df = TORX_itra_no_DNF[TORX_itra_no_DNF['Race'] == race]
    print(df.head)
    # # Save the result
    df.to_excel(f'{race} Data/5. Clean Data for Data Visualisation/{race}_itra_no_DNF.xlsx' , index = False)
# Out:
# <bound method NDFrame.head of Empty DataFrame
# Columns: [Name, ITRA_Nationality, Sex, Age, Performance, Performance_Seconds, Status, Race, Year]
# Index: []>
# <bound method NDFrame.head of                      Name ITRA_Nationality Sex Age      Performance  \
# 0        D Haene Francois              FRA   M  39  2 days 21:08:32
# 1       Marmissolle Benat              FRA   M  43  3 days 01:10:18
# 2          Perrier Martin              FRA   M  34  3 days 03:35:59
# 3           Macchi Andrea              ITA   M  38  3 days 04:43:09
# 4             Hall Damian              GBR   M  49  3 days 04:49:20
# ...                   ...              ...  ..  ..              ...
# 5869      Marmier Natacha              FRA   F  55  6 days 04:37:16
# 5870  Marmier Jean Claude              FRA   M  67  6 days 04:37:20
# 5871         Slagel Craig              CAN   M  38  6 days 04:38:00
# 5872        Dawirs Michel              BEL   M  52  6 days 04:43:34
# 5873            Riz Luigi              ITA   M  54  6 days 05:58:03
#
#       Performance_Seconds    Status    Race  Year
# 0                248912.0  Finished  TOR330  2024
# 1                263418.0  Finished  TOR330  2024
# 2                272159.0  Finished  TOR330  2024
# 3                276189.0  Finished  TOR330  2024
# 4                276560.0  Finished  TOR330  2024
# ...                   ...       ...     ...   ...
# 5869             535036.0  Finished  TOR330  2010
# 5870             535040.0  Finished  TOR330  2010
# 5871             535080.0  Finished  TOR330  2010
# 5872             535414.0  Finished  TOR330  2010
# 5873             539883.0  Finished  TOR330  2010
#
# [5874 rows x 9 columns]>
# <bound method NDFrame.head of Empty DataFrame
# Columns: [Name, ITRA_Nationality, Sex, Age, Performance, Performance_Seconds, Status, Race, Year]
# Index: []>
